# %% [markdown]
# # Part II Getting our Audio Features for Top100 Hotlist

# %% [markdown]
# Goal: Generate a 5k list with diff audio features from diff authors based on our hot list
#
# 1. Start with only one song and figure out which query etc. (done)
#
# 2. Get Several Authors and their albums
# 3. Feed quere with all album and / or track ids

# %% [markdown]
# ## Load data file

# %%
import pandas as pd

df_input = pd.read_csv ("../web_scraping_Marcus_Anne/df.csv")
                  #'Path where the CSV file is stored\df.csv')
df_input.head(14)
# Out:
#     Unnamed: 0  Rank                                      Song Title  \
# 0            0    57                                            1999
# 1            0    20               (Everything I Do) I Do It For You
# 2            0    46                   (I Can't Get No) Satisfaction
# 3            0    15                  (I've Had) The Time Of My Life
# 4            0    47                     (Let Me Be Your) Teddy Bear
# 5            0    19                (Sittin' On) The Dock Of The Bay
# 6            1    29             (We're Gonna) Rock Around The Clock
# 7            1    38    (You Gotta) Fight For Your Right (To Party!)
# 8            1    70  (Your Love Keeps Lifting Me) Higher And Higher
# 9            1   100                                        1 2 Step
# 10           1    78                                      1, 2, 3, 4
# 11           1    74                                      16 Candles
# 12           2    88                              A Teenager In Love
# 13           2    19                                             ABC
#
#                       Song Artist  Year        Genre  Decade
# 0                          Prince  1983      Popular    1980
# 1                     Bryan Adams  1991       Ballad    1990
# 2                  Rolling Stones  1965       Oldies    1960
# 3   Bill Medley & Jennifer Warnes  1987       Ballad    1980
# 4                   Elvis Presley  1957       Oldies    1950
# 5                    Otis Redding  1968       Oldies    1960
# 6         Bill Haley & His Comets  1955       Oldies    1950
# 7                    Beastie Boys  1987  Alternative    1980
# 8                   Jackie Wilson  1967       Oldies    1960
# 9       Ciara Feat. Missy Elliott  2004          R&B    2000
# 10                Plain White T's  2008         Rock    2000
# 11                         Crests  1958       Oldies    1950
# 12            Dion & The Belmonts  1958       Oldies    1950
# 13                      Jackson 5  1970       Oldies    1970

# %%
df_input["Song Artist"].value_counts()
# Out:
# Beatles              18
# Frank Sinatra        17
# Elvis Presley        11
# Michael Jackson      10
# Dean Martin           7
#                      ..
# Louis Armstrong       1
# Sean Kingston         1
# Tony Bennett          1
# N Sync                1
# Simon & Garfunkel     1
# Name: Song Artist, Length: 382, dtype: int64

# %%
382*10
# Out:
# 3820

# %%
#simple way

artist = "Prince"

#song = sp.search(q="prince", limit=10) 
song = sp.search(q=artist, limit=5) 

#pprint.pprint(song['tracks']['items'][0]['uri'])
song["tracks"]["items"][0]["uri"]
sp.audio_features(song["tracks"]["items"][0]["uri"])[0]
# Out:
# {'danceability': 0.589,
#  'energy': 0.484,
#  'key': 7,
#  'loudness': -11.613,
#  'mode': 1,
#  'speechiness': 0.0742,
#  'acousticness': 0.42,
#  'instrumentalness': 0.0385,
#  'liveness': 0.109,
#  'valence': 0.0726,
#  'tempo': 139.998,
#  'type': 'audio_features',
#  'id': '2O9KgUsmuon6Gycdmagc6t',
#  'uri': 'spotify:track:2O9KgUsmuon6Gycdmagc6t',
#  'track_href': 'https://api.spotify.com/v1/tracks/2O9KgUsmuon6Gycdmagc6t',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2O9KgUsmuon6Gycdmagc6t',
#  'duration_ms': 95709,
#  'time_signature': 4}

# %%
#transform into a dataframe 
my_dict = sp.audio_features(song["tracks"]["items"][0]["uri"])[0] # you can provide a list of uri's

print(my_dict)
my_dict_new = { key: [my_dict[key]] for key in list(my_dict.keys()) }

#my_dict_new['name'] = [song["tracks"]["items"][0]['name']]
print(my_dict_new)

pd.DataFrame(my_dict_new)

# %% [markdown]
# ### Test

# %%
from tqdm import tqdm_notebook

# %%
def artist_tracks(artists):
    
    '''
    Takes a list of artist names, iterates through their Spotify albums, checks for 
    duplicate albums, then appends all the tracks in those albums to a list of lists
    '''
    
    # Each list in this list will be a track and its features
    tracks = []
    
    
    for artist in tqdm_notebook(artists):
        
        # Get the artist URI (a unique ID)
        artist_uri = sp.search(artist)['tracks']['items'][0]['artists'][0]['uri']

        # Spotify has a lot of duplicate albums, but we'll cross-reference them with this list to avoid extra loops
        album_checker = []
        
        # The starting point of our loop of albums for those artists with more than 50
        n = 0
        
        # Note the album_type = 'album'. This discounts singles, compilations and collaborations
        while len(sp.artist_albums(artist_uri, album_type = 'album', limit=50, offset = n)['items']) > 0:
            
            # Avoid overloading Spotify with requests by assigning the list of album dictionaries to a variable
            dict_list = sp.artist_albums(artist_uri, album_type = 'album', limit=50, offset = n)['items']
            
            for i, album in tqdm_notebook(enumerate(dict_list)):

                # Add the featured artists for the album in question to the checklist
                check_this_album = [j['name'] for j in dict_list[i]['artists']]
                # And the album name
                check_this_album.append(dict_list[i]['name'])
                # And its date
                check_this_album.append(dict_list[i]['release_date'])

                # Only continue looping if that album isn't in the checklist
                if check_this_album not in album_checker:
                    
                    # Add this album to the checker
                    album_checker.append(check_this_album)
                    # For every song on the album, get its descriptors and features in a list and add to the tracklist
                    tracks.extend([[artist, album['name'], album['uri'], song['name'],

                      album['release_date']] + list(sp.audio_features(song['uri'])[0].values()) 
                                   for song in sp.album_tracks(album['uri'])['items']])
            
            # Go through the next 50 albums (otherwise we'll get an infinite while loop)
            n += 50

    return tracks

# %%
artist_tracks(["Clueso"])
# Out:
# <ipython-input-59-99c3e4f8f852>:12: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for artist in tqdm_notebook(artists):
#   0%|          | 0/1 [00:00<?, ?it/s]
# <ipython-input-59-99c3e4f8f852>:29: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i, album in tqdm_notebook(enumerate(dict_list)):
# 0it [00:00, ?it/s]
# [['Clueso',
#   '37 Grad im Paradies',
#   'spotify:album:5YzSgYPNMpoGhsiJuxsxx1',
#   '37 Grad im Paradies',
#   '2021-09-10',
#   0.704,
#   0.761,
#   2,
#   -5.175,
#   0,
#   0.0866,
#   0.193,
#   0,
#   0.371,
#   0.92,
#   109.957,
#   'audio_features',
#   '1hZdD6Jf5QB4az60f7JasG',
#   'spotify:track:1hZdD6Jf5QB4az60f7JasG',
#   'https://api.spotify.com/v1/tracks/1hZdD6Jf5QB4az60f7JasG',
#   'https://api.spotify.com/v1/audio-analysis/1hZdD6Jf5QB4az60f7JasG',
#   143904,
#   4],
#  ['Clueso',
#   '37 Grad im Paradies',
#   'spotify:album:5YzSgYPNMpoGhsiJuxsxx1',
#   'Willkommen Zurück (feat. Andreas Bourani)',
#   '2021-09-10',
#   0.552,
#   0.699,
#   0,
#   -4.448,
#   1,
#   0.244,
#   0.114,
#   3.34e-06,
#   0.171,
#   0.735,
#   96.741,
#   'audio_features',
#   '39y82nQly82LaIC6o6eam3',
#   'spotify:track:39y82nQly82LaIC6o6eam3',
#   'https://api.spotify.com/v1/tracks/39y82nQly82LaIC6o6eam3',
#   'https://api.spotify.com/v1/audio-analysis/39y82nQly82LaIC6o6eam3',
#   149661,
#   4],
#  ['Clueso',
#   '37 Grad im Paradies',
#   'spotify:album:5YzSgYPNMpoGhsiJuxsxx1',
#   'Leider Berlin',
#   '2021-09-10',
#   0.731,
#   0.837,
#   7,
#   -4.29,
#   0,
#   0.03,
#   0.0775,
#   1.22e-05,
#   0.216,
#   0.635,
#   119.989,
#   'audio_features',
#   '72JzOET71wM1n7L46ud0uy',
#   'spotify:track:72JzOET71wM1n7L46ud0uy',
#   'https://api.spotify.com/v1/tracks/72JzOET71wM1n7L46ud0uy',
#   'https://api.spotify.com/v1/audio-analysis/72JzOET71wM1n7L46ud0uy',
#   192668,
#   4],
#  ['Clueso',
#   '37 Grad im Paradies',
#   'spotify:album:5YzSgYPNMpoGhsiJuxsxx1',
#   'Du Warst Immer Dabei',
#   '2021-09-10',
#   0.732,
#   0.516,
#   6,
#   -8.611,
#   1,
#   0.0999,
#   0.761,
#   1.24e-05,
#   0.0819,
#   0.665,
#   155.939,
#   'audio_features',
#   '0BLeKB3iteYyaS10h67TY2',
#   'spotify:track:0BLeKB3iteYyaS10h67TY2',
#   'https://api.spotify.com/v1/tracks/0BLeKB3iteYyaS10h67TY2',
#   'https://api.spotify.com/v1/audio-analysis/0BLeKB3iteYyaS10h67TY2',
#   176346,
#   4],
#  ['Clueso',
#   '37 Grad im Paradies',
#   'spotify:album:5YzSgYPNMpoGhsiJuxsxx1',
#   'Aber Ohne Dich',
#   '2021-09-10',
#   0.794,
#   0.732,
#   8,
#   -5.864,
#   0,
#   0.149,
#   0.539,
#   1.56e-05,
#   0.117,
#   0.417,
#   98.959,
#   'audio_features',
#   '2TmSY7Chow5iMpIIOLnNbq',
#   'spotify:track:2TmSY7Chow5iMpIIOLnNbq',
#   'https://api.spotify.com/v1/tracks/2TmSY7Chow5iMpIIOLnNbq',
#   'https://api.spotify.com/v1/audio-analysis/2TmSY7Chow5iMpIIOLnNbq',
#   172733,
#   4],
#  ['Clueso',
#   '37 Grad im Paradies',
#   'spotify:album:5YzSgYPNMpoGhsiJuxsxx1',
#   'Flugmodus',
#   '2021-09-10',
#   0.724,
#   0.535,
#   8,
#   -6.273,
#   1,
#   0.0858,
#   0.608,
#   0,
#   0.387,
#   0.705,
#   140.01,
#   'audio_features',
#   '3VrgQhEaG8ivzUZ9TMu1nH',
#   'spotify:track:3VrgQhEaG8ivzUZ9TMu1nH',
#   'https://api.spotify.com/v1/tracks/3VrgQhEaG8ivzUZ9TMu1nH',
#   'https://api.spotify.com/v1/audio-analysis/3VrgQhEaG8ivzUZ9TMu1nH',
#   178399,
#   3],
#  ['Clueso',
#   '37 Grad im Paradies',
#   'spotify:album:5YzSgYPNMpoGhsiJuxsxx1',
#   'Tanzen',
#   '2021-09-10',
#   0.889,
#   0.53,
#   9,
#   -5.114,
#   0,
#   0.0999,
#   0.215,
#   0,
#   0.0744,
#   0.797,
#   99.015,
#   'audio_features',
#   '6aZJXIkdjjQGZEVOF7suGW',
#   'spotify:track:6aZJXIkdjjQGZEVOF7suGW',
#   'https://api.spotify.com/v1/tracks/6aZJXIkdjjQGZEVOF7suGW',
#   'https://api.spotify.com/v1/audio-analysis/6aZJXIkdjjQGZEVOF7suGW',
#   167800,
#   4],
#  ['Clueso',
#   '37 Grad im Paradies',
#   'spotify:album:5YzSgYPNMpoGhsiJuxsxx1',
#   'Sag Mir Was Du Willst',
#   '2021-09-10',
#   0.752,
#   0.642,
#   5,
#   -5.297,
#   1,
#   0.049,
#   0.364,
#   0,
#   0.269,
#   0.669,
#   95.001,
#   'audio_features',
#   '73Ghkf1A4BnC2L7ia7S18W',
#   'spotify:track:73Ghkf1A4BnC2L7ia7S18W',
#   'https://api.spotify.com/v1/tracks/73Ghkf1A4BnC2L7ia7S18W',
#   'https://api.spotify.com/v1/audio-analysis/73Ghkf1A4BnC2L7ia7S18W',
#   183485,
#   4],
#  ['Clueso',
#   'Willkommen Zurück',
#   'spotify:album:0Qv02wmRha9676ze1Wt20x',
#   'Willkommen Zurück (feat. Andreas Bourani)',
#   '2021-07-01',
#   0.637,
#   0.681,
#   0,
#   -5.049,
#   1,
#   0.228,
#   0.195,
#   6.02e-06,
#   0.157,
#   0.758,
#   98.777,
#   'audio_features',
#   '5KGRq831ZKRYTlptAupEJQ',
#   'spotify:track:5KGRq831ZKRYTlptAupEJQ',
#   'https://api.spotify.com/v1/tracks/5KGRq831ZKRYTlptAupEJQ',
#   'https://api.spotify.com/v1/audio-analysis/5KGRq831ZKRYTlptAupEJQ',
#   149655,
#   4],
#  ['Clueso',
#   'Willkommen Zurück',
#   'spotify:album:0Qv02wmRha9676ze1Wt20x',
#   'Leider Berlin',
#   '2021-07-01',
#   0.731,
#   0.829,
#   7,
#   -4.407,
#   0,
#   0.0299,
#   0.097,
#   1.21e-05,
#   0.218,
#   0.68,
#   119.987,
#   'audio_features',
#   '0OLinqVSoh19VtMz2lQGSG',
#   'spotify:track:0OLinqVSoh19VtMz2lQGSG',
#   'https://api.spotify.com/v1/tracks/0OLinqVSoh19VtMz2lQGSG',
#   'https://api.spotify.com/v1/audio-analysis/0OLinqVSoh19VtMz2lQGSG',
#   192984,
#   4],
#  ['Clueso',
#   'Willkommen Zurück',
#   'spotify:album:0Qv02wmRha9676ze1Wt20x',
#   'Du Warst Immer Dabei',
#   '2021-07-01',
#   0.726,
#   0.533,
#   6,
#   -7.784,
#   1,
#   0.16,
#   0.783,
#   4.73e-05,
#   0.0983,
#   0.538,
#   156.007,
#   'audio_features',
#   '5gwW8EOSHXkXbnM9C7ySMN',
#   'spotify:track:5gwW8EOSHXkXbnM9C7ySMN',
#   'https://api.spotify.com/v1/tracks/5gwW8EOSHXkXbnM9C7ySMN',
#   'https://api.spotify.com/v1/audio-analysis/5gwW8EOSHXkXbnM9C7ySMN',
#   175824,
#   4],
#  ['Clueso',
#   'Willkommen Zurück',
#   'spotify:album:0Qv02wmRha9676ze1Wt20x',
#   'Aber Ohne Dich',
#   '2021-07-01',
#   0.799,
#   0.698,
#   8,
#   -6.632,
#   0,
#   0.161,
#   0.545,
#   7.7e-05,
#   0.103,
#   0.404,
#   98.936,
#   'audio_features',
#   '5ivDDF2O4kmtEnxSiTTG7I',
#   'spotify:track:5ivDDF2O4kmtEnxSiTTG7I',
#   'https://api.spotify.com/v1/tracks/5ivDDF2O4kmtEnxSiTTG7I',
#   'https://api.spotify.com/v1/audio-analysis/5ivDDF2O4kmtEnxSiTTG7I',
#   171964,
#   4],
#  ['Clueso',
#   'Willkommen Zurück',
#   'spotify:album:0Qv02wmRha9676ze1Wt20x',
#   'Flugmodus',
#   '2021-07-01',
#   0.723,
#   0.535,
#   5,
#   -6.273,
#   0,
#   0.0753,
#   0.608,
#   0,
#   0.346,
#   0.707,
#   140.013,
#   'audio_features',
#   '7lVJTrfsxre6hVN160Om7G',
#   'spotify:track:7lVJTrfsxre6hVN160Om7G',
#   'https://api.spotify.com/v1/tracks/7lVJTrfsxre6hVN160Om7G',
#   'https://api.spotify.com/v1/audio-analysis/7lVJTrfsxre6hVN160Om7G',
#   178121,
#   3],
#  ['Clueso',
#   'Willkommen Zurück',
#   'spotify:album:0Qv02wmRha9676ze1Wt20x',
#   'Tanzen',
#   '2021-07-01',
#   0.892,
#   0.5,
#   9,
#   -5.66,
#   0,
#   0.0862,
#   0.303,
#   0,
#   0.0871,
#   0.801,
#   99.019,
#   'audio_features',
#   '1jT9lJ8EmopLTkQtfRZdYa',
#   'spotify:track:1jT9lJ8EmopLTkQtfRZdYa',
#   'https://api.spotify.com/v1/tracks/1jT9lJ8EmopLTkQtfRZdYa',
#   'https://api.spotify.com/v1/audio-analysis/1jT9lJ8EmopLTkQtfRZdYa',
#   167721,
#   4],
#  ['Clueso',
#   'Willkommen Zurück',
#   'spotify:album:0Qv02wmRha9676ze1Wt20x',
#   'Sag Mir Was Du Willst',
#   '2021-07-01',
#   0.747,
#   0.655,
#   5,
#   -5.272,
#   1,
#   0.0486,
#   0.397,
#   0,
#   0.331,
#   0.671,
#   95.011,
#   'audio_features',
#   '1YbpiZyIfmJdpoOWLQjtz0',
#   'spotify:track:1YbpiZyIfmJdpoOWLQjtz0',
#   'https://api.spotify.com/v1/tracks/1YbpiZyIfmJdpoOWLQjtz0',
#   'https://api.spotify.com/v1/audio-analysis/1YbpiZyIfmJdpoOWLQjtz0',
#   183203,
#   4],
#  ['Clueso',
#   'Handgepäck I',
#   'spotify:album:4ckkL9Kjq737Hcuqe4cWAk',
#   'Aufbruch',
#   '2018-08-24',
#   0.269,
#   0.0752,
#   0,
#   -18.738,
#   0,
#   0.0371,
#   0.972,
#   0.717,
#   0.0854,
#   0.0711,
#   115.533,
#   'audio_features',
#   '3XZWMghIitGlHtUJwA3r2E',
#   'spotify:track:3XZWMghIitGlHtUJwA3r2E',
#   'https://api.spotify.com/v1/tracks/3XZWMghIitGlHtUJwA3r2E',
#   'https://api.spotify.com/v1/audio-analysis/3XZWMghIitGlHtUJwA3r2E',
#   68521,
#   4],
#  ['Clueso',
#   'Handgepäck I',
#   'spotify:album:4ckkL9Kjq737Hcuqe4cWAk',
#   'Wie versprochen',
#   '2018-08-24',
#   0.676,
#   0.495,
#   5,
#   -7.535,
#   1,
#   0.0253,
#   0.317,
#   0.000309,
#   0.0514,
#   0.433,
#   134.955,
#   'audio_features',
#   '3KQ8BI3qEGlze3ToDNIfJ9',
#   'spotify:track:3KQ8BI3qEGlze3ToDNIfJ9',
#   'https://api.spotify.com/v1/tracks/3KQ8BI3qEGlze3ToDNIfJ9',
#   'https://api.spotify.com/v1/audio-analysis/3KQ8BI3qEGlze3ToDNIfJ9',
#   224371,
#   4],
#  ['Clueso',
#   'Handgepäck I',
#   'spotify:album:4ckkL9Kjq737Hcuqe4cWAk',
#   'Vier Jahreszeiten an einem Tag',
#   '2018-08-24',
#   0.607,
#   0.464,
#   9,
#   -7.407,
#   1,
#   0.0315,
#   0.764,
#   1.56e-05,
#   0.131,
#   0.509,
#   178.167,
#   'audio_features',
#   '0T3pLdXFA2rAeEgac5UF7V',
#   'spotify:track:0T3pLdXFA2rAeEgac5UF7V',
#   'https://api.spotify.com/v1/tracks/0T3pLdXFA2rAeEgac5UF7V',
#   'https://api.spotify.com/v1/audio-analysis/0T3pLdXFA2rAeEgac5UF7V',
#   171668,
#   4],
#  ['Clueso',
#   'Handgepäck I',
#   'spotify:album:4ckkL9Kjq737Hcuqe4cWAk',
#   'Waldrandlichter',
#   '2018-08-24',
#   0.607,
#   0.622,
#   11,
#   -9.0,
#   0,
#   0.0281,
#   0.857,
#   8.32e-05,
#   0.11,
#   0.548,
#   93.499,
#   'audio_features',
#   '67M3Utyfsfqr1Lt4LbQ7rO',
#   'spotify:track:67M3Utyfsfqr1Lt4LbQ7rO',
#   'https://api.spotify.com/v1/tracks/67M3Utyfsfqr1Lt4LbQ7rO',
#   'https://api.spotify.com/v1/audio-analysis/67M3Utyfsfqr1Lt4LbQ7rO',
#   198690,
#   4],
#  ['Clueso',
#   'Handgepäck I',
#   'spotify:album:4ckkL9Kjq737Hcuqe4cWAk',
#   'Stein',
#   '2018-08-24',
#   0.437,
#   0.282,
#   2,
#   -12.727,
#   1,
#   0.0362,
#   0.806,
#   0.00494,
#   0.138,
#   0.223,
#   135.125,
#   'audio_features',
#   '60ryw9Wiww7gjS1RQSOyVS',
#   'spotify:track:60ryw9Wiww7gjS1RQSOyVS',
#   'https://api.spotify.com/v1/tracks/60ryw9Wiww7gjS1RQSOyVS',
#   'https://api.spotify.com/v1/audio-analysis/60ryw9Wiww7gjS1RQSOyVS',
#   160041,
#   5],
#  ['Clueso',
#   'Handgepäck I',
#   'spotify:album:4ckkL9Kjq737Hcuqe4cWAk',
#   'Einfache Fahrt',
#   '2018-08-24',
#   0.598,
#   0.429,
#   4,
#   -11.155,
#   0,
#   0.0398,
#   0.682,
#   0.00946,
#   0.127,
#   0.378,
#   79.941,
#   'audio_features',
#   '2o5AYC0Ftxh5Mlx4P26UNk',
#   'spotify:track:2o5AYC0Ftxh5Mlx4P26UNk',
#   'https://api.spotify.com/v1/tracks/2o5AYC0Ftxh5Mlx4P26UNk',
#   'https://api.spotify.com/v1/audio-analysis/2o5AYC0Ftxh5Mlx4P26UNk',
#   191984,
#   4],
#  ['Clueso',
#   'Handgepäck I',
#   'spotify:album:4ckkL9Kjq737Hcuqe4cWAk',
#   'Zwischenstopp',
#   '2018-08-24',
#   0.502,
#   0.423,
#   11,
#   -8.892,
#   0,
#   0.0453,
#   0.756,
#   0.28,
#   0.345,
#   0.558,
#   172.457,
#   'audio_features',
#   '1ooP7Sxy5Ao6QtyHbbTHVC',
#   'spotify:track:1ooP7Sxy5Ao6QtyHbbTHVC',
#   'https://api.spotify.com/v1/tracks/1ooP7Sxy5Ao6QtyHbbTHVC',
#   'https://api.spotify.com/v1/audio-analysis/1ooP7Sxy5Ao6QtyHbbTHVC',
#   90413,
#   3],
#  ['Clueso',
#   'Handgepäck I',
#   'spotify:album:4ckkL9Kjq737Hcuqe4cWAk',
#   'Du und Ich',
#   '2018-08-24',
#   0.869,
#   0.652,
#   7,
#   -7.375,
#   1,
#   0.0506,
#   0.731,
#   7.79e-05,
#   0.267,
#   0.871,
#   101.982,
#   'audio_features',
#   '6nFHXIv0gt2zFmzhgD8W24',
#   'spotify:track:6nFHXIv0gt2zFmzhgD8W24',
#   'https://api.spotify.com/v1/tracks/6nFHXIv0gt2zFmzhgD8W24',
#   'https://api.spotify.com/v1/audio-analysis/6nFHXIv0gt2zFmzhgD8W24',
#   193483,
#   3],
#  ['Clueso',
#   'Handgepäck I',
#   'spotify:album:4ckkL9Kjq737Hcuqe4cWAk',
#   'Wenn ein Mensch lebt',
#   '2018-08-24',
#   0.391,
#   0.229,
#   1,
#   -10.616,
#   0,
#   0.0323,
#   0.937,
#   0.0227,
#   0.115,
#   0.223,
#   173.53,
#   'audio_features',
#   '6Q2oUl9Xy7JJpX6rS1fD0D',
#   'spotify:track:6Q2oUl9Xy7JJpX6rS1fD0D',
#   'https://api.spotify.com/v1/tracks/6Q2oUl9Xy7JJpX6rS1fD0D',
#   'https://api.spotify.com/v1/audio-analysis/6Q2oUl9Xy7JJpX6rS1fD0D',
#   187079,
#   3],
#  ['Clueso',
#   'Handgepäck I',
#   'spotify:album:4ckkL9Kjq737Hcuqe4cWAk',
#   'Wüste',
#   '2018-08-24',
#   0.587,
#   0.343,
#   3,
#   -12.844,
#   1,
#   0.0341,
#   0.811,
#   0.43,
#   0.155,
#   0.323,
#   97.804,
#   'audio_features',
#   '6pqKQQ8X9VRo3Z9DmbEUu5',
#   'spotify:track:6pqKQQ8X9VRo3Z9DmbEUu5',
#   'https://api.spotify.com/v1/tracks/6pqKQQ8X9VRo3Z9DmbEUu5',
#   'https://api.spotify.com/v1/audio-analysis/6pqKQQ8X9VRo3Z9DmbEUu5',
#   120161,
#   4],
#  ['Clueso',
#   'Handgepäck I',
#   'spotify:album:4ckkL9Kjq737Hcuqe4cWAk',
#   'Landstreicher',
#   '2018-08-24',
#   0.706,
#   0.336,
#   5,
#   -12.059,
#   1,
#   0.0574,
#   0.852,
#   0.000851,
#   0.102,
#   0.672,
#   131.334,
#   'audio_features',
#   '04ucdFQC8SiTL03VLLY4aN',
#   'spotify:track:04ucdFQC8SiTL03VLLY4aN',
#   'https://api.spotify.com/v1/tracks/04ucdFQC8SiTL03VLLY4aN',
#   'https://api.spotify.com/v1/audio-analysis/04ucdFQC8SiTL03VLLY4aN',
#   87429,
#   4],
#  ['Clueso',
#   'Handgepäck I',
#   'spotify:album:4ckkL9Kjq737Hcuqe4cWAk',
#   'Zimmer 102',
#   '2018-08-24',
#   0.718,
#   0.448,
#   7,
#   -8.291,
#   1,
#   0.0309,
#   0.505,
#   0.000549,
#   0.543,
#   0.334,
#   115.575,
#   'audio_features',
#   '7b66UZej5UDsSP6c6XlsBu',
#   'spotify:track:7b66UZej5UDsSP6c6XlsBu',
#   'https://api.spotify.com/v1/tracks/7b66UZej5UDsSP6c6XlsBu',
#   'https://api.spotify.com/v1/audio-analysis/7b66UZej5UDsSP6c6XlsBu',
#   247488,
#   4],
#  ['Clueso',
#   'Handgepäck I',
#   'spotify:album:4ckkL9Kjq737Hcuqe4cWAk',
#   'Kurz vor Abflug',
#   '2018-08-24',
#   0.635,
#   0.433,
#   0,
#   -9.118,
#   1,
#   0.0343,
#   0.665,
#   0.165,
#   0.248,
#   0.341,
#   118.059,
#   'audio_features',
#   '0cyDQvbJ4m1A3BGj8NpMCV',
#   'spotify:track:0cyDQvbJ4m1A3BGj8NpMCV',
#   'https://api.spotify.com/v1/tracks/0cyDQvbJ4m1A3BGj8NpMCV',
#   'https://api.spotify.com/v1/audio-analysis/0cyDQvbJ4m1A3BGj8NpMCV',
#   242372,
#   4],
#  ['Clueso',
#   'Handgepäck I',
#   'spotify:album:4ckkL9Kjq737Hcuqe4cWAk',
#   'Auf Kredit',
#   '2018-08-24',
#   0.467,
#   0.281,
#   7,
#   -10.059,
#   1,
#   0.0297,
#   0.888,
#   0.000447,
#   0.129,
#   0.117,
#   95.78,
#   'audio_features',
#   '6ILMRfi8OpnqUQSFLMQFe5',
#   'spotify:track:6ILMRfi8OpnqUQSFLMQFe5',
#   'https://api.spotify.com/v1/tracks/6ILMRfi8OpnqUQSFLMQFe5',
#   'https://api.spotify.com/v1/audio-analysis/6ILMRfi8OpnqUQSFLMQFe5',
#   267784,
#   4],
#  ['Clueso',
#   'Handgepäck I',
#   'spotify:album:4ckkL9Kjq737Hcuqe4cWAk',
#   'Es ist schon spät',
#   '2018-08-24',
#   0.588,
#   0.301,
#   2,
#   -11.158,
#   0,
#   0.0332,
#   0.903,
#   0.000302,
#   0.128,
#   0.149,
#   143.971,
#   'audio_features',
#   '5GdBeXjAd4ThCZ5Af7vCF8',
#   'spotify:track:5GdBeXjAd4ThCZ5Af7vCF8',
#   'https://api.spotify.com/v1/tracks/5GdBeXjAd4ThCZ5Af7vCF8',
#   'https://api.spotify.com/v1/audio-analysis/5GdBeXjAd4ThCZ5Af7vCF8',
#   124523,
#   4],
#  ['Clueso',
#   'Handgepäck I',
#   'spotify:album:4ckkL9Kjq737Hcuqe4cWAk',
#   'Dünnes Eis',
#   '2018-08-24',
#   0.762,
#   0.288,
#   2,
#   -11.151,
#   1,
#   0.0391,
#   0.894,
#   0.00182,
#   0.452,
#   0.455,
#   96.007,
#   'audio_features',
#   '76J91m1FHx4CB7OdpojRS2',
#   'spotify:track:76J91m1FHx4CB7OdpojRS2',
#   'https://api.spotify.com/v1/tracks/76J91m1FHx4CB7OdpojRS2',
#   'https://api.spotify.com/v1/audio-analysis/76J91m1FHx4CB7OdpojRS2',
#   211069,
#   4],
#  ['Clueso',
#   'Handgepäck I',
#   'spotify:album:4ckkL9Kjq737Hcuqe4cWAk',
#   'Morgen ist der Winter vorbei',
#   '2018-08-24',
#   0.656,
#   0.226,
#   7,
#   -9.409,
#   1,
#   0.0348,
#   0.922,
#   0.000734,
#   0.25,
#   0.318,
#   116.142,
#   'audio_features',
#   '29thuGn0x3LYzNrF7ju23B',
#   'spotify:track:29thuGn0x3LYzNrF7ju23B',
#   'https://api.spotify.com/v1/tracks/29thuGn0x3LYzNrF7ju23B',
#   'https://api.spotify.com/v1/audio-analysis/29thuGn0x3LYzNrF7ju23B',
#   199529,
#   4],
#  ['Clueso',
#   'Handgepäck I',
#   'spotify:album:4ckkL9Kjq737Hcuqe4cWAk',
#   'Paris',
#   '2018-08-24',
#   0.404,
#   0.268,
#   5,
#   -9.977,
#   0,
#   0.0361,
#   0.941,
#   7.58e-05,
#   0.868,
#   0.567,
#   155.568,
#   'audio_features',
#   '6YWZysg2Ua4Ah7MtuVB1sR',
#   'spotify:track:6YWZysg2Ua4Ah7MtuVB1sR',
#   'https://api.spotify.com/v1/tracks/6YWZysg2Ua4Ah7MtuVB1sR',
#   'https://api.spotify.com/v1/audio-analysis/6YWZysg2Ua4Ah7MtuVB1sR',
#   263646,
#   3],
#  ['Clueso',
#   'Neuanfang',
#   'spotify:album:6W2dRaTI0N8DxxcK4BrUcH',
#   'Neuanfang',
#   '2016-10-14',
#   0.655,
#   0.657,
#   7,
#   -6.399,
#   1,
#   0.0362,
#   0.0129,
#   6.07e-06,
#   0.326,
#   0.658,
#   128.005,
#   'audio_features',
#   '3uuCSRW0BOayXKGN3N8PNQ',
#   'spotify:track:3uuCSRW0BOayXKGN3N8PNQ',
#   'https://api.spotify.com/v1/tracks/3uuCSRW0BOayXKGN3N8PNQ',
#   'https://api.spotify.com/v1/audio-analysis/3uuCSRW0BOayXKGN3N8PNQ',
#   186160,
#   4],
#  ['Clueso',
#   'Neuanfang',
#   'spotify:album:6W2dRaTI0N8DxxcK4BrUcH',
#   'Achterbahn',
#   '2016-10-14',
#   0.785,
#   0.866,
#   4,
#   -5.376,
#   0,
#   0.0478,
#   0.153,
#   0,
#   0.0694,
#   0.827,
#   122.748,
#   'audio_features',
#   '1DS3d4C8LjzlQhwzOFq8bI',
#   'spotify:track:1DS3d4C8LjzlQhwzOFq8bI',
#   'https://api.spotify.com/v1/tracks/1DS3d4C8LjzlQhwzOFq8bI',
#   'https://api.spotify.com/v1/audio-analysis/1DS3d4C8LjzlQhwzOFq8bI',
#   210960,
#   4],
#  ['Clueso',
#   'Neuanfang',
#   'spotify:album:6W2dRaTI0N8DxxcK4BrUcH',
#   'Neue Luft',
#   '2016-10-14',
#   0.657,
#   0.42,
#   2,
#   -8.492,
#   0,
#   0.028,
#   0.545,
#   4.81e-05,
#   0.0691,
#   0.451,
#   77.982,
#   'audio_features',
#   '0W7vSUiPbRjuG4L5sHD8V8',
#   'spotify:track:0W7vSUiPbRjuG4L5sHD8V8',
#   'https://api.spotify.com/v1/tracks/0W7vSUiPbRjuG4L5sHD8V8',
#   'https://api.spotify.com/v1/audio-analysis/0W7vSUiPbRjuG4L5sHD8V8',
#   255667,
#   4],
#  ['Clueso',
#   'Neuanfang',
#   'spotify:album:6W2dRaTI0N8DxxcK4BrUcH',
#   'Erinnerungen',
#   '2016-10-14',
#   0.634,
#   0.789,
#   5,
#   -7.86,
#   0,
#   0.0408,
#   0.25,
#   0.00187,
#   0.1,
#   0.538,
#   89.006,
#   'audio_features',
#   '0bv4WfoKr5rWs9V2GxuaOW',
#   'spotify:track:0bv4WfoKr5rWs9V2GxuaOW',
#   'https://api.spotify.com/v1/tracks/0bv4WfoKr5rWs9V2GxuaOW',
#   'https://api.spotify.com/v1/audio-analysis/0bv4WfoKr5rWs9V2GxuaOW',
#   283920,
#   4],
#  ['Clueso',
#   'Neuanfang',
#   'spotify:album:6W2dRaTI0N8DxxcK4BrUcH',
#   'Wenn du liebst',
#   '2016-10-14',
#   0.702,
#   0.32,
#   7,
#   -10.407,
#   0,
#   0.0293,
#   0.836,
#   9.05e-05,
#   0.204,
#   0.489,
#   89.008,
#   'audio_features',
#   '7Cucc60UNVCKSYcdfIPFKe',
#   'spotify:track:7Cucc60UNVCKSYcdfIPFKe',
#   'https://api.spotify.com/v1/tracks/7Cucc60UNVCKSYcdfIPFKe',
#   'https://api.spotify.com/v1/audio-analysis/7Cucc60UNVCKSYcdfIPFKe',
#   242960,
#   4],
#  ['Clueso',
#   'Neuanfang',
#   'spotify:album:6W2dRaTI0N8DxxcK4BrUcH',
#   'Lass sie reden',
#   '2016-10-14',
#   0.77,
#   0.618,
#   1,
#   -7.442,
#   1,
#   0.0305,
#   0.661,
#   0.00298,
#   0.171,
#   0.849,
#   127.979,
#   'audio_features',
#   '1jw4ePqfqpbEl2vp0buzua',
#   'spotify:track:1jw4ePqfqpbEl2vp0buzua',
#   'https://api.spotify.com/v1/tracks/1jw4ePqfqpbEl2vp0buzua',
#   'https://api.spotify.com/v1/audio-analysis/1jw4ePqfqpbEl2vp0buzua',
#   249453,
#   4],
#  ['Clueso',
#   'Neuanfang',
#   'spotify:album:6W2dRaTI0N8DxxcK4BrUcH',
#   'Anderssein',
#   '2016-10-14',
#   0.684,
#   0.833,
#   4,
#   -5.628,
#   0,
#   0.0734,
#   0.221,
#   7.26e-05,
#   0.0965,
#   0.961,
#   155.96,
#   'audio_features',
#   '0BzFRWu9GSWZM0v6Zpij2k',
#   'spotify:track:0BzFRWu9GSWZM0v6Zpij2k',
#   'https://api.spotify.com/v1/tracks/0BzFRWu9GSWZM0v6Zpij2k',
#   'https://api.spotify.com/v1/audio-analysis/0BzFRWu9GSWZM0v6Zpij2k',
#   208827,
#   4],
#  ['Clueso',
#   'Neuanfang',
#   'spotify:album:6W2dRaTI0N8DxxcK4BrUcH',
#   'Gordo',
#   '2016-10-14',
#   0.745,
#   0.68,
#   7,
#   -8.129,
#   1,
#   0.038,
#   0.164,
#   0.000395,
#   0.087,
#   0.512,
#   124.013,
#   'audio_features',
#   '0KxGzAqya13zjGe5BVN3pH',
#   'spotify:track:0KxGzAqya13zjGe5BVN3pH',
#   'https://api.spotify.com/v1/tracks/0KxGzAqya13zjGe5BVN3pH',
#   'https://api.spotify.com/v1/audio-analysis/0KxGzAqya13zjGe5BVN3pH',
#   270987,
#   4],
#  ['Clueso',
#   'Neuanfang',
#   'spotify:album:6W2dRaTI0N8DxxcK4BrUcH',
#   'Jeder lebt für sich allein',
#   '2016-10-14',
#   0.597,
#   0.393,
#   8,
#   -9.903,
#   1,
#   0.0438,
#   0.805,
#   0.00795,
#   0.105,
#   0.478,
#   80.989,
#   'audio_features',
#   '1RwZN2WVjGFZu4r7KqPsGn',
#   'spotify:track:1RwZN2WVjGFZu4r7KqPsGn',
#   'https://api.spotify.com/v1/tracks/1RwZN2WVjGFZu4r7KqPsGn',
#   'https://api.spotify.com/v1/audio-analysis/1RwZN2WVjGFZu4r7KqPsGn',
#   238253,
#   4],
#  ['Clueso',
#   'Neuanfang',
#   'spotify:album:6W2dRaTI0N8DxxcK4BrUcH',
#   'Sorgenfrei',
#   '2016-10-14',
#   0.589,
#   0.385,
#   4,
#   -11.184,
#   1,
#   0.0302,
#   0.709,
#   0.00117,
#   0.13,
#   0.217,
#   128.531,
#   'audio_features',
#   '6DqA4oFoJ6QJbfPfo1tf4J',
#   'spotify:track:6DqA4oFoJ6QJbfPfo1tf4J',
#   'https://api.spotify.com/v1/tracks/6DqA4oFoJ6QJbfPfo1tf4J',
#   'https://api.spotify.com/v1/audio-analysis/6DqA4oFoJ6QJbfPfo1tf4J',
#   277400,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Neuanfang',
#   '2016-10-14',
#   0.655,
#   0.657,
#   7,
#   -6.399,
#   1,
#   0.0362,
#   0.0129,
#   6.07e-06,
#   0.326,
#   0.658,
#   128.004,
#   'audio_features',
#   '3qjEqVfDNa0SG2rB5C4bD3',
#   'spotify:track:3qjEqVfDNa0SG2rB5C4bD3',
#   'https://api.spotify.com/v1/tracks/3qjEqVfDNa0SG2rB5C4bD3',
#   'https://api.spotify.com/v1/audio-analysis/3qjEqVfDNa0SG2rB5C4bD3',
#   186160,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Achterbahn',
#   '2016-10-14',
#   0.785,
#   0.866,
#   4,
#   -5.376,
#   0,
#   0.0478,
#   0.153,
#   0,
#   0.0694,
#   0.827,
#   122.748,
#   'audio_features',
#   '0sBupXuHJjIM5Rbd92XqpP',
#   'spotify:track:0sBupXuHJjIM5Rbd92XqpP',
#   'https://api.spotify.com/v1/tracks/0sBupXuHJjIM5Rbd92XqpP',
#   'https://api.spotify.com/v1/audio-analysis/0sBupXuHJjIM5Rbd92XqpP',
#   210960,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Neue Luft',
#   '2016-10-14',
#   0.657,
#   0.42,
#   2,
#   -8.492,
#   0,
#   0.028,
#   0.545,
#   4.81e-05,
#   0.0691,
#   0.451,
#   77.982,
#   'audio_features',
#   '0K6viJLs6otu6WO2tMUFaI',
#   'spotify:track:0K6viJLs6otu6WO2tMUFaI',
#   'https://api.spotify.com/v1/tracks/0K6viJLs6otu6WO2tMUFaI',
#   'https://api.spotify.com/v1/audio-analysis/0K6viJLs6otu6WO2tMUFaI',
#   255667,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Erinnerungen',
#   '2016-10-14',
#   0.634,
#   0.789,
#   5,
#   -7.86,
#   0,
#   0.0408,
#   0.25,
#   0.00187,
#   0.1,
#   0.538,
#   89.006,
#   'audio_features',
#   '3RAulNjMXLeHzLIWlbI1AW',
#   'spotify:track:3RAulNjMXLeHzLIWlbI1AW',
#   'https://api.spotify.com/v1/tracks/3RAulNjMXLeHzLIWlbI1AW',
#   'https://api.spotify.com/v1/audio-analysis/3RAulNjMXLeHzLIWlbI1AW',
#   283920,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Wenn du liebst',
#   '2016-10-14',
#   0.702,
#   0.32,
#   7,
#   -10.407,
#   0,
#   0.0293,
#   0.836,
#   9.05e-05,
#   0.204,
#   0.489,
#   89.008,
#   'audio_features',
#   '2IaGmp8wx4UhBfePhVvNH7',
#   'spotify:track:2IaGmp8wx4UhBfePhVvNH7',
#   'https://api.spotify.com/v1/tracks/2IaGmp8wx4UhBfePhVvNH7',
#   'https://api.spotify.com/v1/audio-analysis/2IaGmp8wx4UhBfePhVvNH7',
#   242960,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Lass sie reden',
#   '2016-10-14',
#   0.77,
#   0.618,
#   1,
#   -7.442,
#   1,
#   0.0305,
#   0.661,
#   0.00298,
#   0.171,
#   0.849,
#   127.979,
#   'audio_features',
#   '41PYMpQOyhRumnOyUrXcxu',
#   'spotify:track:41PYMpQOyhRumnOyUrXcxu',
#   'https://api.spotify.com/v1/tracks/41PYMpQOyhRumnOyUrXcxu',
#   'https://api.spotify.com/v1/audio-analysis/41PYMpQOyhRumnOyUrXcxu',
#   249453,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Anderssein',
#   '2016-10-14',
#   0.684,
#   0.833,
#   4,
#   -5.628,
#   0,
#   0.0734,
#   0.221,
#   7.26e-05,
#   0.0965,
#   0.961,
#   155.96,
#   'audio_features',
#   '4RawXjQ37X595aJu6CdTDv',
#   'spotify:track:4RawXjQ37X595aJu6CdTDv',
#   'https://api.spotify.com/v1/tracks/4RawXjQ37X595aJu6CdTDv',
#   'https://api.spotify.com/v1/audio-analysis/4RawXjQ37X595aJu6CdTDv',
#   208827,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Gordo',
#   '2016-10-14',
#   0.745,
#   0.68,
#   7,
#   -8.129,
#   1,
#   0.038,
#   0.164,
#   0.000395,
#   0.087,
#   0.512,
#   124.013,
#   'audio_features',
#   '2GGvAAL18HqKb6xRO8HMtp',
#   'spotify:track:2GGvAAL18HqKb6xRO8HMtp',
#   'https://api.spotify.com/v1/tracks/2GGvAAL18HqKb6xRO8HMtp',
#   'https://api.spotify.com/v1/audio-analysis/2GGvAAL18HqKb6xRO8HMtp',
#   270987,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Jeder lebt für sich allein',
#   '2016-10-14',
#   0.597,
#   0.393,
#   8,
#   -9.903,
#   1,
#   0.0439,
#   0.805,
#   0.00795,
#   0.105,
#   0.478,
#   80.989,
#   'audio_features',
#   '6UMJaXRbdPxwUNI4m2uGAS',
#   'spotify:track:6UMJaXRbdPxwUNI4m2uGAS',
#   'https://api.spotify.com/v1/tracks/6UMJaXRbdPxwUNI4m2uGAS',
#   'https://api.spotify.com/v1/audio-analysis/6UMJaXRbdPxwUNI4m2uGAS',
#   238253,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Sorgenfrei',
#   '2016-10-14',
#   0.589,
#   0.385,
#   4,
#   -11.184,
#   1,
#   0.0302,
#   0.709,
#   0.00117,
#   0.13,
#   0.217,
#   128.531,
#   'audio_features',
#   '5ujqyXp0wnTPePO4rtGLLP',
#   'spotify:track:5ujqyXp0wnTPePO4rtGLLP',
#   'https://api.spotify.com/v1/tracks/5ujqyXp0wnTPePO4rtGLLP',
#   'https://api.spotify.com/v1/audio-analysis/5ujqyXp0wnTPePO4rtGLLP',
#   277400,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Neuanfang - Tilmann Jarmer Remix',
#   '2016-10-14',
#   0.685,
#   0.544,
#   2,
#   -9.552,
#   1,
#   0.202,
#   0.517,
#   0,
#   0.117,
#   0.244,
#   127.83,
#   'audio_features',
#   '10RvtyYIZ9jT3IvIf22Tne',
#   'spotify:track:10RvtyYIZ9jT3IvIf22Tne',
#   'https://api.spotify.com/v1/tracks/10RvtyYIZ9jT3IvIf22Tne',
#   'https://api.spotify.com/v1/audio-analysis/10RvtyYIZ9jT3IvIf22Tne',
#   161653,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Neue Luft - Grunert Remix',
#   '2016-10-14',
#   0.406,
#   0.196,
#   2,
#   -15.202,
#   0,
#   0.0357,
#   0.903,
#   3.71e-05,
#   0.0937,
#   0.195,
#   156.066,
#   'audio_features',
#   '2P8VEVUwqWM4moUKZLz5P7',
#   'spotify:track:2P8VEVUwqWM4moUKZLz5P7',
#   'https://api.spotify.com/v1/tracks/2P8VEVUwqWM4moUKZLz5P7',
#   'https://api.spotify.com/v1/audio-analysis/2P8VEVUwqWM4moUKZLz5P7',
#   304920,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Erinnerungen - tim neuhaus & f i s c h e r Remix',
#   '2016-10-14',
#   0.253,
#   0.45,
#   5,
#   -10.502,
#   0,
#   0.0542,
#   0.512,
#   7.87e-05,
#   0.118,
#   0.141,
#   178.195,
#   'audio_features',
#   '3Mw1adeA9goI0IpDjYSptE',
#   'spotify:track:3Mw1adeA9goI0IpDjYSptE',
#   'https://api.spotify.com/v1/tracks/3Mw1adeA9goI0IpDjYSptE',
#   'https://api.spotify.com/v1/audio-analysis/3Mw1adeA9goI0IpDjYSptE',
#   314573,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Anderssein - Egotron Remix',
#   '2016-10-14',
#   0.606,
#   0.661,
#   2,
#   -8.352,
#   1,
#   0.0579,
#   0.0348,
#   0.000654,
#   0.305,
#   0.187,
#   77.956,
#   'audio_features',
#   '2BozZq12Tfb0CLewD3zoF6',
#   'spotify:track:2BozZq12Tfb0CLewD3zoF6',
#   'https://api.spotify.com/v1/tracks/2BozZq12Tfb0CLewD3zoF6',
#   'https://api.spotify.com/v1/audio-analysis/2BozZq12Tfb0CLewD3zoF6',
#   208827,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Jeder lebt für sich allein - Clueso & DJ Beathova Remix',
#   '2016-10-14',
#   0.657,
#   0.532,
#   1,
#   -9.955,
#   1,
#   0.0826,
#   0.43,
#   0.00555,
#   0.114,
#   0.283,
#   162.035,
#   'audio_features',
#   '4QeQmsklziiQPGqoBqfJjz',
#   'spotify:track:4QeQmsklziiQPGqoBqfJjz',
#   'https://api.spotify.com/v1/tracks/4QeQmsklziiQPGqoBqfJjz',
#   'https://api.spotify.com/v1/audio-analysis/4QeQmsklziiQPGqoBqfJjz',
#   242693,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Achterbahn - Handgepäck Version',
#   '2016-10-14',
#   0.673,
#   0.529,
#   7,
#   -11.514,
#   1,
#   0.0409,
#   0.75,
#   0.000374,
#   0.353,
#   0.559,
#   115.518,
#   'audio_features',
#   '17cccNlFqOyiVbRTKh0vYY',
#   'spotify:track:17cccNlFqOyiVbRTKh0vYY',
#   'https://api.spotify.com/v1/tracks/17cccNlFqOyiVbRTKh0vYY',
#   'https://api.spotify.com/v1/audio-analysis/17cccNlFqOyiVbRTKh0vYY',
#   203347,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Anderssein - Akustik Version',
#   '2016-10-14',
#   0.685,
#   0.753,
#   7,
#   -7.951,
#   1,
#   0.048,
#   0.755,
#   0,
#   0.344,
#   0.963,
#   155.991,
#   'audio_features',
#   '6quAyTNlmoJsiisgMgyAMF',
#   'spotify:track:6quAyTNlmoJsiisgMgyAMF',
#   'https://api.spotify.com/v1/tracks/6quAyTNlmoJsiisgMgyAMF',
#   'https://api.spotify.com/v1/audio-analysis/6quAyTNlmoJsiisgMgyAMF',
#   194907,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Neuanfang - Demo 2015',
#   '2016-10-14',
#   0.363,
#   0.498,
#   2,
#   -7.738,
#   1,
#   0.0809,
#   0.0951,
#   0,
#   0.384,
#   0.543,
#   128.053,
#   'audio_features',
#   '0BivKBTTz5FbjmVGxsfa9Z',
#   'spotify:track:0BivKBTTz5FbjmVGxsfa9Z',
#   'https://api.spotify.com/v1/tracks/0BivKBTTz5FbjmVGxsfa9Z',
#   'https://api.spotify.com/v1/audio-analysis/0BivKBTTz5FbjmVGxsfa9Z',
#   185853,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Gordo - Demo 2015',
#   '2016-10-14',
#   0.827,
#   0.562,
#   7,
#   -8.394,
#   0,
#   0.0523,
#   0.218,
#   0.00678,
#   0.104,
#   0.725,
#   124.003,
#   'audio_features',
#   '6XpKk9IO5FL7jjq3frIWKy',
#   'spotify:track:6XpKk9IO5FL7jjq3frIWKy',
#   'https://api.spotify.com/v1/tracks/6XpKk9IO5FL7jjq3frIWKy',
#   'https://api.spotify.com/v1/audio-analysis/6XpKk9IO5FL7jjq3frIWKy',
#   276200,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Neuanfang - Instrumental',
#   '2016-10-14',
#   0.74,
#   0.482,
#   7,
#   -7.544,
#   1,
#   0.0365,
#   0.000399,
#   0.803,
#   0.171,
#   0.573,
#   127.978,
#   'audio_features',
#   '7u9ZPt777EwPNUwmRVmOr8',
#   'spotify:track:7u9ZPt777EwPNUwmRVmOr8',
#   'https://api.spotify.com/v1/tracks/7u9ZPt777EwPNUwmRVmOr8',
#   'https://api.spotify.com/v1/audio-analysis/7u9ZPt777EwPNUwmRVmOr8',
#   186160,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Achterbahn - Instrumental',
#   '2016-10-14',
#   0.895,
#   0.778,
#   2,
#   -6.798,
#   1,
#   0.041,
#   0.00251,
#   0.853,
#   0.0651,
#   0.797,
#   122.749,
#   'audio_features',
#   '1wSLG9nXCBVzXeuXvsQqk9',
#   'spotify:track:1wSLG9nXCBVzXeuXvsQqk9',
#   'https://api.spotify.com/v1/tracks/1wSLG9nXCBVzXeuXvsQqk9',
#   'https://api.spotify.com/v1/audio-analysis/1wSLG9nXCBVzXeuXvsQqk9',
#   210960,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Neue Luft - Instrumental',
#   '2016-10-14',
#   0.684,
#   0.367,
#   2,
#   -8.703,
#   0,
#   0.026,
#   0.188,
#   0.805,
#   0.0743,
#   0.386,
#   77.989,
#   'audio_features',
#   '7lnpAx5uzgW6c7d1re7p4C',
#   'spotify:track:7lnpAx5uzgW6c7d1re7p4C',
#   'https://api.spotify.com/v1/tracks/7lnpAx5uzgW6c7d1re7p4C',
#   'https://api.spotify.com/v1/audio-analysis/7lnpAx5uzgW6c7d1re7p4C',
#   255560,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Erinnerungen - Instrumental',
#   '2016-10-14',
#   0.639,
#   0.855,
#   5,
#   -10.26,
#   0,
#   0.0309,
#   0.0689,
#   0.846,
#   0.107,
#   0.368,
#   89.002,
#   'audio_features',
#   '4h1QXxuWOeqqCFzibom8mk',
#   'spotify:track:4h1QXxuWOeqqCFzibom8mk',
#   'https://api.spotify.com/v1/tracks/4h1QXxuWOeqqCFzibom8mk',
#   'https://api.spotify.com/v1/audio-analysis/4h1QXxuWOeqqCFzibom8mk',
#   284027,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Wenn du liebst - Instrumental',
#   '2016-10-14',
#   0.643,
#   0.274,
#   7,
#   -12.149,
#   0,
#   0.0526,
#   0.838,
#   0.905,
#   0.206,
#   0.213,
#   177.94,
#   'audio_features',
#   '5vN7tUxHkupZmabDZFCXFn',
#   'spotify:track:5vN7tUxHkupZmabDZFCXFn',
#   'https://api.spotify.com/v1/tracks/5vN7tUxHkupZmabDZFCXFn',
#   'https://api.spotify.com/v1/audio-analysis/5vN7tUxHkupZmabDZFCXFn',
#   242960,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Lass sie reden - Instrumental',
#   '2016-10-14',
#   0.77,
#   0.609,
#   1,
#   -7.775,
#   1,
#   0.0397,
#   0.438,
#   0.8,
#   0.287,
#   0.85,
#   128.021,
#   'audio_features',
#   '1ccjfIGNCA5dMO5ZVVTFKv',
#   'spotify:track:1ccjfIGNCA5dMO5ZVVTFKv',
#   'https://api.spotify.com/v1/tracks/1ccjfIGNCA5dMO5ZVVTFKv',
#   'https://api.spotify.com/v1/audio-analysis/1ccjfIGNCA5dMO5ZVVTFKv',
#   249453,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Anderssein - Instrumental',
#   '2016-10-14',
#   0.764,
#   0.777,
#   4,
#   -6.837,
#   0,
#   0.0647,
#   0.0208,
#   0.81,
#   0.0861,
#   0.93,
#   156.035,
#   'audio_features',
#   '18fOB56quKrYvL3F9iBbzX',
#   'spotify:track:18fOB56quKrYvL3F9iBbzX',
#   'https://api.spotify.com/v1/tracks/18fOB56quKrYvL3F9iBbzX',
#   'https://api.spotify.com/v1/audio-analysis/18fOB56quKrYvL3F9iBbzX',
#   208827,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Gordo - Instrumental',
#   '2016-10-14',
#   0.781,
#   0.612,
#   7,
#   -10.265,
#   1,
#   0.0309,
#   0.0296,
#   0.779,
#   0.0898,
#   0.551,
#   123.989,
#   'audio_features',
#   '3k1ZaVT7bjx1TQ59UH82mt',
#   'spotify:track:3k1ZaVT7bjx1TQ59UH82mt',
#   'https://api.spotify.com/v1/tracks/3k1ZaVT7bjx1TQ59UH82mt',
#   'https://api.spotify.com/v1/audio-analysis/3k1ZaVT7bjx1TQ59UH82mt',
#   270987,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Jeder lebt für sich allein - Instrumental',
#   '2016-10-14',
#   0.588,
#   0.331,
#   1,
#   -11.288,
#   1,
#   0.0341,
#   0.531,
#   0.945,
#   0.101,
#   0.278,
#   80.994,
#   'audio_features',
#   '7lA3PShFAM7KJxiBi6K9id',
#   'spotify:track:7lA3PShFAM7KJxiBi6K9id',
#   'https://api.spotify.com/v1/tracks/7lA3PShFAM7KJxiBi6K9id',
#   'https://api.spotify.com/v1/audio-analysis/7lA3PShFAM7KJxiBi6K9id',
#   238253,
#   4],
#  ['Clueso',
#   'Neuanfang (Deluxe Edition)',
#   'spotify:album:6IaWqDs0ldptwVfTLhgGSK',
#   'Sorgenfrei - Instrumental',
#   '2016-10-14',
#   0.43,
#   0.297,
#   11,
#   -13.607,
#   0,
#   0.0394,
#   0.599,
#   0.789,
#   0.13,
#   0.22,
#   129.131,
#   'audio_features',
#   '7rKNnCskeHM3Os3Lj3bPVn',
#   'spotify:track:7rKNnCskeHM3Os3Lj3bPVn',
#   'https://api.spotify.com/v1/tracks/7rKNnCskeHM3Os3Lj3bPVn',
#   'https://api.spotify.com/v1/audio-analysis/7rKNnCskeHM3Os3Lj3bPVn',
#   277400,
#   4],
#  ['Clueso',
#   'Stadtrandlichter (Live)',
#   'spotify:album:1FydoZHEVD8Iytg0UDHurj',
#   'Pack meine Sachen - Live',
#   '2015-11-13',
#   0.548,
#   0.892,
#   11,
#   -5.713,
#   0,
#   0.0512,
#   0.0931,
#   2.92e-06,
#   0.333,
#   0.718,
#   92.413,
#   'audio_features',
#   '3JZTvRJIXALt4pvd43kj2U',
#   'spotify:track:3JZTvRJIXALt4pvd43kj2U',
#   'https://api.spotify.com/v1/tracks/3JZTvRJIXALt4pvd43kj2U',
#   'https://api.spotify.com/v1/audio-analysis/3JZTvRJIXALt4pvd43kj2U',
#   305056,
#   4],
#  ['Clueso',
#   'Stadtrandlichter (Live)',
#   'spotify:album:1FydoZHEVD8Iytg0UDHurj',
#   'Zu schnell vorbei - Live',
#   '2015-11-13',
#   0.663,
#   0.796,
#   2,
#   -6.4,
#   1,
#   0.0307,
#   0.293,
#   0.000147,
#   0.902,
#   0.467,
#   126.003,
#   'audio_features',
#   '5gshQQVgQ2uDzrqAmwSp8X',
#   'spotify:track:5gshQQVgQ2uDzrqAmwSp8X',
#   'https://api.spotify.com/v1/tracks/5gshQQVgQ2uDzrqAmwSp8X',
#   'https://api.spotify.com/v1/audio-analysis/5gshQQVgQ2uDzrqAmwSp8X',
#   391393,
#   4],
#  ['Clueso',
#   'Stadtrandlichter (Live)',
#   'spotify:album:1FydoZHEVD8Iytg0UDHurj',
#   'Freidrehen - Live',
#   '2015-11-13',
#   0.628,
#   0.852,
#   4,
#   -6.672,
#   0,
#   0.102,
#   0.256,
#   2.12e-06,
#   0.386,
#   0.428,
#   95.816,
#   'audio_features',
#   '0BcUwQ9os4wHvZB0zjrGkP',
#   'spotify:track:0BcUwQ9os4wHvZB0zjrGkP',
#   'https://api.spotify.com/v1/tracks/0BcUwQ9os4wHvZB0zjrGkP',
#   'https://api.spotify.com/v1/audio-analysis/0BcUwQ9os4wHvZB0zjrGkP',
#   284588,
#   4],
#  ['Clueso',
#   'Stadtrandlichter (Live)',
#   'spotify:album:1FydoZHEVD8Iytg0UDHurj',
#   'Still - Live',
#   '2015-11-13',
#   0.611,
#   0.776,
#   10,
#   -6.81,
#   1,
#   0.0397,
#   0.393,
#   2.96e-06,
#   0.882,
#   0.586,
#   143.953,
#   'audio_features',
#   '5Mhu6EN6Vu8Sa53qbC1sZh',
#   'spotify:track:5Mhu6EN6Vu8Sa53qbC1sZh',
#   'https://api.spotify.com/v1/tracks/5Mhu6EN6Vu8Sa53qbC1sZh',
#   'https://api.spotify.com/v1/audio-analysis/5Mhu6EN6Vu8Sa53qbC1sZh',
#   224626,
#   4],
#  ['Clueso',
#   'Stadtrandlichter (Live)',
#   'spotify:album:1FydoZHEVD8Iytg0UDHurj',
#   'Intro - Alles leuchtet - Live',
#   '2015-11-13',
#   0.299,
#   0.442,
#   10,
#   -17.006,
#   0,
#   0.0517,
#   0.941,
#   0.89,
#   0.376,
#   0.248,
#   78.866,
#   'audio_features',
#   '49nFLXNc2642gUOwSuGacA',
#   'spotify:track:49nFLXNc2642gUOwSuGacA',
#   'https://api.spotify.com/v1/tracks/49nFLXNc2642gUOwSuGacA',
#   'https://api.spotify.com/v1/audio-analysis/49nFLXNc2642gUOwSuGacA',
#   130431,
#   4],
#  ['Clueso',
#   'Stadtrandlichter (Live)',
#   'spotify:album:1FydoZHEVD8Iytg0UDHurj',
#   'Alles leuchtet - Live',
#   '2015-11-13',
#   0.549,
#   0.831,
#   1,
#   -6.473,
#   1,
#   0.0698,
#   0.272,
#   0.000773,
#   0.234,
#   0.388,
#   157.635,
#   'audio_features',
#   '0aOM2hQ868dSrMxDEd09o2',
#   'spotify:track:0aOM2hQ868dSrMxDEd09o2',
#   'https://api.spotify.com/v1/tracks/0aOM2hQ868dSrMxDEd09o2',
#   'https://api.spotify.com/v1/audio-analysis/0aOM2hQ868dSrMxDEd09o2',
#   313193,
#   4],
#  ['Clueso',
#   'Stadtrandlichter (Live)',
#   'spotify:album:1FydoZHEVD8Iytg0UDHurj',
#   'Medley - Live',
#   '2015-11-13',
#   0.447,
#   0.841,
#   9,
#   -5.255,
#   0,
#   0.249,
#   0.261,
#   0,
#   0.785,
#   0.479,
#   85.502,
#   'audio_features',
#   '1bQx57JYnqPhkZMYNMM6mN',
#   'spotify:track:1bQx57JYnqPhkZMYNMM6mN',
#   'https://api.spotify.com/v1/tracks/1bQx57JYnqPhkZMYNMM6mN',
#   'https://api.spotify.com/v1/audio-analysis/1bQx57JYnqPhkZMYNMM6mN',
#   679510,
#   4],
#  ['Clueso',
#   'Stadtrandlichter (Live)',
#   'spotify:album:1FydoZHEVD8Iytg0UDHurj',
#   'Gewinner - Live',
#   '2015-11-13',
#   0.668,
#   0.567,
#   0,
#   -8.258,
#   1,
#   0.0456,
#   0.606,
#   0.00612,
#   0.816,
#   0.155,
#   114.92,
#   'audio_features',
#   '1KdqbcyeGhHHLRMkSAkjVO',
#   'spotify:track:1KdqbcyeGhHHLRMkSAkjVO',
#   'https://api.spotify.com/v1/tracks/1KdqbcyeGhHHLRMkSAkjVO',
#   'https://api.spotify.com/v1/audio-analysis/1KdqbcyeGhHHLRMkSAkjVO',
#   354297,
#   4],
#  ['Clueso',
#   'Stadtrandlichter (Live)',
#   'spotify:album:1FydoZHEVD8Iytg0UDHurj',
#   'Nebenbei - Live',
#   '2015-11-13',
#   0.465,
#   0.551,
#   4,
#   -7.752,
#   0,
#   0.0474,
#   0.708,
#   0.000473,
#   0.89,
#   0.203,
#   76.742,
#   'audio_features',
#   '6q4pkkpZ4fxWF5pk4n5bxb',
#   'spotify:track:6q4pkkpZ4fxWF5pk4n5bxb',
#   'https://api.spotify.com/v1/tracks/6q4pkkpZ4fxWF5pk4n5bxb',
#   'https://api.spotify.com/v1/audio-analysis/6q4pkkpZ4fxWF5pk4n5bxb',
#   458419,
#   4],
#  ['Clueso',
#   'Stadtrandlichter (Live)',
#   'spotify:album:1FydoZHEVD8Iytg0UDHurj',
#   'Verdamp lang her - Live',
#   '2015-11-13',
#   0.536,
#   0.79,
#   4,
#   -7.085,
#   0,
#   0.0573,
#   0.218,
#   7.94e-05,
#   0.728,
#   0.098,
#   145.235,
#   'audio_features',
#   '47QVeFHXrgfd8JpGIUYc2t',
#   'spotify:track:47QVeFHXrgfd8JpGIUYc2t',
#   'https://api.spotify.com/v1/tracks/47QVeFHXrgfd8JpGIUYc2t',
#   'https://api.spotify.com/v1/audio-analysis/47QVeFHXrgfd8JpGIUYc2t',
#   504264,
#   4],
#  ['Clueso',
#   'Stadtrandlichter (Live)',
#   'spotify:album:1FydoZHEVD8Iytg0UDHurj',
#   'Out Of Space - Live',
#   '2015-11-13',
#   0.626,
#   0.9,
#   2,
#   -7.41,
#   0,
#   0.0524,
#   0.0749,
#   0.00897,
#   0.843,
#   0.246,
#   119.993,
#   'audio_features',
#   '1XnhZOSsueO0Ak3NpNU6eN',
#   'spotify:track:1XnhZOSsueO0Ak3NpNU6eN',
#   'https://api.spotify.com/v1/tracks/1XnhZOSsueO0Ak3NpNU6eN',
#   'https://api.spotify.com/v1/audio-analysis/1XnhZOSsueO0Ak3NpNU6eN',
#   494318,
#   4],
#  ['Clueso',
#   'Stadtrandlichter (Live)',
#   'spotify:album:1FydoZHEVD8Iytg0UDHurj',
#   'Cello - Live',
#   '2015-11-13',
#   0.579,
#   0.825,
#   7,
#   -6.678,
#   0,
#   0.107,
#   0.547,
#   1.78e-05,
#   0.72,
#   0.36,
#   95.269,
#   'audio_features',
#   '47R6Hf3eTDRhVdU9Hmat3Y',
#   'spotify:track:47R6Hf3eTDRhVdU9Hmat3Y',
#   'https://api.spotify.com/v1/tracks/47R6Hf3eTDRhVdU9Hmat3Y',
#   'https://api.spotify.com/v1/audio-analysis/47R6Hf3eTDRhVdU9Hmat3Y',
#   284203,
#   4],
#  ['Clueso',
#   'Stadtrandlichter (Live)',
#   'spotify:album:1FydoZHEVD8Iytg0UDHurj',
#   'Stadtrandlichter - Live',
#   '2015-11-13',
#   0.397,
#   0.488,
#   1,
#   -10.429,
#   0,
#   0.0496,
#   0.768,
#   0.000758,
#   0.343,
#   0.148,
#   95.933,
#   'audio_features',
#   '3l23u8yIzt0cBDPSzszJii',
#   'spotify:track:3l23u8yIzt0cBDPSzszJii',
#   'https://api.spotify.com/v1/tracks/3l23u8yIzt0cBDPSzszJii',
#   'https://api.spotify.com/v1/audio-analysis/3l23u8yIzt0cBDPSzszJii',
#   291957,
#   4],
#  ['Clueso',
#   'Stadtrandlichter (Live)',
#   'spotify:album:1FydoZHEVD8Iytg0UDHurj',
#   'Intro - So sehr dabei - Live',
#   '2015-11-13',
#   0.482,
#   0.192,
#   10,
#   -15.921,
#   0,
#   0.056,
#   0.96,
#   0.197,
#   0.162,
#   0.135,
#   113.456,
#   'audio_features',
#   '5HjvXOaZc1LM1w1dQjYWUN',
#   'spotify:track:5HjvXOaZc1LM1w1dQjYWUN',
#   'https://api.spotify.com/v1/tracks/5HjvXOaZc1LM1w1dQjYWUN',
#   'https://api.spotify.com/v1/audio-analysis/5HjvXOaZc1LM1w1dQjYWUN',
#   86672,
#   4],
#  ['Clueso',
#   'Stadtrandlichter (Live)',
#   'spotify:album:1FydoZHEVD8Iytg0UDHurj',
#   'So sehr dabei - Live',
#   '2015-11-13',
#   0.391,
#   0.451,
#   10,
#   -9.225,
#   0,
#   0.0392,
#   0.713,
#   0.00963,
#   0.685,
#   0.101,
#   121.481,
#   'audio_features',
#   '5vbyc7hpWVa8lkr0jSnnNN',
#   'spotify:track:5vbyc7hpWVa8lkr0jSnnNN',
#   'https://api.spotify.com/v1/tracks/5vbyc7hpWVa8lkr0jSnnNN',
#   'https://api.spotify.com/v1/audio-analysis/5vbyc7hpWVa8lkr0jSnnNN',
#   379658,
#   4],
#  ['Clueso',
#   'Stadtrandlichter (Live)',
#   'spotify:album:1FydoZHEVD8Iytg0UDHurj',
#   'Unter Strom - Live',
#   '2015-11-13',
#   0.518,
#   0.288,
#   0,
#   -13.445,
#   1,
#   0.0335,
#   0.806,
#   0.00172,
#   0.667,
#   0.101,
#   75.756,
#   'audio_features',
#   '68DpJLoJoEo0hOSOQNdPXl',
#   'spotify:track:68DpJLoJoEo0hOSOQNdPXl',
#   'https://api.spotify.com/v1/tracks/68DpJLoJoEo0hOSOQNdPXl',
#   'https://api.spotify.com/v1/audio-analysis/68DpJLoJoEo0hOSOQNdPXl',
#   294387,
#   4],
#  ['Clueso',
#   'Stadtrandlichter (Live)',
#   'spotify:album:1FydoZHEVD8Iytg0UDHurj',
#   'Galerie - Live',
#   '2015-11-13',
#   0.573,
#   0.328,
#   7,
#   -16.046,
#   1,
#   0.123,
#   0.88,
#   0.0177,
#   0.697,
#   0.111,
#   91.492,
#   'audio_features',
#   '4RJK6eEhos1KnIJw0EPExJ',
#   'spotify:track:4RJK6eEhos1KnIJw0EPExJ',
#   'https://api.spotify.com/v1/tracks/4RJK6eEhos1KnIJw0EPExJ',
#   'https://api.spotify.com/v1/audio-analysis/4RJK6eEhos1KnIJw0EPExJ',
#   247655,
#   4],
#  ['Clueso',
#   'Stadtrandlichter (Live)',
#   'spotify:album:1FydoZHEVD8Iytg0UDHurj',
#   'Geradeaus - Live',
#   '2015-11-13',
#   0.478,
#   0.451,
#   7,
#   -11.236,
#   0,
#   0.0359,
#   0.86,
#   8.81e-06,
#   0.689,
#   0.431,
#   90.205,
#   'audio_features',
#   '4KavADV5d293KhEcGLegmQ',
#   'spotify:track:4KavADV5d293KhEcGLegmQ',
#   'https://api.spotify.com/v1/tracks/4KavADV5d293KhEcGLegmQ',
#   'https://api.spotify.com/v1/audio-analysis/4KavADV5d293KhEcGLegmQ',
#   234325,
#   4],
#  ['Clueso',
#   'Stadtrandlichter (Live)',
#   'spotify:album:1FydoZHEVD8Iytg0UDHurj',
#   'Ich falle noch - Live',
#   '2015-11-13',
#   0.396,
#   0.253,
#   6,
#   -15.132,
#   1,
#   0.041,
#   0.908,
#   0.0894,
#   0.661,
#   0.0858,
#   149.789,
#   'audio_features',
#   '5anGnfLHO5tS5eHdXv4kOJ',
#   'spotify:track:5anGnfLHO5tS5eHdXv4kOJ',
#   'https://api.spotify.com/v1/tracks/5anGnfLHO5tS5eHdXv4kOJ',
#   'https://api.spotify.com/v1/audio-analysis/5anGnfLHO5tS5eHdXv4kOJ',
#   178126,
#   3],
#  ['Clueso',
#   'Stadtrandlichter (Live)',
#   'spotify:album:1FydoZHEVD8Iytg0UDHurj',
#   'Lass den Kopf nicht hängen - Live',
#   '2015-11-13',
#   0.37,
#   0.494,
#   5,
#   -14.308,
#   1,
#   0.254,
#   0.818,
#   0.00381,
#   0.693,
#   0.219,
#   183.599,
#   'audio_features',
#   '7HNeRoI1yQ3NsN8GEQ6KFg',
#   'spotify:track:7HNeRoI1yQ3NsN8GEQ6KFg',
#   'https://api.spotify.com/v1/tracks/7HNeRoI1yQ3NsN8GEQ6KFg',
#   'https://api.spotify.com/v1/audio-analysis/7HNeRoI1yQ3NsN8GEQ6KFg',
#   267999,
#   3],
#  ['Clueso',
#   'Stadtrandlichter (Live)',
#   'spotify:album:1FydoZHEVD8Iytg0UDHurj',
#   'Wach auf - Live',
#   '2015-11-13',
#   0.686,
#   0.403,
#   3,
#   -15.811,
#   0,
#   0.0746,
#   0.887,
#   0.00278,
#   0.665,
#   0.58,
#   96.578,
#   'audio_features',
#   '0znVpXmJMsEUZwyia6DhpW',
#   'spotify:track:0znVpXmJMsEUZwyia6DhpW',
#   'https://api.spotify.com/v1/tracks/0znVpXmJMsEUZwyia6DhpW',
#   'https://api.spotify.com/v1/audio-analysis/0znVpXmJMsEUZwyia6DhpW',
#   244885,
#   4],
#  ['Clueso',
#   'Stadtrandlichter',
#   'spotify:album:72kgirTvoqOUEHnegTZLCO',
#   'Pack meine Sachen',
#   '2014-01-01',
#   0.544,
#   0.894,
#   3,
#   -5.915,
#   1,
#   0.0825,
#   0.019,
#   1.68e-06,
#   0.113,
#   0.522,
#   90.925,
#   'audio_features',
#   '3XkcD22BKCVbAegPO5MFX6',
#   'spotify:track:3XkcD22BKCVbAegPO5MFX6',
#   'https://api.spotify.com/v1/tracks/3XkcD22BKCVbAegPO5MFX6',
#   'https://api.spotify.com/v1/audio-analysis/3XkcD22BKCVbAegPO5MFX6',
#   223387,
#   4],
#  ['Clueso',
#   'Stadtrandlichter',
#   'spotify:album:72kgirTvoqOUEHnegTZLCO',
#   'Freidrehen',
#   '2014-01-01',
#   0.653,
#   0.644,
#   9,
#   -7.403,
#   0,
#   0.0952,
#   0.291,
#   3.26e-05,
#   0.128,
#   0.365,
#   95.981,
#   'audio_features',
#   '6XuplOlrHP00OZHsgGwKrc',
#   'spotify:track:6XuplOlrHP00OZHsgGwKrc',
#   'https://api.spotify.com/v1/tracks/6XuplOlrHP00OZHsgGwKrc',
#   'https://api.spotify.com/v1/audio-analysis/6XuplOlrHP00OZHsgGwKrc',
#   223093,
#   4],
#  ['Clueso',
#   'Stadtrandlichter',
#   'spotify:album:72kgirTvoqOUEHnegTZLCO',
#   'Alles leuchtet',
#   '2014-01-01',
#   0.607,
#   0.886,
#   0,
#   -7.14,
#   1,
#   0.0448,
#   0.0306,
#   0.00436,
#   0.144,
#   0.575,
#   156.935,
#   'audio_features',
#   '0SJYTzwudLkJmYLclwPfEF',
#   'spotify:track:0SJYTzwudLkJmYLclwPfEF',
#   'https://api.spotify.com/v1/tracks/0SJYTzwudLkJmYLclwPfEF',
#   'https://api.spotify.com/v1/audio-analysis/0SJYTzwudLkJmYLclwPfEF',
#   221787,
#   4],
#  ['Clueso',
#   'Stadtrandlichter',
#   'spotify:album:72kgirTvoqOUEHnegTZLCO',
#   'Wach auf',
#   '2014-01-01',
#   0.743,
#   0.697,
#   9,
#   -7.744,
#   0,
#   0.0308,
#   0.393,
#   4.49e-06,
#   0.118,
#   0.759,
#   103.979,
#   'audio_features',
#   '6jhR3vJL4XKyjdEby4OAkY',
#   'spotify:track:6jhR3vJL4XKyjdEby4OAkY',
#   'https://api.spotify.com/v1/tracks/6jhR3vJL4XKyjdEby4OAkY',
#   'https://api.spotify.com/v1/audio-analysis/6jhR3vJL4XKyjdEby4OAkY',
#   226200,
#   4],
#  ['Clueso',
#   'Stadtrandlichter',
#   'spotify:album:72kgirTvoqOUEHnegTZLCO',
#   'Interlude I',
#   '2014-01-01',
#   0.328,
#   0.0709,
#   4,
#   -28.819,
#   1,
#   0.0451,
#   0.426,
#   0.981,
#   0.225,
#   0.556,
#   61.021,
#   'audio_features',
#   '7e3SDeztRc8E1XHCp9yzHK',
#   'spotify:track:7e3SDeztRc8E1XHCp9yzHK',
#   'https://api.spotify.com/v1/tracks/7e3SDeztRc8E1XHCp9yzHK',
#   'https://api.spotify.com/v1/audio-analysis/7e3SDeztRc8E1XHCp9yzHK',
#   35400,
#   4],
#  ['Clueso',
#   'Stadtrandlichter',
#   'spotify:album:72kgirTvoqOUEHnegTZLCO',
#   'Stadtrandlichter',
#   '2014-01-01',
#   0.481,
#   0.289,
#   4,
#   -11.688,
#   1,
#   0.0404,
#   0.485,
#   0.00886,
#   0.111,
#   0.111,
#   95.56,
#   'audio_features',
#   '6LaA46Dx02y2tXMOylWqve',
#   'spotify:track:6LaA46Dx02y2tXMOylWqve',
#   'https://api.spotify.com/v1/tracks/6LaA46Dx02y2tXMOylWqve',
#   'https://api.spotify.com/v1/audio-analysis/6LaA46Dx02y2tXMOylWqve',
#   212440,
#   4],
#  ['Clueso',
#   'Stadtrandlichter',
#   'spotify:album:72kgirTvoqOUEHnegTZLCO',
#   'Unter Strom',
#   '2014-01-01',
#   0.569,
#   0.525,
#   9,
#   -9.506,
#   0,
#   0.0352,
#   0.206,
#   0.000392,
#   0.13,
#   0.387,
#   148.099,
#   'audio_features',
#   '4ttL5DvkiBi56P2DK2XFel',
#   'spotify:track:4ttL5DvkiBi56P2DK2XFel',
#   'https://api.spotify.com/v1/tracks/4ttL5DvkiBi56P2DK2XFel',
#   'https://api.spotify.com/v1/audio-analysis/4ttL5DvkiBi56P2DK2XFel',
#   229787,
#   4],
#  ['Clueso',
#   'Stadtrandlichter',
#   'spotify:album:72kgirTvoqOUEHnegTZLCO',
#   'Okay',
#   '2014-01-01',
#   0.404,
#   0.0604,
#   7,
#   -18.253,
#   1,
#   0.0578,
#   0.958,
#   0.0129,
#   0.0923,
#   0.168,
#   78.236,
#   'audio_features',
#   '34uAe8Oe5b6DQp2vrrU9Fo',
#   'spotify:track:34uAe8Oe5b6DQp2vrrU9Fo',
#   'https://api.spotify.com/v1/tracks/34uAe8Oe5b6DQp2vrrU9Fo',
#   'https://api.spotify.com/v1/audio-analysis/34uAe8Oe5b6DQp2vrrU9Fo',
#   56000,
#   4],
#  ['Clueso',
#   'Stadtrandlichter',
#   'spotify:album:72kgirTvoqOUEHnegTZLCO',
#   'Lass den Kopf nicht hängen',
#   '2014-01-01',
#   0.588,
#   0.566,
#   5,
#   -7.572,
#   1,
#   0.0245,
#   0.403,
#   0.000496,
#   0.104,
#   0.343,
#   92.997,
#   'audio_features',
#   '6pFuy6JFlbdOLOp4vjAI0g',
#   'spotify:track:6pFuy6JFlbdOLOp4vjAI0g',
#   'https://api.spotify.com/v1/tracks/6pFuy6JFlbdOLOp4vjAI0g',
#   'https://api.spotify.com/v1/audio-analysis/6pFuy6JFlbdOLOp4vjAI0g',
#   218640,
#   3],
#  ['Clueso',
#   'Stadtrandlichter',
#   'spotify:album:72kgirTvoqOUEHnegTZLCO',
#   'Interlude II',
#   '2014-01-01',
#   0.767,
#   0.325,
#   7,
#   -14.961,
#   0,
#   0.114,
#   0.504,
#   0.717,
#   0.13,
#   0.622,
#   124.272,
#   'audio_features',
#   '3w2LOyrc1IcwP6h6VFmhYd',
#   'spotify:track:3w2LOyrc1IcwP6h6VFmhYd',
#   'https://api.spotify.com/v1/tracks/3w2LOyrc1IcwP6h6VFmhYd',
#   'https://api.spotify.com/v1/audio-analysis/3w2LOyrc1IcwP6h6VFmhYd',
#   84080,
#   4],
#  ['Clueso',
#   'Stadtrandlichter',
#   'spotify:album:72kgirTvoqOUEHnegTZLCO',
#   'Sein Song',
#   '2014-01-01',
#   0.672,
#   0.691,
#   10,
#   -6.543,
#   1,
#   0.0353,
#   0.0515,
#   0,
#   0.0927,
#   0.746,
#   138.103,
#   'audio_features',
#   '2Nc3y5tdHxvW9DswbDZMCx',
#   'spotify:track:2Nc3y5tdHxvW9DswbDZMCx',
#   'https://api.spotify.com/v1/tracks/2Nc3y5tdHxvW9DswbDZMCx',
#   'https://api.spotify.com/v1/audio-analysis/2Nc3y5tdHxvW9DswbDZMCx',
#   176453,
#   4],
#  ['Clueso',
#   'Stadtrandlichter',
#   'spotify:album:72kgirTvoqOUEHnegTZLCO',
#   'Still',
#   '2014-01-01',
#   0.623,
#   0.554,
#   10,
#   -7.083,
#   1,
#   0.0278,
#   0.021,
#   0.000601,
#   0.137,
#   0.77,
#   139.53,
#   'audio_features',
#   '2bKh5t4gkDDjbAJlSd2cy1',
#   'spotify:track:2bKh5t4gkDDjbAJlSd2cy1',
#   'https://api.spotify.com/v1/tracks/2bKh5t4gkDDjbAJlSd2cy1',
#   'https://api.spotify.com/v1/audio-analysis/2bKh5t4gkDDjbAJlSd2cy1',
#   225000,
#   4],
# ...
#   'https://api.spotify.com/v1/tracks/6F71EBA24TDaNGtUimschP',
#   'https://api.spotify.com/v1/audio-analysis/6F71EBA24TDaNGtUimschP',
#   72267,
#   4],
#  ['Clueso',
#   'Gute Musik (Remastered 2014)',
#   'spotify:album:2VyQxxAHFs2wZNuMJ7JtCL',
#   'Love The People - Remastered 2014',
#   '2004-06-18',
#   0.76,
#   0.846,
#   10,
#   -6.957,
#   0,
#   0.0872,
#   0.0145,
#   0,
#   0.175,
#   0.911,
#   158.98,
#   'audio_features',
#   '2TKDpYUGZ18qB15I888fk9',
#   'spotify:track:2TKDpYUGZ18qB15I888fk9',
#   'https://api.spotify.com/v1/tracks/2TKDpYUGZ18qB15I888fk9',
#   'https://api.spotify.com/v1/audio-analysis/2TKDpYUGZ18qB15I888fk9',
#   233053,
#   4],
#  ['Clueso',
#   'Gute Musik (Remastered 2014)',
#   'spotify:album:2VyQxxAHFs2wZNuMJ7JtCL',
#   'Kalter Kaffee (Interlude) - Remastered 2014',
#   '2004-06-18',
#   0.552,
#   0.354,
#   1,
#   -21.163,
#   1,
#   0.543,
#   0.818,
#   0,
#   0.598,
#   0.65,
#   100.793,
#   'audio_features',
#   '1UNDDtt6Q2p0mZzgJYtWDT',
#   'spotify:track:1UNDDtt6Q2p0mZzgJYtWDT',
#   'https://api.spotify.com/v1/tracks/1UNDDtt6Q2p0mZzgJYtWDT',
#   'https://api.spotify.com/v1/audio-analysis/1UNDDtt6Q2p0mZzgJYtWDT',
#   18800,
#   5],
#  ['Clueso',
#   'Gute Musik (Remastered 2014)',
#   'spotify:album:2VyQxxAHFs2wZNuMJ7JtCL',
#   'Bescheid - Remastered 2014',
#   '2004-06-18',
#   0.858,
#   0.781,
#   1,
#   -6.928,
#   1,
#   0.0432,
#   0.0491,
#   0.395,
#   0.0829,
#   0.823,
#   120.015,
#   'audio_features',
#   '7en8oTNL2iUZjjZc7SqKDB',
#   'spotify:track:7en8oTNL2iUZjjZc7SqKDB',
#   'https://api.spotify.com/v1/tracks/7en8oTNL2iUZjjZc7SqKDB',
#   'https://api.spotify.com/v1/audio-analysis/7en8oTNL2iUZjjZc7SqKDB',
#   299813,
#   4],
#  ['Clueso',
#   'Gute Musik (Remastered 2014)',
#   'spotify:album:2VyQxxAHFs2wZNuMJ7JtCL',
#   'Vier kleine Wände - Remastered 2014',
#   '2004-06-18',
#   0.715,
#   0.583,
#   9,
#   -8.575,
#   0,
#   0.4,
#   0.12,
#   0.000286,
#   0.33,
#   0.699,
#   85.274,
#   'audio_features',
#   '4vOUeGGeWkaM6N35KUuDCQ',
#   'spotify:track:4vOUeGGeWkaM6N35KUuDCQ',
#   'https://api.spotify.com/v1/tracks/4vOUeGGeWkaM6N35KUuDCQ',
#   'https://api.spotify.com/v1/audio-analysis/4vOUeGGeWkaM6N35KUuDCQ',
#   190547,
#   4],
#  ['Clueso',
#   'Gute Musik (Remastered 2014)',
#   'spotify:album:2VyQxxAHFs2wZNuMJ7JtCL',
#   'City-Pizza-Express (Interlude) - Remastered 2014',
#   '2004-06-18',
#   0.728,
#   0.568,
#   10,
#   -8.095,
#   0,
#   0.0337,
#   0.01,
#   0.44,
#   0.111,
#   0.854,
#   130.037,
#   'audio_features',
#   '73YAkg9qYmt9KlQ8WBqU6B',
#   'spotify:track:73YAkg9qYmt9KlQ8WBqU6B',
#   'https://api.spotify.com/v1/tracks/73YAkg9qYmt9KlQ8WBqU6B',
#   'https://api.spotify.com/v1/audio-analysis/73YAkg9qYmt9KlQ8WBqU6B',
#   163453,
#   4],
#  ['Clueso',
#   'Gute Musik (Remastered 2014)',
#   'spotify:album:2VyQxxAHFs2wZNuMJ7JtCL',
#   'Pizzaschachteln - Remastered 2014',
#   '2004-06-18',
#   0.56,
#   0.67,
#   7,
#   -7.787,
#   1,
#   0.111,
#   0.198,
#   1.2e-06,
#   0.0911,
#   0.714,
#   78.724,
#   'audio_features',
#   '5amt5V0C8e0T5tdYgPW1u8',
#   'spotify:track:5amt5V0C8e0T5tdYgPW1u8',
#   'https://api.spotify.com/v1/tracks/5amt5V0C8e0T5tdYgPW1u8',
#   'https://api.spotify.com/v1/audio-analysis/5amt5V0C8e0T5tdYgPW1u8',
#   262000,
#   4],
#  ['Clueso',
#   'Gute Musik (Remastered 2014)',
#   'spotify:album:2VyQxxAHFs2wZNuMJ7JtCL',
#   "Wie heisst'n Du? (Interlude) - Remastered 2014",
#   '2004-06-18',
#   0.487,
#   0.449,
#   5,
#   -15.659,
#   1,
#   0.125,
#   0.0238,
#   2.8e-05,
#   0.199,
#   0.835,
#   119.291,
#   'audio_features',
#   '3BpxuMKLU5Ou4m3MfIiG41',
#   'spotify:track:3BpxuMKLU5Ou4m3MfIiG41',
#   'https://api.spotify.com/v1/tracks/3BpxuMKLU5Ou4m3MfIiG41',
#   'https://api.spotify.com/v1/audio-analysis/3BpxuMKLU5Ou4m3MfIiG41',
#   25560,
#   3],
#  ['Clueso',
#   'Gute Musik (Remastered 2014)',
#   'spotify:album:2VyQxxAHFs2wZNuMJ7JtCL',
#   'Wart mal - Remastered 2014',
#   '2004-06-18',
#   0.855,
#   0.69,
#   10,
#   -6.607,
#   0,
#   0.057,
#   0.094,
#   0.00071,
#   0.0766,
#   0.517,
#   113.532,
#   'audio_features',
#   '5BUg8hrHN8fcYgfWvr9CzG',
#   'spotify:track:5BUg8hrHN8fcYgfWvr9CzG',
#   'https://api.spotify.com/v1/tracks/5BUg8hrHN8fcYgfWvr9CzG',
#   'https://api.spotify.com/v1/audio-analysis/5BUg8hrHN8fcYgfWvr9CzG',
#   244813,
#   4],
#  ['Clueso',
#   'Gute Musik (Remastered 2014)',
#   'spotify:album:2VyQxxAHFs2wZNuMJ7JtCL',
#   'Vergessen ist so leicht - Remastered 2014',
#   '2004-06-18',
#   0.648,
#   0.717,
#   5,
#   -8.633,
#   1,
#   0.0361,
#   0.271,
#   0.000283,
#   0.535,
#   0.523,
#   93.479,
#   'audio_features',
#   '1T6vXUsoyjQC0c8kk96gSv',
#   'spotify:track:1T6vXUsoyjQC0c8kk96gSv',
#   'https://api.spotify.com/v1/tracks/1T6vXUsoyjQC0c8kk96gSv',
#   'https://api.spotify.com/v1/audio-analysis/1T6vXUsoyjQC0c8kk96gSv',
#   263240,
#   4],
#  ['Clueso',
#   'Gute Musik (Remastered 2014)',
#   'spotify:album:2VyQxxAHFs2wZNuMJ7JtCL',
#   'Fanpost - Remastered 2014',
#   '2004-06-18',
#   0.782,
#   0.415,
#   6,
#   -10.722,
#   1,
#   0.0402,
#   0.681,
#   0.000247,
#   0.3,
#   0.672,
#   101.205,
#   'audio_features',
#   '0J2iYgR9hkdSPDpsJWOHdc',
#   'spotify:track:0J2iYgR9hkdSPDpsJWOHdc',
#   'https://api.spotify.com/v1/tracks/0J2iYgR9hkdSPDpsJWOHdc',
#   'https://api.spotify.com/v1/audio-analysis/0J2iYgR9hkdSPDpsJWOHdc',
#   232867,
#   4],
#  ['Clueso',
#   'Gute Musik (Remastered 2014)',
#   'spotify:album:2VyQxxAHFs2wZNuMJ7JtCL',
#   'Egal wo! - Remastered 2014',
#   '2004-06-18',
#   0.625,
#   0.498,
#   5,
#   -6.745,
#   1,
#   0.411,
#   0.0815,
#   0,
#   0.443,
#   0.845,
#   88.354,
#   'audio_features',
#   '10JQTqvTjNqM5C0n4awh6L',
#   'spotify:track:10JQTqvTjNqM5C0n4awh6L',
#   'https://api.spotify.com/v1/tracks/10JQTqvTjNqM5C0n4awh6L',
#   'https://api.spotify.com/v1/audio-analysis/10JQTqvTjNqM5C0n4awh6L',
#   281760,
#   4],
#  ['Clueso',
#   'Gute Musik (Remastered 2014)',
#   'spotify:album:2VyQxxAHFs2wZNuMJ7JtCL',
#   'Ich geh heim! - Remastered 2014',
#   '2004-06-18',
#   0.509,
#   0.337,
#   0,
#   -14.147,
#   0,
#   0.355,
#   0.414,
#   0,
#   0.291,
#   0.633,
#   87.04,
#   'audio_features',
#   '5srEb7nnKO6FVra7O2Zhce',
#   'spotify:track:5srEb7nnKO6FVra7O2Zhce',
#   'https://api.spotify.com/v1/tracks/5srEb7nnKO6FVra7O2Zhce',
#   'https://api.spotify.com/v1/audio-analysis/5srEb7nnKO6FVra7O2Zhce',
#   42773,
#   3],
#  ['Clueso',
#   'Gute Musik (Remastered 2014)',
#   'spotify:album:2VyQxxAHFs2wZNuMJ7JtCL',
#   'Herz Boom Boom - Remastered 2014',
#   '2004-06-18',
#   0.77,
#   0.499,
#   6,
#   -10.434,
#   1,
#   0.613,
#   0.371,
#   4.01e-06,
#   0.095,
#   0.912,
#   203.362,
#   'audio_features',
#   '5xs1bzbd06yaJ2yo0f2aT5',
#   'spotify:track:5xs1bzbd06yaJ2yo0f2aT5',
#   'https://api.spotify.com/v1/tracks/5xs1bzbd06yaJ2yo0f2aT5',
#   'https://api.spotify.com/v1/audio-analysis/5xs1bzbd06yaJ2yo0f2aT5',
#   232947,
#   3],
#  ['Clueso',
#   'Gute Musik (Remastered 2014)',
#   'spotify:album:2VyQxxAHFs2wZNuMJ7JtCL',
#   'Vorspiel - Remastered 2014',
#   '2004-06-18',
#   0.549,
#   0.162,
#   11,
#   -17.945,
#   0,
#   0.0476,
#   0.688,
#   0.363,
#   0.11,
#   0.105,
#   82.169,
#   'audio_features',
#   '5sF3R4pUTnMoha2EZPklFW',
#   'spotify:track:5sF3R4pUTnMoha2EZPklFW',
#   'https://api.spotify.com/v1/tracks/5sF3R4pUTnMoha2EZPklFW',
#   'https://api.spotify.com/v1/audio-analysis/5sF3R4pUTnMoha2EZPklFW',
#   58027,
#   4],
#  ['Clueso',
#   'Gute Musik (Remastered 2014)',
#   'spotify:album:2VyQxxAHFs2wZNuMJ7JtCL',
#   'Kein Bock zu gehen - Remastered 2014',
#   '2004-06-18',
#   0.589,
#   0.605,
#   11,
#   -8.455,
#   0,
#   0.0399,
#   0.138,
#   6.81e-05,
#   0.166,
#   0.65,
#   139.336,
#   'audio_features',
#   '7KZsksU3MwoICQqRM9vh88',
#   'spotify:track:7KZsksU3MwoICQqRM9vh88',
#   'https://api.spotify.com/v1/tracks/7KZsksU3MwoICQqRM9vh88',
#   'https://api.spotify.com/v1/audio-analysis/7KZsksU3MwoICQqRM9vh88',
#   351707,
#   4],
#  ['Clueso',
#   'Text und Ton (Remastered 2014)',
#   'spotify:album:4eNfhKwooJrEQf3rQExao2',
#   'Intro - Remastered 2014',
#   '2001-04-30',
#   0.922,
#   0.539,
#   9,
#   -8.625,
#   0,
#   0.289,
#   0.493,
#   0.00178,
#   0.0811,
#   0.766,
#   94.916,
#   'audio_features',
#   '39ZoMbKCwojEfMPoIOlUoR',
#   'spotify:track:39ZoMbKCwojEfMPoIOlUoR',
#   'https://api.spotify.com/v1/tracks/39ZoMbKCwojEfMPoIOlUoR',
#   'https://api.spotify.com/v1/audio-analysis/39ZoMbKCwojEfMPoIOlUoR',
#   112773,
#   4],
#  ['Clueso',
#   'Text und Ton (Remastered 2014)',
#   'spotify:album:4eNfhKwooJrEQf3rQExao2',
#   'Deine Stimme - Remastered 2014',
#   '2001-04-30',
#   0.781,
#   0.592,
#   4,
#   -8.404,
#   0,
#   0.287,
#   0.554,
#   2.34e-06,
#   0.114,
#   0.621,
#   89.91,
#   'audio_features',
#   '0VoOiZDQ1obWg5jWOVeWzv',
#   'spotify:track:0VoOiZDQ1obWg5jWOVeWzv',
#   'https://api.spotify.com/v1/tracks/0VoOiZDQ1obWg5jWOVeWzv',
#   'https://api.spotify.com/v1/audio-analysis/0VoOiZDQ1obWg5jWOVeWzv',
#   173093,
#   4],
#  ['Clueso',
#   'Text und Ton (Remastered 2014)',
#   'spotify:album:4eNfhKwooJrEQf3rQExao2',
#   'Sonne geht auf - Remastered 2014',
#   '2001-04-30',
#   0.689,
#   0.522,
#   2,
#   -8.017,
#   1,
#   0.204,
#   0.274,
#   0.000442,
#   0.0797,
#   0.485,
#   91.163,
#   'audio_features',
#   '5ZCS2reN71sbnCMgSlLv8Q',
#   'spotify:track:5ZCS2reN71sbnCMgSlLv8Q',
#   'https://api.spotify.com/v1/tracks/5ZCS2reN71sbnCMgSlLv8Q',
#   'https://api.spotify.com/v1/audio-analysis/5ZCS2reN71sbnCMgSlLv8Q',
#   213733,
#   4],
#  ['Clueso',
#   'Text und Ton (Remastered 2014)',
#   'spotify:album:4eNfhKwooJrEQf3rQExao2',
#   'Grid Locked (feat. Snaz & Remarkable) - Remastered 2014',
#   '2001-04-30',
#   0.649,
#   0.794,
#   1,
#   -7.065,
#   1,
#   0.395,
#   0.275,
#   0,
#   0.163,
#   0.548,
#   95.117,
#   'audio_features',
#   '4A6eP53lA0pG8oPxsl9xKG',
#   'spotify:track:4A6eP53lA0pG8oPxsl9xKG',
#   'https://api.spotify.com/v1/tracks/4A6eP53lA0pG8oPxsl9xKG',
#   'https://api.spotify.com/v1/audio-analysis/4A6eP53lA0pG8oPxsl9xKG',
#   260507,
#   4],
#  ['Clueso',
#   'Text und Ton (Remastered 2014)',
#   'spotify:album:4eNfhKwooJrEQf3rQExao2',
#   'My Own World - Remastered 2014',
#   '2001-04-30',
#   0.774,
#   0.311,
#   8,
#   -9.547,
#   0,
#   0.123,
#   0.0958,
#   0.861,
#   0.11,
#   0.323,
#   80.286,
#   'audio_features',
#   '3YccpYSAmWvOVJDpYkY42M',
#   'spotify:track:3YccpYSAmWvOVJDpYkY42M',
#   'https://api.spotify.com/v1/tracks/3YccpYSAmWvOVJDpYkY42M',
#   'https://api.spotify.com/v1/audio-analysis/3YccpYSAmWvOVJDpYkY42M',
#   112693,
#   4],
#  ['Clueso',
#   'Text und Ton (Remastered 2014)',
#   'spotify:album:4eNfhKwooJrEQf3rQExao2',
#   'Gib mir Mut - Remastered 2014',
#   '2001-04-30',
#   0.714,
#   0.634,
#   4,
#   -6.679,
#   0,
#   0.276,
#   0.349,
#   0,
#   0.181,
#   0.501,
#   91.09,
#   'audio_features',
#   '7c0vI1YiNqiM9Em4qVm6qe',
#   'spotify:track:7c0vI1YiNqiM9Em4qVm6qe',
#   'https://api.spotify.com/v1/tracks/7c0vI1YiNqiM9Em4qVm6qe',
#   'https://api.spotify.com/v1/audio-analysis/7c0vI1YiNqiM9Em4qVm6qe',
#   214733,
#   4],
#  ['Clueso',
#   'Text und Ton (Remastered 2014)',
#   'spotify:album:4eNfhKwooJrEQf3rQExao2',
#   'Sweet Memories - Remastered 2014',
#   '2001-04-30',
#   0.826,
#   0.585,
#   1,
#   -7.482,
#   1,
#   0.38,
#   0.0773,
#   0.000313,
#   0.126,
#   0.346,
#   93.026,
#   'audio_features',
#   '7yMuAEXpmFqqsmO02hOTsl',
#   'spotify:track:7yMuAEXpmFqqsmO02hOTsl',
#   'https://api.spotify.com/v1/tracks/7yMuAEXpmFqqsmO02hOTsl',
#   'https://api.spotify.com/v1/audio-analysis/7yMuAEXpmFqqsmO02hOTsl',
#   203707,
#   4],
#  ['Clueso',
#   'Text und Ton (Remastered 2014)',
#   'spotify:album:4eNfhKwooJrEQf3rQExao2',
#   'Kaffee - Remastered 2014',
#   '2001-04-30',
#   0.793,
#   0.722,
#   1,
#   -7.606,
#   1,
#   0.18,
#   0.261,
#   4.25e-06,
#   0.196,
#   0.862,
#   93.038,
#   'audio_features',
#   '6BgySTxVMqDpP2lbYGT7wV',
#   'spotify:track:6BgySTxVMqDpP2lbYGT7wV',
#   'https://api.spotify.com/v1/tracks/6BgySTxVMqDpP2lbYGT7wV',
#   'https://api.spotify.com/v1/audio-analysis/6BgySTxVMqDpP2lbYGT7wV',
#   133560,
#   4],
#  ['Clueso',
#   'Text und Ton (Remastered 2014)',
#   'spotify:album:4eNfhKwooJrEQf3rQExao2',
#   'Jenseits von eben - Remastered 2014',
#   '2001-04-30',
#   0.698,
#   0.318,
#   5,
#   -12.568,
#   1,
#   0.0671,
#   0.916,
#   0.553,
#   0.0957,
#   0.276,
#   99.893,
#   'audio_features',
#   '0M5hEbmEUev733KmzGLnkF',
#   'spotify:track:0M5hEbmEUev733KmzGLnkF',
#   'https://api.spotify.com/v1/tracks/0M5hEbmEUev733KmzGLnkF',
#   'https://api.spotify.com/v1/audio-analysis/0M5hEbmEUev733KmzGLnkF',
#   90400,
#   4],
#  ['Clueso',
#   'Text und Ton (Remastered 2014)',
#   'spotify:album:4eNfhKwooJrEQf3rQExao2',
#   'Never Been Broke - Remastered 2014',
#   '2001-04-30',
#   0.652,
#   0.685,
#   10,
#   -7.657,
#   0,
#   0.345,
#   0.641,
#   7.95e-06,
#   0.546,
#   0.883,
#   91.542,
#   'audio_features',
#   '7tRhEzBnw33yl6mSjFgImP',
#   'spotify:track:7tRhEzBnw33yl6mSjFgImP',
#   'https://api.spotify.com/v1/tracks/7tRhEzBnw33yl6mSjFgImP',
#   'https://api.spotify.com/v1/audio-analysis/7tRhEzBnw33yl6mSjFgImP',
#   98173,
#   4],
#  ['Clueso',
#   'Text und Ton (Remastered 2014)',
#   'spotify:album:4eNfhKwooJrEQf3rQExao2',
#   'Old To The New (feat. Stir M & Layguuan Sharkie) - Remastered 2014',
#   '2001-04-30',
#   0.668,
#   0.698,
#   5,
#   -6.081,
#   0,
#   0.309,
#   0.539,
#   7.38e-06,
#   0.323,
#   0.931,
#   87.826,
#   'audio_features',
#   '3qxhVpcBGzEgISd9fY2cHw',
#   'spotify:track:3qxhVpcBGzEgISd9fY2cHw',
#   'https://api.spotify.com/v1/tracks/3qxhVpcBGzEgISd9fY2cHw',
#   'https://api.spotify.com/v1/audio-analysis/3qxhVpcBGzEgISd9fY2cHw',
#   272800,
#   4],
#  ['Clueso',
#   'Text und Ton (Remastered 2014)',
#   'spotify:album:4eNfhKwooJrEQf3rQExao2',
#   "Die Lauten stinken nicht / Nimm dir die Zeit 98' - Remastered 2014",
#   '2001-04-30',
#   0.565,
#   0.587,
#   4,
#   -9.616,
#   0,
#   0.473,
#   0.288,
#   0.00416,
#   0.273,
#   0.555,
#   173.268,
#   'audio_features',
#   '0yn5iShAKTEL31750zGSyO',
#   'spotify:track:0yn5iShAKTEL31750zGSyO',
#   'https://api.spotify.com/v1/tracks/0yn5iShAKTEL31750zGSyO',
#   'https://api.spotify.com/v1/audio-analysis/0yn5iShAKTEL31750zGSyO',
#   226560,
#   4],
#  ['Clueso',
#   'Text und Ton (Remastered 2014)',
#   'spotify:album:4eNfhKwooJrEQf3rQExao2',
#   'Sag mir wo - Remastered 2014',
#   '2001-04-30',
#   0.575,
#   0.787,
#   4,
#   -6.909,
#   0,
#   0.309,
#   0.423,
#   0,
#   0.247,
#   0.581,
#   91.777,
#   'audio_features',
#   '1aQdz8ZXLgBOqs4Vcddeko',
#   'spotify:track:1aQdz8ZXLgBOqs4Vcddeko',
#   'https://api.spotify.com/v1/tracks/1aQdz8ZXLgBOqs4Vcddeko',
#   'https://api.spotify.com/v1/audio-analysis/1aQdz8ZXLgBOqs4Vcddeko',
#   221573,
#   4],
#  ['Clueso',
#   'Text und Ton (Remastered 2014)',
#   'spotify:album:4eNfhKwooJrEQf3rQExao2',
#   'Master Girl - Remastered 2014',
#   '2001-04-30',
#   0.66,
#   0.666,
#   1,
#   -7.656,
#   1,
#   0.0706,
#   0.707,
#   0.908,
#   0.159,
#   0.749,
#   158.011,
#   'audio_features',
#   '647XDosRlyTSBVzlP35zZO',
#   'spotify:track:647XDosRlyTSBVzlP35zZO',
#   'https://api.spotify.com/v1/tracks/647XDosRlyTSBVzlP35zZO',
#   'https://api.spotify.com/v1/audio-analysis/647XDosRlyTSBVzlP35zZO',
#   111133,
#   4],
#  ['Clueso',
#   'Text und Ton (Remastered 2014)',
#   'spotify:album:4eNfhKwooJrEQf3rQExao2',
#   'Spiel da nich mit - Remastered 2014',
#   '2001-04-30',
#   0.657,
#   0.852,
#   11,
#   -7.405,
#   0,
#   0.364,
#   0.0614,
#   1.37e-05,
#   0.0815,
#   0.255,
#   168.972,
#   'audio_features',
#   '3IZDWCuauLon6VpaMC684x',
#   'spotify:track:3IZDWCuauLon6VpaMC684x',
#   'https://api.spotify.com/v1/tracks/3IZDWCuauLon6VpaMC684x',
#   'https://api.spotify.com/v1/audio-analysis/3IZDWCuauLon6VpaMC684x',
#   255693,
#   4],
#  ['Clueso',
#   'Text und Ton (Remastered 2014)',
#   'spotify:album:4eNfhKwooJrEQf3rQExao2',
#   'Text und Ton - Remastered 2014',
#   '2001-04-30',
#   0.665,
#   0.375,
#   8,
#   -15.536,
#   0,
#   0.138,
#   0.416,
#   0.334,
#   0.151,
#   0.788,
#   162.324,
#   'audio_features',
#   '2k6l2IHuXeGO1y8sFXQNpS',
#   'spotify:track:2k6l2IHuXeGO1y8sFXQNpS',
#   'https://api.spotify.com/v1/tracks/2k6l2IHuXeGO1y8sFXQNpS',
#   'https://api.spotify.com/v1/audio-analysis/2k6l2IHuXeGO1y8sFXQNpS',
#   53573,
#   4],
#  ['Clueso',
#   'Text und Ton (Remastered 2014)',
#   'spotify:album:4eNfhKwooJrEQf3rQExao2',
#   'Migrant Souls (feat. Layguuan Sharkie & MC Metaphysics) - Remastered 2014',
#   '2001-04-30',
#   0.818,
#   0.518,
#   2,
#   -8.7,
#   1,
#   0.227,
#   0.531,
#   4.59e-05,
#   0.255,
#   0.56,
#   90.898,
#   'audio_features',
#   '4wyHkWYPqKIsWG2C5ek6MR',
#   'spotify:track:4wyHkWYPqKIsWG2C5ek6MR',
#   'https://api.spotify.com/v1/tracks/4wyHkWYPqKIsWG2C5ek6MR',
#   'https://api.spotify.com/v1/audio-analysis/4wyHkWYPqKIsWG2C5ek6MR',
#   213067,
#   4],
#  ['Clueso',
#   'Text und Ton (Remastered 2014)',
#   'spotify:album:4eNfhKwooJrEQf3rQExao2',
#   'Auf und ab - Remastered 2014',
#   '2001-04-30',
#   0.707,
#   0.592,
#   5,
#   -8.077,
#   0,
#   0.364,
#   0.415,
#   0.00281,
#   0.382,
#   0.421,
#   92.565,
#   'audio_features',
#   '78TXe0EE44AWj7PGo1dugL',
#   'spotify:track:78TXe0EE44AWj7PGo1dugL',
#   'https://api.spotify.com/v1/tracks/78TXe0EE44AWj7PGo1dugL',
#   'https://api.spotify.com/v1/audio-analysis/78TXe0EE44AWj7PGo1dugL',
#   219867,
#   4]]

# %%
def df_tracks(tracks):
    
    '''
    Takes the output of artist_tracks (i.e. a list of lists),
    puts it in a dataframe and formats it.
    '''

    df = pd.DataFrame(tracks, columns=['artist',
     'album_name',
     'album_uri',
     'track',
     'release_date'] + list(sp.audio_features('7tr2za8SQg2CI8EDgrdtNl')[0].keys()))

    df.rename(columns={'uri':'song_uri'}, inplace=True)

    df.drop_duplicates(subset=['artist', 'track', 'release_date'], inplace=True)

    # Reorder the cols to have identifiers first, auditory features last
    cols = ['artist', 'album_name', 'album_uri', 'track', 'release_date', 'id', 'song_uri', 'track_href',
     'analysis_url', 'type', 'danceability', 'energy', 'key',  'loudness', 'mode', 'speechiness',
     'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature']

    df = df[cols]
    
    return df

# %%
# figure out how your can feed in several songs and artists

# %%
#transform dic into a list

# %% [markdown]
# # Installing Spotipy

# %% [markdown]
# In order to use the Spotify API (SpotiPy) we will have to create an account in Spotify and follow these steps. Once we have done it we will start initializing the API and look at the search method for which we can introduce a "query" q, in this example we will try it with Lady Gaga:

# %%
#!pip install spotipy

# %% [markdown]
# ## Loading credentials from another config file

# %%
import config

# %% [markdown]
# ## Starting with Spotify API

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials

#client_id = "5622c0f1f94243ffa051cfbdf4734578"
#client_secret = "5622c0f1f94243ffa051cfbdf4734578"

#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# The "sp" variable has two useful funtions:
# The first usefull function is:
# .search(q='',limit=n)
# .search(q="track:"+song_name+" artist:"+artist_name,limit=5) to restrict to a song name and artist.
# Where the "q" keyword is the query you want to perform on spotify: song_name, artist,...
# while The "limit" keyword will limit the number of returned results.
#
# The second usefull function is:
# .audio_features([URL|URI|ID])
# which returns some 'features of the song', that after cleanup, we can use in order to characterize a song.

results = sp.search(q='Billie Eilish', limit=5,market="GB")
results
#json_results = json.dumps(results, ensure_ascii=True)
#json_results
#results['tracks']['items'][0]['album']
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Billie+Eilish&type=track&market=GB&offset=0&limit=5',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#        'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#        'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#        'name': 'Billie Eilish',
#        'type': 'artist',
#        'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#      'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#      'id': '0JGOiO34nwfUdDrD612dOp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#        'width': 64}],
#      'name': 'Happier Than Ever',
#      'release_date': '2021-07-30',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'disc_number': 1,
#     'duration_ms': 298899,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM72105936'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4RVwu0g32PAqgUiJoXsdF8'},
#     'href': 'https://api.spotify.com/v1/tracks/4RVwu0g32PAqgUiJoXsdF8',
#     'id': '4RVwu0g32PAqgUiJoXsdF8',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Happier Than Ever',
#     'popularity': 94,
#     'preview_url': None,
#     'track_number': 15,
#     'type': 'track',
#     'uri': 'spotify:track:4RVwu0g32PAqgUiJoXsdF8'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0zt5rQZyk3KegttfgPi30G'},
#      'href': 'https://api.spotify.com/v1/albums/0zt5rQZyk3KegttfgPi30G',
#      'id': '0zt5rQZyk3KegttfgPi30G',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a617aa364f885076114906f9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a617aa364f885076114906f9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a617aa364f885076114906f9',
#        'width': 64}],
#      'name': 'ESTATE 2021 HITS',
#      'release_date': '2021-08-06',
#      'release_date_precision': 'day',
#      'total_tracks': 31,
#      'type': 'album',
#      'uri': 'spotify:album:0zt5rQZyk3KegttfgPi30G'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'disc_number': 1,
#     'duration_ms': 199931,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71815958'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1i3fTnSg2X03MWLEt411Eb'},
#     'href': 'https://api.spotify.com/v1/tracks/1i3fTnSg2X03MWLEt411Eb',
#     'id': '1i3fTnSg2X03MWLEt411Eb',
#     'is_local': False,
#     'is_playable': True,
#     'name': "when the party's over",
#     'popularity': 18,
#     'preview_url': None,
#     'track_number': 28,
#     'type': 'track',
#     'uri': 'spotify:track:1i3fTnSg2X03MWLEt411Eb'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#        'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#        'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#        'name': 'Billie Eilish',
#        'type': 'artist',
#        'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6LuN9FCkKOj5PcnpouEgny'},
#        'href': 'https://api.spotify.com/v1/artists/6LuN9FCkKOj5PcnpouEgny',
#        'id': '6LuN9FCkKOj5PcnpouEgny',
#        'name': 'Khalid',
#        'type': 'artist',
#        'uri': 'spotify:artist:6LuN9FCkKOj5PcnpouEgny'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2sBB17RXTamvj7Ncps15AK'},
#      'href': 'https://api.spotify.com/v1/albums/2sBB17RXTamvj7Ncps15AK',
#      'id': '2sBB17RXTamvj7Ncps15AK',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738a3f0a3ca7929dea23cd274c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028a3f0a3ca7929dea23cd274c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518a3f0a3ca7929dea23cd274c',
#        'width': 64}],
#      'name': 'lovely (with Khalid)',
#      'release_date': '2018-04-19',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2sBB17RXTamvj7Ncps15AK'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6LuN9FCkKOj5PcnpouEgny'},
#       'href': 'https://api.spotify.com/v1/artists/6LuN9FCkKOj5PcnpouEgny',
#       'id': '6LuN9FCkKOj5PcnpouEgny',
#       'name': 'Khalid',
#       'type': 'artist',
#       'uri': 'spotify:artist:6LuN9FCkKOj5PcnpouEgny'}],
#     'disc_number': 1,
#     'duration_ms': 200185,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71804190'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0u2P5u6lvoDfwTYjAADbn4'},
#     'href': 'https://api.spotify.com/v1/tracks/0u2P5u6lvoDfwTYjAADbn4',
#     'id': '0u2P5u6lvoDfwTYjAADbn4',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'lovely (with Khalid)',
#     'popularity': 86,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0u2P5u6lvoDfwTYjAADbn4'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#        'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#        'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#        'name': 'Billie Eilish',
#        'type': 'artist',
#        'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#      'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#      'id': '0JGOiO34nwfUdDrD612dOp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#        'width': 64}],
#      'name': 'Happier Than Ever',
#      'release_date': '2021-07-30',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'disc_number': 1,
#     'duration_ms': 196730,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM72105927'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2KnuaZYoGzDoHiBTNYOTXG'},
#     'href': 'https://api.spotify.com/v1/tracks/2KnuaZYoGzDoHiBTNYOTXG',
#     'id': '2KnuaZYoGzDoHiBTNYOTXG',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Billie Bossa Nova',
#     'popularity': 81,
#     'preview_url': None,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:2KnuaZYoGzDoHiBTNYOTXG'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6CcHGSgeYoXO72rMwBeZ2V'},
#        'href': 'https://api.spotify.com/v1/artists/6CcHGSgeYoXO72rMwBeZ2V',
#        'id': '6CcHGSgeYoXO72rMwBeZ2V',
#        'name': 'Carl Davis',
#        'type': 'artist',
#        'uri': 'spotify:artist:6CcHGSgeYoXO72rMwBeZ2V'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1AZTVGOm7t5zkOcweZBivz'},
#        'href': 'https://api.spotify.com/v1/artists/1AZTVGOm7t5zkOcweZBivz',
#        'id': '1AZTVGOm7t5zkOcweZBivz',
#        'name': 'Leif Segerstam',
#        'type': 'artist',
#        'uri': 'spotify:artist:1AZTVGOm7t5zkOcweZBivz'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Veude8V6p7YxBNIQld13F'},
#        'href': 'https://api.spotify.com/v1/artists/5Veude8V6p7YxBNIQld13F',
#        'id': '5Veude8V6p7YxBNIQld13F',
#        'name': 'György Lehel',
#        'type': 'artist',
#        'uri': 'spotify:artist:5Veude8V6p7YxBNIQld13F'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2IpitDGspEKl8VaB3qd4ya'},
#        'href': 'https://api.spotify.com/v1/artists/2IpitDGspEKl8VaB3qd4ya',
#        'id': '2IpitDGspEKl8VaB3qd4ya',
#        'name': 'Zdeněk Košler',
#        'type': 'artist',
#        'uri': 'spotify:artist:2IpitDGspEKl8VaB3qd4ya'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/68tBK9r9zdViB8V73G5SA9'},
#        'href': 'https://api.spotify.com/v1/artists/68tBK9r9zdViB8V73G5SA9',
#        'id': '68tBK9r9zdViB8V73G5SA9',
#        'name': 'Richard Hayman',
#        'type': 'artist',
#        'uri': 'spotify:artist:68tBK9r9zdViB8V73G5SA9'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/27kuIxOlYJi0Wt6dH7Xe5Y'},
#        'href': 'https://api.spotify.com/v1/artists/27kuIxOlYJi0Wt6dH7Xe5Y',
#        'id': '27kuIxOlYJi0Wt6dH7Xe5Y',
#        'name': 'Adrian Leaper',
#        'type': 'artist',
#        'uri': 'spotify:artist:27kuIxOlYJi0Wt6dH7Xe5Y'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2enPrYI2oHc6IWCuCmLfX9'},
#        'href': 'https://api.spotify.com/v1/artists/2enPrYI2oHc6IWCuCmLfX9',
#        'id': '2enPrYI2oHc6IWCuCmLfX9',
#        'name': 'Alexander Rahbari',
#        'type': 'artist',
#        'uri': 'spotify:artist:2enPrYI2oHc6IWCuCmLfX9'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/12eE2b1achxTzCwb8lcx6l'},
#        'href': 'https://api.spotify.com/v1/artists/12eE2b1achxTzCwb8lcx6l',
#        'id': '12eE2b1achxTzCwb8lcx6l',
#        'name': 'Kenneth Jean',
#        'type': 'artist',
#        'uri': 'spotify:artist:12eE2b1achxTzCwb8lcx6l'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2V2ZxZB2Vy0JDoHcyNWQC8'},
#        'href': 'https://api.spotify.com/v1/artists/2V2ZxZB2Vy0JDoHcyNWQC8',
#        'id': '2V2ZxZB2Vy0JDoHcyNWQC8',
#        'name': 'Uwe Mund',
#        'type': 'artist',
#        'uri': 'spotify:artist:2V2ZxZB2Vy0JDoHcyNWQC8'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2eqNsX66FyKi3bnl1KSqZz'},
#        'href': 'https://api.spotify.com/v1/artists/2eqNsX66FyKi3bnl1KSqZz',
#        'id': '2eqNsX66FyKi3bnl1KSqZz',
#        'name': 'Béla Drahos',
#        'type': 'artist',
#        'uri': 'spotify:artist:2eqNsX66FyKi3bnl1KSqZz'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6dg4xqm9InvCIZwVil23Yg'},
#        'href': 'https://api.spotify.com/v1/artists/6dg4xqm9InvCIZwVil23Yg',
#        'id': '6dg4xqm9InvCIZwVil23Yg',
#        'name': 'James DePreist',
#        'type': 'artist',
#        'uri': 'spotify:artist:6dg4xqm9InvCIZwVil23Yg'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7G5Z4L6m1LGBJ42aMS0zUL'},
#        'href': 'https://api.spotify.com/v1/artists/7G5Z4L6m1LGBJ42aMS0zUL',
#        'id': '7G5Z4L6m1LGBJ42aMS0zUL',
#        'name': 'Kenneth Schermerhorn',
#        'type': 'artist',
#        'uri': 'spotify:artist:7G5Z4L6m1LGBJ42aMS0zUL'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/09Ruas7vF7YHnor4to4Eyo'},
#        'href': 'https://api.spotify.com/v1/artists/09Ruas7vF7YHnor4to4Eyo',
#        'id': '09Ruas7vF7YHnor4to4Eyo',
#        'name': 'Richard Edlinger',
#        'type': 'artist',
#        'uri': 'spotify:artist:09Ruas7vF7YHnor4to4Eyo'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0lluGWFB8hZ6HFktcH6kkr'},
#        'href': 'https://api.spotify.com/v1/artists/0lluGWFB8hZ6HFktcH6kkr',
#        'id': '0lluGWFB8hZ6HFktcH6kkr',
#        'name': 'Marin Alsop',
#        'type': 'artist',
#        'uri': 'spotify:artist:0lluGWFB8hZ6HFktcH6kkr'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6Dkj1lYjjOCsGB170vlWc6'},
#        'href': 'https://api.spotify.com/v1/artists/6Dkj1lYjjOCsGB170vlWc6',
#        'id': '6Dkj1lYjjOCsGB170vlWc6',
#        'name': 'Michael Halasz',
#        'type': 'artist',
#        'uri': 'spotify:artist:6Dkj1lYjjOCsGB170vlWc6'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0eaRvM9NkpTV399cyiZUwf'},
#        'href': 'https://api.spotify.com/v1/artists/0eaRvM9NkpTV399cyiZUwf',
#        'id': '0eaRvM9NkpTV399cyiZUwf',
#        'name': 'Jeremy Summerly',
#        'type': 'artist',
#        'uri': 'spotify:artist:0eaRvM9NkpTV399cyiZUwf'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2A5MfDq59CDZg119HhLcT7'},
#        'href': 'https://api.spotify.com/v1/artists/2A5MfDq59CDZg119HhLcT7',
#        'id': '2A5MfDq59CDZg119HhLcT7',
#        'name': 'Helmut Muller-Bruhl',
#        'type': 'artist',
#        'uri': 'spotify:artist:2A5MfDq59CDZg119HhLcT7'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/10ZoutqXuCmFqOKwZdZs99'},
#        'href': 'https://api.spotify.com/v1/artists/10ZoutqXuCmFqOKwZdZs99',
#        'id': '10ZoutqXuCmFqOKwZdZs99',
#        'name': 'Morten Schuldt-Jensen',
#        'type': 'artist',
#        'uri': 'spotify:artist:10ZoutqXuCmFqOKwZdZs99'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3QEztQUVjL5FGxXuP70mJQ'},
#        'href': 'https://api.spotify.com/v1/artists/3QEztQUVjL5FGxXuP70mJQ',
#        'id': '3QEztQUVjL5FGxXuP70mJQ',
#        'name': 'Johannes Wildner',
#        'type': 'artist',
#        'uri': 'spotify:artist:3QEztQUVjL5FGxXuP70mJQ'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0yVP6JP8tiC5SzUqCRv4w7'},
#        'href': 'https://api.spotify.com/v1/artists/0yVP6JP8tiC5SzUqCRv4w7',
#        'id': '0yVP6JP8tiC5SzUqCRv4w7',
#        'name': 'William Stromberg',
#        'type': 'artist',
#        'uri': 'spotify:artist:0yVP6JP8tiC5SzUqCRv4w7'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6jKsnWXyWgE3jyC0Cs0Cdb'},
#        'href': 'https://api.spotify.com/v1/artists/6jKsnWXyWgE3jyC0Cs0Cdb',
#        'id': '6jKsnWXyWgE3jyC0Cs0Cdb',
#        'name': 'Dmitry Yablonsky',
#        'type': 'artist',
#        'uri': 'spotify:artist:6jKsnWXyWgE3jyC0Cs0Cdb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4RqJLaVkFhOYsn72FUS2iQ'},
#      'href': 'https://api.spotify.com/v1/albums/4RqJLaVkFhOYsn72FUS2iQ',
#      'id': '4RqJLaVkFhOYsn72FUS2iQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736f535cfea3ddfb09c19c8f47',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026f535cfea3ddfb09c19c8f47',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516f535cfea3ddfb09c19c8f47',
#        'width': 64}],
#      'name': 'Classical Music: 50 of the Best Film Classics',
#      'release_date': '2012-10-01',
#      'release_date_precision': 'day',
#      'total_tracks': 50,
#      'type': 'album',
#      'uri': 'spotify:album:4RqJLaVkFhOYsn72FUS2iQ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3MKCzCnpzw3TjUYs2v7vDA'},
#       'href': 'https://api.spotify.com/v1/artists/3MKCzCnpzw3TjUYs2v7vDA',
#       'id': '3MKCzCnpzw3TjUYs2v7vDA',
#       'name': 'Pyotr Ilyich Tchaikovsky',
#       'type': 'artist',
#       'uri': 'spotify:artist:3MKCzCnpzw3TjUYs2v7vDA'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0DJZPK3nRWESIS0yexi6Qi'},
#       'href': 'https://api.spotify.com/v1/artists/0DJZPK3nRWESIS0yexi6Qi',
#       'id': '0DJZPK3nRWESIS0yexi6Qi',
#       'name': 'Russian State Symphony Orchestra',
#       'type': 'artist',
#       'uri': 'spotify:artist:0DJZPK3nRWESIS0yexi6Qi'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6jKsnWXyWgE3jyC0Cs0Cdb'},
#       'href': 'https://api.spotify.com/v1/artists/6jKsnWXyWgE3jyC0Cs0Cdb',
#       'id': '6jKsnWXyWgE3jyC0Cs0Cdb',
#       'name': 'Dmitry Yablonsky',
#       'type': 'artist',
#       'uri': 'spotify:artist:6jKsnWXyWgE3jyC0Cs0Cdb'}],
#     'disc_number': 1,
#     'duration_ms': 138493,
#     'explicit': False,
#     'external_ids': {'isrc': 'HKI190201219'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5mr7bInpz2uiHNT5Us2kfj'},
#     'href': 'https://api.spotify.com/v1/tracks/5mr7bInpz2uiHNT5Us2kfj',
#     'id': '5mr7bInpz2uiHNT5Us2kfj',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Swan Lake, Op. 20, Act II No. 10: Scene, "Swan Theme" (Billy Elliot/Black Swan)',
#     'popularity': 13,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0f99211cd972347f5bf4b710fd8c84a80c40a2c7?cid=56e8c847e9974517952ef0d040f2a78b',
#     'track_number': 46,
#     'type': 'track',
#     'uri': 'spotify:track:5mr7bInpz2uiHNT5Us2kfj'}],
#   'limit': 5,
#   'next': 'https://api.spotify.com/v1/search?query=Billie+Eilish&type=track&market=GB&offset=5&limit=5',
#   'offset': 0,
#   'previous': None,
#   'total': 1232}}

# %% [markdown]
# {'spotify': 'https://open.spotify.com/track/4O2N861eOnF9q8EtpH8IJu'}

# %%
type(results)
# Out:
# dict

# %%
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
results['tracks'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
import pprint

pprint.pprint(results)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Billie+Eilish&type=track&market=GB&offset=0&limit=5',
#             'items': [{'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#                                               'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#                                               'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#                                               'name': 'Billie Eilish',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#                                  'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#                                  'id': '0JGOiO34nwfUdDrD612dOp',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#                                              'width': 64}],
#                                  'name': 'Happier Than Ever',
#                                  'release_date': '2021-07-30',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 16,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#                                     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#                                     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#                                     'name': 'Billie Eilish',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#                        'disc_number': 1,
#                        'duration_ms': 298899,
#                        'explicit': True,
#                        'external_ids': {'isrc': 'USUM72105936'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/4RVwu0g32PAqgUiJoXsdF8'},
#                        'href': 'https://api.spotify.com/v1/tracks/4RVwu0g32PAqgUiJoXsdF8',
#                        'id': '4RVwu0g32PAqgUiJoXsdF8',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Happier Than Ever',
#                        'popularity': 94,
#                        'preview_url': None,
#                        'track_number': 15,
#                        'type': 'track',
#                        'uri': 'spotify:track:4RVwu0g32PAqgUiJoXsdF8'},
#                       {'album': {'album_type': 'compilation',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#                                               'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#                                               'id': '0LyfQWJT6nXafLPZqxe9Of',
#                                               'name': 'Various Artists',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/0zt5rQZyk3KegttfgPi30G'},
#                                  'href': 'https://api.spotify.com/v1/albums/0zt5rQZyk3KegttfgPi30G',
#                                  'id': '0zt5rQZyk3KegttfgPi30G',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273a617aa364f885076114906f9',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02a617aa364f885076114906f9',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851a617aa364f885076114906f9',
#                                              'width': 64}],
#                                  'name': 'ESTATE 2021 HITS',
#                                  'release_date': '2021-08-06',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 31,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:0zt5rQZyk3KegttfgPi30G'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#                                     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#                                     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#                                     'name': 'Billie Eilish',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#                        'disc_number': 1,
#                        'duration_ms': 199931,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'USUM71815958'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/1i3fTnSg2X03MWLEt411Eb'},
#                        'href': 'https://api.spotify.com/v1/tracks/1i3fTnSg2X03MWLEt411Eb',
#                        'id': '1i3fTnSg2X03MWLEt411Eb',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': "when the party's over",
#                        'popularity': 18,
#                        'preview_url': None,
#                        'track_number': 28,
#                        'type': 'track',
#                        'uri': 'spotify:track:1i3fTnSg2X03MWLEt411Eb'},
#                       {'album': {'album_type': 'single',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#                                               'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#                                               'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#                                               'name': 'Billie Eilish',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/6LuN9FCkKOj5PcnpouEgny'},
#                                               'href': 'https://api.spotify.com/v1/artists/6LuN9FCkKOj5PcnpouEgny',
#                                               'id': '6LuN9FCkKOj5PcnpouEgny',
#                                               'name': 'Khalid',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:6LuN9FCkKOj5PcnpouEgny'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/2sBB17RXTamvj7Ncps15AK'},
#                                  'href': 'https://api.spotify.com/v1/albums/2sBB17RXTamvj7Ncps15AK',
#                                  'id': '2sBB17RXTamvj7Ncps15AK',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b2738a3f0a3ca7929dea23cd274c',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e028a3f0a3ca7929dea23cd274c',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d000048518a3f0a3ca7929dea23cd274c',
#                                              'width': 64}],
#                                  'name': 'lovely (with Khalid)',
#                                  'release_date': '2018-04-19',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 1,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:2sBB17RXTamvj7Ncps15AK'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#                                     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#                                     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#                                     'name': 'Billie Eilish',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#                                    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6LuN9FCkKOj5PcnpouEgny'},
#                                     'href': 'https://api.spotify.com/v1/artists/6LuN9FCkKOj5PcnpouEgny',
#                                     'id': '6LuN9FCkKOj5PcnpouEgny',
#                                     'name': 'Khalid',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:6LuN9FCkKOj5PcnpouEgny'}],
#                        'disc_number': 1,
#                        'duration_ms': 200185,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'USUM71804190'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/0u2P5u6lvoDfwTYjAADbn4'},
#                        'href': 'https://api.spotify.com/v1/tracks/0u2P5u6lvoDfwTYjAADbn4',
#                        'id': '0u2P5u6lvoDfwTYjAADbn4',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'lovely (with Khalid)',
#                        'popularity': 86,
#                        'preview_url': None,
#                        'track_number': 1,
#                        'type': 'track',
#                        'uri': 'spotify:track:0u2P5u6lvoDfwTYjAADbn4'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#                                               'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#                                               'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#                                               'name': 'Billie Eilish',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#                                  'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#                                  'id': '0JGOiO34nwfUdDrD612dOp',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#                                              'width': 64}],
#                                  'name': 'Happier Than Ever',
#                                  'release_date': '2021-07-30',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 16,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#                                     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#                                     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#                                     'name': 'Billie Eilish',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#                        'disc_number': 1,
#                        'duration_ms': 196730,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'USUM72105927'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/2KnuaZYoGzDoHiBTNYOTXG'},
#                        'href': 'https://api.spotify.com/v1/tracks/2KnuaZYoGzDoHiBTNYOTXG',
#                        'id': '2KnuaZYoGzDoHiBTNYOTXG',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Billie Bossa Nova',
#                        'popularity': 81,
#                        'preview_url': None,
#                        'track_number': 3,
#                        'type': 'track',
#                        'uri': 'spotify:track:2KnuaZYoGzDoHiBTNYOTXG'},
#                       {'album': {'album_type': 'compilation',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#                                               'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#                                               'id': '0LyfQWJT6nXafLPZqxe9Of',
#                                               'name': 'Various Artists',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/6CcHGSgeYoXO72rMwBeZ2V'},
#                                               'href': 'https://api.spotify.com/v1/artists/6CcHGSgeYoXO72rMwBeZ2V',
#                                               'id': '6CcHGSgeYoXO72rMwBeZ2V',
#                                               'name': 'Carl Davis',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:6CcHGSgeYoXO72rMwBeZ2V'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/1AZTVGOm7t5zkOcweZBivz'},
#                                               'href': 'https://api.spotify.com/v1/artists/1AZTVGOm7t5zkOcweZBivz',
#                                               'id': '1AZTVGOm7t5zkOcweZBivz',
#                                               'name': 'Leif Segerstam',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:1AZTVGOm7t5zkOcweZBivz'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Veude8V6p7YxBNIQld13F'},
#                                               'href': 'https://api.spotify.com/v1/artists/5Veude8V6p7YxBNIQld13F',
#                                               'id': '5Veude8V6p7YxBNIQld13F',
#                                               'name': 'György Lehel',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:5Veude8V6p7YxBNIQld13F'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/2IpitDGspEKl8VaB3qd4ya'},
#                                               'href': 'https://api.spotify.com/v1/artists/2IpitDGspEKl8VaB3qd4ya',
#                                               'id': '2IpitDGspEKl8VaB3qd4ya',
#                                               'name': 'Zdeněk Košler',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:2IpitDGspEKl8VaB3qd4ya'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/68tBK9r9zdViB8V73G5SA9'},
#                                               'href': 'https://api.spotify.com/v1/artists/68tBK9r9zdViB8V73G5SA9',
#                                               'id': '68tBK9r9zdViB8V73G5SA9',
#                                               'name': 'Richard Hayman',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:68tBK9r9zdViB8V73G5SA9'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/27kuIxOlYJi0Wt6dH7Xe5Y'},
#                                               'href': 'https://api.spotify.com/v1/artists/27kuIxOlYJi0Wt6dH7Xe5Y',
#                                               'id': '27kuIxOlYJi0Wt6dH7Xe5Y',
#                                               'name': 'Adrian Leaper',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:27kuIxOlYJi0Wt6dH7Xe5Y'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/2enPrYI2oHc6IWCuCmLfX9'},
#                                               'href': 'https://api.spotify.com/v1/artists/2enPrYI2oHc6IWCuCmLfX9',
#                                               'id': '2enPrYI2oHc6IWCuCmLfX9',
#                                               'name': 'Alexander Rahbari',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:2enPrYI2oHc6IWCuCmLfX9'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/12eE2b1achxTzCwb8lcx6l'},
#                                               'href': 'https://api.spotify.com/v1/artists/12eE2b1achxTzCwb8lcx6l',
#                                               'id': '12eE2b1achxTzCwb8lcx6l',
#                                               'name': 'Kenneth Jean',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:12eE2b1achxTzCwb8lcx6l'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/2V2ZxZB2Vy0JDoHcyNWQC8'},
#                                               'href': 'https://api.spotify.com/v1/artists/2V2ZxZB2Vy0JDoHcyNWQC8',
#                                               'id': '2V2ZxZB2Vy0JDoHcyNWQC8',
#                                               'name': 'Uwe Mund',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:2V2ZxZB2Vy0JDoHcyNWQC8'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/2eqNsX66FyKi3bnl1KSqZz'},
#                                               'href': 'https://api.spotify.com/v1/artists/2eqNsX66FyKi3bnl1KSqZz',
#                                               'id': '2eqNsX66FyKi3bnl1KSqZz',
#                                               'name': 'Béla Drahos',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:2eqNsX66FyKi3bnl1KSqZz'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/6dg4xqm9InvCIZwVil23Yg'},
#                                               'href': 'https://api.spotify.com/v1/artists/6dg4xqm9InvCIZwVil23Yg',
#                                               'id': '6dg4xqm9InvCIZwVil23Yg',
#                                               'name': 'James DePreist',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:6dg4xqm9InvCIZwVil23Yg'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/7G5Z4L6m1LGBJ42aMS0zUL'},
#                                               'href': 'https://api.spotify.com/v1/artists/7G5Z4L6m1LGBJ42aMS0zUL',
#                                               'id': '7G5Z4L6m1LGBJ42aMS0zUL',
#                                               'name': 'Kenneth Schermerhorn',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:7G5Z4L6m1LGBJ42aMS0zUL'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/09Ruas7vF7YHnor4to4Eyo'},
#                                               'href': 'https://api.spotify.com/v1/artists/09Ruas7vF7YHnor4to4Eyo',
#                                               'id': '09Ruas7vF7YHnor4to4Eyo',
#                                               'name': 'Richard Edlinger',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:09Ruas7vF7YHnor4to4Eyo'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/0lluGWFB8hZ6HFktcH6kkr'},
#                                               'href': 'https://api.spotify.com/v1/artists/0lluGWFB8hZ6HFktcH6kkr',
#                                               'id': '0lluGWFB8hZ6HFktcH6kkr',
#                                               'name': 'Marin Alsop',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:0lluGWFB8hZ6HFktcH6kkr'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/6Dkj1lYjjOCsGB170vlWc6'},
#                                               'href': 'https://api.spotify.com/v1/artists/6Dkj1lYjjOCsGB170vlWc6',
#                                               'id': '6Dkj1lYjjOCsGB170vlWc6',
#                                               'name': 'Michael Halasz',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:6Dkj1lYjjOCsGB170vlWc6'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/0eaRvM9NkpTV399cyiZUwf'},
#                                               'href': 'https://api.spotify.com/v1/artists/0eaRvM9NkpTV399cyiZUwf',
#                                               'id': '0eaRvM9NkpTV399cyiZUwf',
#                                               'name': 'Jeremy Summerly',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:0eaRvM9NkpTV399cyiZUwf'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/2A5MfDq59CDZg119HhLcT7'},
#                                               'href': 'https://api.spotify.com/v1/artists/2A5MfDq59CDZg119HhLcT7',
#                                               'id': '2A5MfDq59CDZg119HhLcT7',
#                                               'name': 'Helmut Muller-Bruhl',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:2A5MfDq59CDZg119HhLcT7'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/10ZoutqXuCmFqOKwZdZs99'},
#                                               'href': 'https://api.spotify.com/v1/artists/10ZoutqXuCmFqOKwZdZs99',
#                                               'id': '10ZoutqXuCmFqOKwZdZs99',
#                                               'name': 'Morten Schuldt-Jensen',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:10ZoutqXuCmFqOKwZdZs99'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/3QEztQUVjL5FGxXuP70mJQ'},
#                                               'href': 'https://api.spotify.com/v1/artists/3QEztQUVjL5FGxXuP70mJQ',
#                                               'id': '3QEztQUVjL5FGxXuP70mJQ',
#                                               'name': 'Johannes Wildner',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:3QEztQUVjL5FGxXuP70mJQ'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/0yVP6JP8tiC5SzUqCRv4w7'},
#                                               'href': 'https://api.spotify.com/v1/artists/0yVP6JP8tiC5SzUqCRv4w7',
#                                               'id': '0yVP6JP8tiC5SzUqCRv4w7',
#                                               'name': 'William Stromberg',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:0yVP6JP8tiC5SzUqCRv4w7'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/6jKsnWXyWgE3jyC0Cs0Cdb'},
#                                               'href': 'https://api.spotify.com/v1/artists/6jKsnWXyWgE3jyC0Cs0Cdb',
#                                               'id': '6jKsnWXyWgE3jyC0Cs0Cdb',
#                                               'name': 'Dmitry Yablonsky',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:6jKsnWXyWgE3jyC0Cs0Cdb'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/4RqJLaVkFhOYsn72FUS2iQ'},
#                                  'href': 'https://api.spotify.com/v1/albums/4RqJLaVkFhOYsn72FUS2iQ',
#                                  'id': '4RqJLaVkFhOYsn72FUS2iQ',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b2736f535cfea3ddfb09c19c8f47',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e026f535cfea3ddfb09c19c8f47',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d000048516f535cfea3ddfb09c19c8f47',
#                                              'width': 64}],
#                                  'name': 'Classical Music: 50 of the Best Film '
#                                          'Classics',
#                                  'release_date': '2012-10-01',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 50,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:4RqJLaVkFhOYsn72FUS2iQ'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3MKCzCnpzw3TjUYs2v7vDA'},
#                                     'href': 'https://api.spotify.com/v1/artists/3MKCzCnpzw3TjUYs2v7vDA',
#                                     'id': '3MKCzCnpzw3TjUYs2v7vDA',
#                                     'name': 'Pyotr Ilyich Tchaikovsky',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:3MKCzCnpzw3TjUYs2v7vDA'},
#                                    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0DJZPK3nRWESIS0yexi6Qi'},
#                                     'href': 'https://api.spotify.com/v1/artists/0DJZPK3nRWESIS0yexi6Qi',
#                                     'id': '0DJZPK3nRWESIS0yexi6Qi',
#                                     'name': 'Russian State Symphony Orchestra',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:0DJZPK3nRWESIS0yexi6Qi'},
#                                    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6jKsnWXyWgE3jyC0Cs0Cdb'},
#                                     'href': 'https://api.spotify.com/v1/artists/6jKsnWXyWgE3jyC0Cs0Cdb',
#                                     'id': '6jKsnWXyWgE3jyC0Cs0Cdb',
#                                     'name': 'Dmitry Yablonsky',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:6jKsnWXyWgE3jyC0Cs0Cdb'}],
#                        'disc_number': 1,
#                        'duration_ms': 138493,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'HKI190201219'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/5mr7bInpz2uiHNT5Us2kfj'},
#                        'href': 'https://api.spotify.com/v1/tracks/5mr7bInpz2uiHNT5Us2kfj',
#                        'id': '5mr7bInpz2uiHNT5Us2kfj',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Swan Lake, Op. 20, Act II No. 10: Scene, "Swan '
#                                'Theme" (Billy Elliot/Black Swan)',
#                        'popularity': 13,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/0f99211cd972347f5bf4b710fd8c84a80c40a2c7?cid=d4726b15e5b34b0fa3c825aaea90d658',
#                        'track_number': 46,
#                        'type': 'track',
#                        'uri': 'spotify:track:5mr7bInpz2uiHNT5Us2kfj'}],
#             'limit': 5,
#             'next': 'https://api.spotify.com/v1/search?query=Billie+Eilish&type=track&market=GB&offset=5&limit=5',
#             'offset': 0,
#             'previous': None,
#             'total': 1232}}

# %%
results['tracks']['items']
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#    'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#    'id': '0JGOiO34nwfUdDrD612dOp',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#      'width': 64}],
#    'name': 'Happier Than Ever',
#    'release_date': '2021-07-30',
#    'release_date_precision': 'day',
#    'total_tracks': 16,
#    'type': 'album',
#    'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'disc_number': 1,
#   'duration_ms': 298899,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUM72105936'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4RVwu0g32PAqgUiJoXsdF8'},
#   'href': 'https://api.spotify.com/v1/tracks/4RVwu0g32PAqgUiJoXsdF8',
#   'id': '4RVwu0g32PAqgUiJoXsdF8',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Happier Than Ever',
#   'popularity': 94,
#   'preview_url': None,
#   'track_number': 15,
#   'type': 'track',
#   'uri': 'spotify:track:4RVwu0g32PAqgUiJoXsdF8'},
#  {'album': {'album_type': 'compilation',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#      'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#      'id': '0LyfQWJT6nXafLPZqxe9Of',
#      'name': 'Various Artists',
#      'type': 'artist',
#      'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0zt5rQZyk3KegttfgPi30G'},
#    'href': 'https://api.spotify.com/v1/albums/0zt5rQZyk3KegttfgPi30G',
#    'id': '0zt5rQZyk3KegttfgPi30G',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273a617aa364f885076114906f9',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02a617aa364f885076114906f9',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851a617aa364f885076114906f9',
#      'width': 64}],
#    'name': 'ESTATE 2021 HITS',
#    'release_date': '2021-08-06',
#    'release_date_precision': 'day',
#    'total_tracks': 31,
#    'type': 'album',
#    'uri': 'spotify:album:0zt5rQZyk3KegttfgPi30G'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'disc_number': 1,
#   'duration_ms': 199931,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM71815958'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1i3fTnSg2X03MWLEt411Eb'},
#   'href': 'https://api.spotify.com/v1/tracks/1i3fTnSg2X03MWLEt411Eb',
#   'id': '1i3fTnSg2X03MWLEt411Eb',
#   'is_local': False,
#   'is_playable': True,
#   'name': "when the party's over",
#   'popularity': 18,
#   'preview_url': None,
#   'track_number': 28,
#   'type': 'track',
#   'uri': 'spotify:track:1i3fTnSg2X03MWLEt411Eb'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6LuN9FCkKOj5PcnpouEgny'},
#      'href': 'https://api.spotify.com/v1/artists/6LuN9FCkKOj5PcnpouEgny',
#      'id': '6LuN9FCkKOj5PcnpouEgny',
#      'name': 'Khalid',
#      'type': 'artist',
#      'uri': 'spotify:artist:6LuN9FCkKOj5PcnpouEgny'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2sBB17RXTamvj7Ncps15AK'},
#    'href': 'https://api.spotify.com/v1/albums/2sBB17RXTamvj7Ncps15AK',
#    'id': '2sBB17RXTamvj7Ncps15AK',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2738a3f0a3ca7929dea23cd274c',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e028a3f0a3ca7929dea23cd274c',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048518a3f0a3ca7929dea23cd274c',
#      'width': 64}],
#    'name': 'lovely (with Khalid)',
#    'release_date': '2018-04-19',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:2sBB17RXTamvj7Ncps15AK'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6LuN9FCkKOj5PcnpouEgny'},
#     'href': 'https://api.spotify.com/v1/artists/6LuN9FCkKOj5PcnpouEgny',
#     'id': '6LuN9FCkKOj5PcnpouEgny',
#     'name': 'Khalid',
#     'type': 'artist',
#     'uri': 'spotify:artist:6LuN9FCkKOj5PcnpouEgny'}],
#   'disc_number': 1,
#   'duration_ms': 200185,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM71804190'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0u2P5u6lvoDfwTYjAADbn4'},
#   'href': 'https://api.spotify.com/v1/tracks/0u2P5u6lvoDfwTYjAADbn4',
#   'id': '0u2P5u6lvoDfwTYjAADbn4',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'lovely (with Khalid)',
#   'popularity': 86,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:0u2P5u6lvoDfwTYjAADbn4'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#    'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#    'id': '0JGOiO34nwfUdDrD612dOp',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#      'width': 64}],
#    'name': 'Happier Than Ever',
#    'release_date': '2021-07-30',
#    'release_date_precision': 'day',
#    'total_tracks': 16,
#    'type': 'album',
#    'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'disc_number': 1,
#   'duration_ms': 196730,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM72105927'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2KnuaZYoGzDoHiBTNYOTXG'},
#   'href': 'https://api.spotify.com/v1/tracks/2KnuaZYoGzDoHiBTNYOTXG',
#   'id': '2KnuaZYoGzDoHiBTNYOTXG',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Billie Bossa Nova',
#   'popularity': 81,
#   'preview_url': None,
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:2KnuaZYoGzDoHiBTNYOTXG'},
#  {'album': {'album_type': 'compilation',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#      'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#      'id': '0LyfQWJT6nXafLPZqxe9Of',
#      'name': 'Various Artists',
#      'type': 'artist',
#      'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6CcHGSgeYoXO72rMwBeZ2V'},
#      'href': 'https://api.spotify.com/v1/artists/6CcHGSgeYoXO72rMwBeZ2V',
#      'id': '6CcHGSgeYoXO72rMwBeZ2V',
#      'name': 'Carl Davis',
#      'type': 'artist',
#      'uri': 'spotify:artist:6CcHGSgeYoXO72rMwBeZ2V'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1AZTVGOm7t5zkOcweZBivz'},
#      'href': 'https://api.spotify.com/v1/artists/1AZTVGOm7t5zkOcweZBivz',
#      'id': '1AZTVGOm7t5zkOcweZBivz',
#      'name': 'Leif Segerstam',
#      'type': 'artist',
#      'uri': 'spotify:artist:1AZTVGOm7t5zkOcweZBivz'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Veude8V6p7YxBNIQld13F'},
#      'href': 'https://api.spotify.com/v1/artists/5Veude8V6p7YxBNIQld13F',
#      'id': '5Veude8V6p7YxBNIQld13F',
#      'name': 'György Lehel',
#      'type': 'artist',
#      'uri': 'spotify:artist:5Veude8V6p7YxBNIQld13F'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2IpitDGspEKl8VaB3qd4ya'},
#      'href': 'https://api.spotify.com/v1/artists/2IpitDGspEKl8VaB3qd4ya',
#      'id': '2IpitDGspEKl8VaB3qd4ya',
#      'name': 'Zdeněk Košler',
#      'type': 'artist',
#      'uri': 'spotify:artist:2IpitDGspEKl8VaB3qd4ya'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/68tBK9r9zdViB8V73G5SA9'},
#      'href': 'https://api.spotify.com/v1/artists/68tBK9r9zdViB8V73G5SA9',
#      'id': '68tBK9r9zdViB8V73G5SA9',
#      'name': 'Richard Hayman',
#      'type': 'artist',
#      'uri': 'spotify:artist:68tBK9r9zdViB8V73G5SA9'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/27kuIxOlYJi0Wt6dH7Xe5Y'},
#      'href': 'https://api.spotify.com/v1/artists/27kuIxOlYJi0Wt6dH7Xe5Y',
#      'id': '27kuIxOlYJi0Wt6dH7Xe5Y',
#      'name': 'Adrian Leaper',
#      'type': 'artist',
#      'uri': 'spotify:artist:27kuIxOlYJi0Wt6dH7Xe5Y'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2enPrYI2oHc6IWCuCmLfX9'},
#      'href': 'https://api.spotify.com/v1/artists/2enPrYI2oHc6IWCuCmLfX9',
#      'id': '2enPrYI2oHc6IWCuCmLfX9',
#      'name': 'Alexander Rahbari',
#      'type': 'artist',
#      'uri': 'spotify:artist:2enPrYI2oHc6IWCuCmLfX9'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/12eE2b1achxTzCwb8lcx6l'},
#      'href': 'https://api.spotify.com/v1/artists/12eE2b1achxTzCwb8lcx6l',
#      'id': '12eE2b1achxTzCwb8lcx6l',
#      'name': 'Kenneth Jean',
#      'type': 'artist',
#      'uri': 'spotify:artist:12eE2b1achxTzCwb8lcx6l'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2V2ZxZB2Vy0JDoHcyNWQC8'},
#      'href': 'https://api.spotify.com/v1/artists/2V2ZxZB2Vy0JDoHcyNWQC8',
#      'id': '2V2ZxZB2Vy0JDoHcyNWQC8',
#      'name': 'Uwe Mund',
#      'type': 'artist',
#      'uri': 'spotify:artist:2V2ZxZB2Vy0JDoHcyNWQC8'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2eqNsX66FyKi3bnl1KSqZz'},
#      'href': 'https://api.spotify.com/v1/artists/2eqNsX66FyKi3bnl1KSqZz',
#      'id': '2eqNsX66FyKi3bnl1KSqZz',
#      'name': 'Béla Drahos',
#      'type': 'artist',
#      'uri': 'spotify:artist:2eqNsX66FyKi3bnl1KSqZz'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6dg4xqm9InvCIZwVil23Yg'},
#      'href': 'https://api.spotify.com/v1/artists/6dg4xqm9InvCIZwVil23Yg',
#      'id': '6dg4xqm9InvCIZwVil23Yg',
#      'name': 'James DePreist',
#      'type': 'artist',
#      'uri': 'spotify:artist:6dg4xqm9InvCIZwVil23Yg'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7G5Z4L6m1LGBJ42aMS0zUL'},
#      'href': 'https://api.spotify.com/v1/artists/7G5Z4L6m1LGBJ42aMS0zUL',
#      'id': '7G5Z4L6m1LGBJ42aMS0zUL',
#      'name': 'Kenneth Schermerhorn',
#      'type': 'artist',
#      'uri': 'spotify:artist:7G5Z4L6m1LGBJ42aMS0zUL'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/09Ruas7vF7YHnor4to4Eyo'},
#      'href': 'https://api.spotify.com/v1/artists/09Ruas7vF7YHnor4to4Eyo',
#      'id': '09Ruas7vF7YHnor4to4Eyo',
#      'name': 'Richard Edlinger',
#      'type': 'artist',
#      'uri': 'spotify:artist:09Ruas7vF7YHnor4to4Eyo'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0lluGWFB8hZ6HFktcH6kkr'},
#      'href': 'https://api.spotify.com/v1/artists/0lluGWFB8hZ6HFktcH6kkr',
#      'id': '0lluGWFB8hZ6HFktcH6kkr',
#      'name': 'Marin Alsop',
#      'type': 'artist',
#      'uri': 'spotify:artist:0lluGWFB8hZ6HFktcH6kkr'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6Dkj1lYjjOCsGB170vlWc6'},
#      'href': 'https://api.spotify.com/v1/artists/6Dkj1lYjjOCsGB170vlWc6',
#      'id': '6Dkj1lYjjOCsGB170vlWc6',
#      'name': 'Michael Halasz',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Dkj1lYjjOCsGB170vlWc6'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0eaRvM9NkpTV399cyiZUwf'},
#      'href': 'https://api.spotify.com/v1/artists/0eaRvM9NkpTV399cyiZUwf',
#      'id': '0eaRvM9NkpTV399cyiZUwf',
#      'name': 'Jeremy Summerly',
#      'type': 'artist',
#      'uri': 'spotify:artist:0eaRvM9NkpTV399cyiZUwf'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2A5MfDq59CDZg119HhLcT7'},
#      'href': 'https://api.spotify.com/v1/artists/2A5MfDq59CDZg119HhLcT7',
#      'id': '2A5MfDq59CDZg119HhLcT7',
#      'name': 'Helmut Muller-Bruhl',
#      'type': 'artist',
#      'uri': 'spotify:artist:2A5MfDq59CDZg119HhLcT7'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/10ZoutqXuCmFqOKwZdZs99'},
#      'href': 'https://api.spotify.com/v1/artists/10ZoutqXuCmFqOKwZdZs99',
#      'id': '10ZoutqXuCmFqOKwZdZs99',
#      'name': 'Morten Schuldt-Jensen',
#      'type': 'artist',
#      'uri': 'spotify:artist:10ZoutqXuCmFqOKwZdZs99'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3QEztQUVjL5FGxXuP70mJQ'},
#      'href': 'https://api.spotify.com/v1/artists/3QEztQUVjL5FGxXuP70mJQ',
#      'id': '3QEztQUVjL5FGxXuP70mJQ',
#      'name': 'Johannes Wildner',
#      'type': 'artist',
#      'uri': 'spotify:artist:3QEztQUVjL5FGxXuP70mJQ'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/0yVP6JP8tiC5SzUqCRv4w7'},
#      'href': 'https://api.spotify.com/v1/artists/0yVP6JP8tiC5SzUqCRv4w7',
#      'id': '0yVP6JP8tiC5SzUqCRv4w7',
#      'name': 'William Stromberg',
#      'type': 'artist',
#      'uri': 'spotify:artist:0yVP6JP8tiC5SzUqCRv4w7'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6jKsnWXyWgE3jyC0Cs0Cdb'},
#      'href': 'https://api.spotify.com/v1/artists/6jKsnWXyWgE3jyC0Cs0Cdb',
#      'id': '6jKsnWXyWgE3jyC0Cs0Cdb',
#      'name': 'Dmitry Yablonsky',
#      'type': 'artist',
#      'uri': 'spotify:artist:6jKsnWXyWgE3jyC0Cs0Cdb'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4RqJLaVkFhOYsn72FUS2iQ'},
#    'href': 'https://api.spotify.com/v1/albums/4RqJLaVkFhOYsn72FUS2iQ',
#    'id': '4RqJLaVkFhOYsn72FUS2iQ',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2736f535cfea3ddfb09c19c8f47',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e026f535cfea3ddfb09c19c8f47',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048516f535cfea3ddfb09c19c8f47',
#      'width': 64}],
#    'name': 'Classical Music: 50 of the Best Film Classics',
#    'release_date': '2012-10-01',
#    'release_date_precision': 'day',
#    'total_tracks': 50,
#    'type': 'album',
#    'uri': 'spotify:album:4RqJLaVkFhOYsn72FUS2iQ'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3MKCzCnpzw3TjUYs2v7vDA'},
#     'href': 'https://api.spotify.com/v1/artists/3MKCzCnpzw3TjUYs2v7vDA',
#     'id': '3MKCzCnpzw3TjUYs2v7vDA',
#     'name': 'Pyotr Ilyich Tchaikovsky',
#     'type': 'artist',
#     'uri': 'spotify:artist:3MKCzCnpzw3TjUYs2v7vDA'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0DJZPK3nRWESIS0yexi6Qi'},
#     'href': 'https://api.spotify.com/v1/artists/0DJZPK3nRWESIS0yexi6Qi',
#     'id': '0DJZPK3nRWESIS0yexi6Qi',
#     'name': 'Russian State Symphony Orchestra',
#     'type': 'artist',
#     'uri': 'spotify:artist:0DJZPK3nRWESIS0yexi6Qi'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6jKsnWXyWgE3jyC0Cs0Cdb'},
#     'href': 'https://api.spotify.com/v1/artists/6jKsnWXyWgE3jyC0Cs0Cdb',
#     'id': '6jKsnWXyWgE3jyC0Cs0Cdb',
#     'name': 'Dmitry Yablonsky',
#     'type': 'artist',
#     'uri': 'spotify:artist:6jKsnWXyWgE3jyC0Cs0Cdb'}],
#   'disc_number': 1,
#   'duration_ms': 138493,
#   'explicit': False,
#   'external_ids': {'isrc': 'HKI190201219'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5mr7bInpz2uiHNT5Us2kfj'},
#   'href': 'https://api.spotify.com/v1/tracks/5mr7bInpz2uiHNT5Us2kfj',
#   'id': '5mr7bInpz2uiHNT5Us2kfj',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Swan Lake, Op. 20, Act II No. 10: Scene, "Swan Theme" (Billy Elliot/Black Swan)',
#   'popularity': 13,
#   'preview_url': 'https://p.scdn.co/mp3-preview/0f99211cd972347f5bf4b710fd8c84a80c40a2c7?cid=d4726b15e5b34b0fa3c825aaea90d658',
#   'track_number': 46,
#   'type': 'track',
#   'uri': 'spotify:track:5mr7bInpz2uiHNT5Us2kfj'}]

# %%
len(results['tracks']['items'])
# Out:
# 5

# %%
results['tracks']['items'][0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#   'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#   'id': '0JGOiO34nwfUdDrD612dOp',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#     'width': 64}],
#   'name': 'Happier Than Ever',
#   'release_date': '2021-07-30',
#   'release_date_precision': 'day',
#   'total_tracks': 16,
#   'type': 'album',
#   'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#    'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#    'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#    'name': 'Billie Eilish',
#    'type': 'artist',
#    'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#  'disc_number': 1,
#  'duration_ms': 298899,
#  'explicit': True,
#  'external_ids': {'isrc': 'USUM72105936'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/4RVwu0g32PAqgUiJoXsdF8'},
#  'href': 'https://api.spotify.com/v1/tracks/4RVwu0g32PAqgUiJoXsdF8',
#  'id': '4RVwu0g32PAqgUiJoXsdF8',
#  'is_local': False,
#  'is_playable': True,
#  'name': 'Happier Than Ever',
#  'popularity': 94,
#  'preview_url': None,
#  'track_number': 15,
#  'type': 'track',
#  'uri': 'spotify:track:4RVwu0g32PAqgUiJoXsdF8'}

# %%
results['tracks']['items'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
results['tracks']['items'][0]['id']
# Out:
# '4RVwu0g32PAqgUiJoXsdF8'

# %%
for item in results['tracks']['items']:
    print("The name of song is: '{}' and the id is: {}".format(item['name'],item['external_urls']['spotify']))
# Out:
# The name of song is: 'Happier Than Ever' and the id is: https://open.spotify.com/track/4RVwu0g32PAqgUiJoXsdF8
# The name of song is: 'when the party's over' and the id is: https://open.spotify.com/track/1i3fTnSg2X03MWLEt411Eb
# The name of song is: 'lovely (with Khalid)' and the id is: https://open.spotify.com/track/0u2P5u6lvoDfwTYjAADbn4
# The name of song is: 'Billie Bossa Nova' and the id is: https://open.spotify.com/track/2KnuaZYoGzDoHiBTNYOTXG
# The name of song is: 'Swan Lake, Op. 20, Act II No. 10: Scene, "Swan Theme" (Billy Elliot/Black Swan)' and the id is: https://open.spotify.com/track/5mr7bInpz2uiHNT5Us2kfj

# %%
results["tracks"]["items"][0]['name']
# Out:
# 'Happier Than Ever'

# %%
import pandas as pd

song = sp.search(q="Bad Guy", limit=1) 
#pprint.pprint(song['tracks']['items'][0]['uri'])
song["tracks"]["items"][0]["uri"]
sp.audio_features(song["tracks"]["items"][0]["uri"])[0]
# Out:
# {'danceability': 0.701,
#  'energy': 0.425,
#  'key': 7,
#  'loudness': -10.965,
#  'mode': 1,
#  'speechiness': 0.375,
#  'acousticness': 0.328,
#  'instrumentalness': 0.13,
#  'liveness': 0.1,
#  'valence': 0.562,
#  'tempo': 135.128,
#  'type': 'audio_features',
#  'id': '2Fxmhks0bxGSBdJ92vM42m',
#  'uri': 'spotify:track:2Fxmhks0bxGSBdJ92vM42m',
#  'track_href': 'https://api.spotify.com/v1/tracks/2Fxmhks0bxGSBdJ92vM42m',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Fxmhks0bxGSBdJ92vM42m',
#  'duration_ms': 194088,
#  'time_signature': 4}

# %%
my_dict = sp.audio_features(song["tracks"]["items"][0]["uri"])[0] # you can provide a list of uri's

print(my_dict)
my_dict_new = { key: [my_dict[key]] for key in list(my_dict.keys()) }

#my_dict_new['name'] = [song["tracks"]["items"][0]['name']]
print(my_dict_new)

pd.DataFrame(my_dict_new)
# Out:
# {'danceability': 0.701, 'energy': 0.425, 'key': 7, 'loudness': -10.965, 'mode': 1, 'speechiness': 0.375, 'acousticness': 0.328, 'instrumentalness': 0.13, 'liveness': 0.1, 'valence': 0.562, 'tempo': 135.128, 'type': 'audio_features', 'id': '2Fxmhks0bxGSBdJ92vM42m', 'uri': 'spotify:track:2Fxmhks0bxGSBdJ92vM42m', 'track_href': 'https://api.spotify.com/v1/tracks/2Fxmhks0bxGSBdJ92vM42m', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Fxmhks0bxGSBdJ92vM42m', 'duration_ms': 194088, 'time_signature': 4}
# {'danceability': [0.701], 'energy': [0.425], 'key': [7], 'loudness': [-10.965], 'mode': [1], 'speechiness': [0.375], 'acousticness': [0.328], 'instrumentalness': [0.13], 'liveness': [0.1], 'valence': [0.562], 'tempo': [135.128], 'type': ['audio_features'], 'id': ['2Fxmhks0bxGSBdJ92vM42m'], 'uri': ['spotify:track:2Fxmhks0bxGSBdJ92vM42m'], 'track_href': ['https://api.spotify.com/v1/tracks/2Fxmhks0bxGSBdJ92vM42m'], 'analysis_url': ['https://api.spotify.com/v1/audio-analysis/2Fxmhks0bxGSBdJ92vM42m'], 'duration_ms': [194088], 'time_signature': [4]}
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.701   0.425    7   -10.965     1        0.375         0.328
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0              0.13       0.1    0.562  135.128  audio_features
#
#                        id                                   uri  \
# 0  2Fxmhks0bxGSBdJ92vM42m  spotify:track:2Fxmhks0bxGSBdJ92vM42m
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2Fxmhks0bxGS...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2Fxm...       194088
#
#    time_signature
# 0               4

# %% [markdown]
# Let's search for songs of several artists

# %%
my_artists = ['Placebo','Marylin Manson','Janis Joplin']

my_dict = {}
#for artist in my_artists:
#    #result = sp.search(q=artist, limit= 50)
#    my_dict[artist] = sp.search(q=artist, limit= 50)

my_dict = {artist: sp.search(q=artist, limit= 50,market="GB") for artist in my_artists}
#my_dict
my_dict.keys()
# Out:
# dict_keys(['Placebo', 'Marylin Manson', 'Janis Joplin'])

# %%
my_dict
# Out:
# {'Placebo': {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Placebo&type=track&market=GB&offset=0&limit=50',
#    'items': [{'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#         'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#         'id': '6RZUqkomCmb8zCRqc9eznB',
#         'name': 'Placebo',
#         'type': 'artist',
#         'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2cDDG5rnwEgjNL8Q0cO9Zd'},
#       'href': 'https://api.spotify.com/v1/albums/2cDDG5rnwEgjNL8Q0cO9Zd',
#       'id': '2cDDG5rnwEgjNL8Q0cO9Zd',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273ac68d5f575b62ee76a235396',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02ac68d5f575b62ee76a235396',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851ac68d5f575b62ee76a235396',
#         'width': 64}],
#       'name': "Without You I'm Nothing",
#       'release_date': '1998-10-12',
#       'release_date_precision': 'day',
#       'total_tracks': 13,
#       'type': 'album',
#       'uri': 'spotify:album:2cDDG5rnwEgjNL8Q0cO9Zd'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#        'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#        'id': '6RZUqkomCmb8zCRqc9eznB',
#        'name': 'Placebo',
#        'type': 'artist',
#        'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#      'disc_number': 1,
#      'duration_ms': 213800,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBAAA9820460'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/3tRv4ZYZimrL27flnjgeR6'},
#      'href': 'https://api.spotify.com/v1/tracks/3tRv4ZYZimrL27flnjgeR6',
#      'id': '3tRv4ZYZimrL27flnjgeR6',
#      'is_local': False,
#      'is_playable': True,
#      'name': 'Every You Every Me',
#      'popularity': 66,
#      'preview_url': 'https://p.scdn.co/mp3-preview/a281fc491f2249d525284d1762566e27f94ae169?cid=d4726b15e5b34b0fa3c825aaea90d658',
#      'track_number': 8,
#      'type': 'track',
#      'uri': 'spotify:track:3tRv4ZYZimrL27flnjgeR6'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#         'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#         'id': '6RZUqkomCmb8zCRqc9eznB',
#         'name': 'Placebo',
#         'type': 'artist',
#         'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/7cfTTszDP3KgMjtxhE8Re7'},
#       'href': 'https://api.spotify.com/v1/albums/7cfTTszDP3KgMjtxhE8Re7',
#       'id': '7cfTTszDP3KgMjtxhE8Re7',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2735a95bd5fa1b59b390a22d1de',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e025a95bd5fa1b59b390a22d1de',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048515a95bd5fa1b59b390a22d1de',
#         'width': 64}],
#       'name': 'Meds',
#       'release_date': '2006-03-13',
#       'release_date_precision': 'day',
#       'total_tracks': 13,
#       'type': 'album',
#       'uri': 'spotify:album:7cfTTszDP3KgMjtxhE8Re7'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#        'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#        'id': '6RZUqkomCmb8zCRqc9eznB',
#        'name': 'Placebo',
#        'type': 'artist',
#        'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#      'disc_number': 1,
#      'duration_ms': 216186,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBAAA0500879'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2DO7ywgu9cdNqXf7Cukys9'},
#      'href': 'https://api.spotify.com/v1/tracks/2DO7ywgu9cdNqXf7Cukys9',
#      'id': '2DO7ywgu9cdNqXf7Cukys9',
#      'is_local': False,
#      'is_playable': True,
#      'name': 'Song to Say Goodbye',
#      'popularity': 56,
#      'preview_url': 'https://p.scdn.co/mp3-preview/24e463a1de198f3a3594267c8ba4db8685e689dc?cid=d4726b15e5b34b0fa3c825aaea90d658',
#      'track_number': 13,
#      'type': 'track',
#      'uri': 'spotify:track:2DO7ywgu9cdNqXf7Cukys9'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#         'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#         'id': '6RZUqkomCmb8zCRqc9eznB',
#         'name': 'Placebo',
#         'type': 'artist',
#         'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/42LvsxgKnHYVu7PQRXmURw'},
#       'href': 'https://api.spotify.com/v1/albums/42LvsxgKnHYVu7PQRXmURw',
#       'id': '42LvsxgKnHYVu7PQRXmURw',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2735574c157ee6da19c3d2fbd16',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e025574c157ee6da19c3d2fbd16',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048515574c157ee6da19c3d2fbd16',
#         'width': 64}],
#       'name': 'Covers',
#       'release_date': '2003-03-24',
#       'release_date_precision': 'day',
#       'total_tracks': 10,
#       'type': 'album',
#       'uri': 'spotify:album:42LvsxgKnHYVu7PQRXmURw'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#        'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#        'id': '6RZUqkomCmb8zCRqc9eznB',
#        'name': 'Placebo',
#        'type': 'artist',
#        'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#      'disc_number': 1,
#      'duration_ms': 297320,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBAAA0300682'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/6RHHbAbyIcPpvS1dP3KUGq'},
#      'href': 'https://api.spotify.com/v1/tracks/6RHHbAbyIcPpvS1dP3KUGq',
#      'id': '6RHHbAbyIcPpvS1dP3KUGq',
#      'is_local': False,
#      'is_playable': True,
#      'name': 'Running Up That Hill',
#      'popularity': 62,
#      'preview_url': 'https://p.scdn.co/mp3-preview/bb95a992e74d5103205267c61e4bbd9fedcb4db8?cid=d4726b15e5b34b0fa3c825aaea90d658',
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:6RHHbAbyIcPpvS1dP3KUGq'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#         'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#         'id': '6RZUqkomCmb8zCRqc9eznB',
#         'name': 'Placebo',
#         'type': 'artist',
#         'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/57d7iI3YmpeAvbJGmvLBVu'},
#       'href': 'https://api.spotify.com/v1/albums/57d7iI3YmpeAvbJGmvLBVu',
#       'id': '57d7iI3YmpeAvbJGmvLBVu',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2736e2977bd512137598b5e00fc',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e026e2977bd512137598b5e00fc',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048516e2977bd512137598b5e00fc',
#         'width': 64}],
#       'name': 'Placebo',
#       'release_date': '1996-06-17',
#       'release_date_precision': 'day',
#       'total_tracks': 11,
#       'type': 'album',
#       'uri': 'spotify:album:57d7iI3YmpeAvbJGmvLBVu'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#        'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#        'id': '6RZUqkomCmb8zCRqc9eznB',
#        'name': 'Placebo',
#        'type': 'artist',
#        'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#      'disc_number': 1,
#      'duration_ms': 210933,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBAAA9710443'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1ZOeXUr9ieWw80zs1T6pkp'},
#      'href': 'https://api.spotify.com/v1/tracks/1ZOeXUr9ieWw80zs1T6pkp',
#      'id': '1ZOeXUr9ieWw80zs1T6pkp',
#      'is_local': False,
#      'is_playable': True,
#      'name': 'Nancy Boy',
#      'popularity': 51,
#      'preview_url': 'https://p.scdn.co/mp3-preview/06bcbadee3f70cd525c6330eea01d219e83f2c68?cid=d4726b15e5b34b0fa3c825aaea90d658',
#      'track_number': 6,
#      'type': 'track',
#      'uri': 'spotify:track:1ZOeXUr9ieWw80zs1T6pkp'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#         'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#         'id': '6RZUqkomCmb8zCRqc9eznB',
#         'name': 'Placebo',
#         'type': 'artist',
#         'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2cDDG5rnwEgjNL8Q0cO9Zd'},
#       'href': 'https://api.spotify.com/v1/albums/2cDDG5rnwEgjNL8Q0cO9Zd',
#       'id': '2cDDG5rnwEgjNL8Q0cO9Zd',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273ac68d5f575b62ee76a235396',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02ac68d5f575b62ee76a235396',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851ac68d5f575b62ee76a235396',
#         'width': 64}],
#       'name': "Without You I'm Nothing",
#       'release_date': '1998-10-12',
#       'release_date_precision': 'day',
#       'total_tracks': 13,
#       'type': 'album',
#       'uri': 'spotify:album:2cDDG5rnwEgjNL8Q0cO9Zd'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#        'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#        'id': '6RZUqkomCmb8zCRqc9eznB',
#        'name': 'Placebo',
#        'type': 'artist',
#        'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#      'disc_number': 1,
#      'duration_ms': 254760,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBAAA9820347'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1TqmZVIyeD4aN4Wa0wbnfy'},
#      'href': 'https://api.spotify.com/v1/tracks/1TqmZVIyeD4aN4Wa0wbnfy',
#      'id': '1TqmZVIyeD4aN4Wa0wbnfy',
#      'is_local': False,
#      'is_playable': True,
#      'name': 'Pure Morning',
#      'popularity': 59,
#      'preview_url': 'https://p.scdn.co/mp3-preview/42be861caeeb76ac7b66b09f284218c61e547337?cid=d4726b15e5b34b0fa3c825aaea90d658',
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:1TqmZVIyeD4aN4Wa0wbnfy'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#         'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#         'id': '6RZUqkomCmb8zCRqc9eznB',
#         'name': 'Placebo',
#         'type': 'artist',
#         'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/4fUDor6o5gw0b18iYKEaRq'},
#       'href': 'https://api.spotify.com/v1/albums/4fUDor6o5gw0b18iYKEaRq',
#       'id': '4fUDor6o5gw0b18iYKEaRq',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2736745a70abfc25f45612c4d32',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e026745a70abfc25f45612c4d32',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048516745a70abfc25f45612c4d32',
#         'width': 64}],
#       'name': 'Sleeping With Ghosts',
#       'release_date': '2003-03-24',
#       'release_date_precision': 'day',
#       'total_tracks': 12,
#       'type': 'album',
#       'uri': 'spotify:album:4fUDor6o5gw0b18iYKEaRq'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#        'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#        'id': '6RZUqkomCmb8zCRqc9eznB',
#        'name': 'Placebo',
#        'type': 'artist',
#        'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#      'disc_number': 1,
#      'duration_ms': 190573,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBAAA0201199'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/3WBPiogtVDBSXK7uOpxJ6m'},
#      'href': 'https://api.spotify.com/v1/tracks/3WBPiogtVDBSXK7uOpxJ6m',
#      'id': '3WBPiogtVDBSXK7uOpxJ6m',
#      'is_local': False,
#      'is_playable': True,
#      'name': 'The Bitter End',
#      'popularity': 63,
#      'preview_url': 'https://p.scdn.co/mp3-preview/8dd321eff83c064cccf5932c263f235f88223a7c?cid=d4726b15e5b34b0fa3c825aaea90d658',
#      'track_number': 5,
#      'type': 'track',
#      'uri': 'spotify:track:3WBPiogtVDBSXK7uOpxJ6m'},
#     {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2xtmoxSauQs0TQFUoHmbfy'},
#         'href': 'https://api.spotify.com/v1/artists/2xtmoxSauQs0TQFUoHmbfy',
#         'id': '2xtmoxSauQs0TQFUoHmbfy',
#         'name': 'Crawlers',
#         'type': 'artist',
#         'uri': 'spotify:artist:2xtmoxSauQs0TQFUoHmbfy'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/13F3AcBecF8ghMDft2mQOF'},
#       'href': 'https://api.spotify.com/v1/albums/13F3AcBecF8ghMDft2mQOF',
#       'id': '13F3AcBecF8ghMDft2mQOF',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27314bbe22c49aa8af15eb02c91',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0214bbe22c49aa8af15eb02c91',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485114bbe22c49aa8af15eb02c91',
#         'width': 64}],
#       'name': 'Placebo',
#       'release_date': '2020-04-10',
#       'release_date_precision': 'day',
#       'total_tracks': 1,
#       'type': 'album',
#       'uri': 'spotify:album:13F3AcBecF8ghMDft2mQOF'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2xtmoxSauQs0TQFUoHmbfy'},
#        'href': 'https://api.spotify.com/v1/artists/2xtmoxSauQs0TQFUoHmbfy',
#        'id': '2xtmoxSauQs0TQFUoHmbfy',
#        'name': 'Crawlers',
#        'type': 'artist',
#        'uri': 'spotify:artist:2xtmoxSauQs0TQFUoHmbfy'}],
#      'disc_number': 1,
#      'duration_ms': 178064,
#      'explicit': False,
#      'external_ids': {'isrc': 'GB9TP2000478'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/7AFClX4KhMrxp6RrNNR7P6'},
#      'href': 'https://api.spotify.com/v1/tracks/7AFClX4KhMrxp6RrNNR7P6',
#      'id': '7AFClX4KhMrxp6RrNNR7P6',
#      'is_local': False,
#      'is_playable': True,
#      'name': 'Placebo',
#      'popularity': 41,
#      'preview_url': 'https://p.scdn.co/mp3-preview/7fd68b2150154c280a12f64d9d462db39c11e4f9?cid=d4726b15e5b34b0fa3c825aaea90d658',
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:7AFClX4KhMrxp6RrNNR7P6'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5SMVzTJyKFJ7TUb46DglcH'},
#         'href': 'https://api.spotify.com/v1/artists/5SMVzTJyKFJ7TUb46DglcH',
#         'id': '5SMVzTJyKFJ7TUb46DglcH',
#         'name': 'Parliament',
#         'type': 'artist',
#         'uri': 'spotify:artist:5SMVzTJyKFJ7TUb46DglcH'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/7Kv0H0XMdIyRs41a6USzrd'},
#       'href': 'https://api.spotify.com/v1/albums/7Kv0H0XMdIyRs41a6USzrd',
#       'id': '7Kv0H0XMdIyRs41a6USzrd',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273dadce998f88dba71c98adf88',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02dadce998f88dba71c98adf88',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851dadce998f88dba71c98adf88',
#         'width': 64}],
#       'name': 'Funkentelechy Vs. The Placebo Syndrome',
#       'release_date': '1977-11-28',
#       'release_date_precision': 'day',
#       'total_tracks': 6,
#       'type': 'album',
#       'uri': 'spotify:album:7Kv0H0XMdIyRs41a6USzrd'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5SMVzTJyKFJ7TUb46DglcH'},
#        'href': 'https://api.spotify.com/v1/artists/5SMVzTJyKFJ7TUb46DglcH',
#        'id': '5SMVzTJyKFJ7TUb46DglcH',
#        'name': 'Parliament',
#        'type': 'artist',
#        'uri': 'spotify:artist:5SMVzTJyKFJ7TUb46DglcH'}],
#      'disc_number': 1,
#      'duration_ms': 346666,
#      'explicit': False,
#      'external_ids': {'isrc': 'USUMG7710009'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1v1PV2wERHiMPesMWX0qmO'},
#      'href': 'https://api.spotify.com/v1/tracks/1v1PV2wERHiMPesMWX0qmO',
#      'id': '1v1PV2wERHiMPesMWX0qmO',
#      'is_local': False,
#      'is_playable': True,
#      'name': 'Flash Light',
#      'popularity': 60,
#      'preview_url': None,
#      'track_number': 6,
#      'type': 'track',
#      'uri': 'spotify:track:1v1PV2wERHiMPesMWX0qmO'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4yZojjwm9hIOplqpvQLiUs'},
#         'href': 'https://api.spotify.com/v1/artists/4yZojjwm9hIOplqpvQLiUs',
#         'id': '4yZojjwm9hIOplqpvQLiUs',
#         'name': 'Real Effect',
#         'type': 'artist',
#         'uri': 'spotify:artist:4yZojjwm9hIOplqpvQLiUs'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/1tl5U1jaFPImOady1YfgLQ'},
#       'href': 'https://api.spotify.com/v1/albums/1tl5U1jaFPImOady1YfgLQ',
#       'id': '1tl5U1jaFPImOady1YfgLQ',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2738699f00aaf1526fd45f7ccc5',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e028699f00aaf1526fd45f7ccc5',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048518699f00aaf1526fd45f7ccc5',
#         'width': 64}],
#       'name': 'Placebo',
#       'release_date': '2019-05-10',
#       'release_date_precision': 'day',
#       'total_tracks': 12,
#       'type': 'album',
#       'uri': 'spotify:album:1tl5U1jaFPImOady1YfgLQ'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4yZojjwm9hIOplqpvQLiUs'},
#        'href': 'https://api.spotify.com/v1/artists/4yZojjwm9hIOplqpvQLiUs',
#        'id': '4yZojjwm9hIOplqpvQLiUs',
#        'name': 'Real Effect',
#        'type': 'artist',
#        'uri': 'spotify:artist:4yZojjwm9hIOplqpvQLiUs'}],
#      'disc_number': 1,
#      'duration_ms': 75528,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBSMU6836657'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2PkPqa0U7pBX2Qrl0bSps3'},
#      'href': 'https://api.spotify.com/v1/tracks/2PkPqa0U7pBX2Qrl0bSps3',
#      'id': '2PkPqa0U7pBX2Qrl0bSps3',
#      'is_local': False,
#      'is_playable': True,
#      'name': 'Placebo',
#      'popularity': 26,
#      'preview_url': 'https://p.scdn.co/mp3-preview/8ab10a84ae7347504a563e3d82dba80321e44d0e?cid=d4726b15e5b34b0fa3c825aaea90d658',
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:2PkPqa0U7pBX2Qrl0bSps3'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#         'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#         'id': '6RZUqkomCmb8zCRqc9eznB',
#         'name': 'Placebo',
#         'type': 'artist',
#         'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/4fUDor6o5gw0b18iYKEaRq'},
#       'href': 'https://api.spotify.com/v1/albums/4fUDor6o5gw0b18iYKEaRq',
#       'id': '4fUDor6o5gw0b18iYKEaRq',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2736745a70abfc25f45612c4d32',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e026745a70abfc25f45612c4d32',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048516745a70abfc25f45612c4d32',
#         'width': 64}],
#       'name': 'Sleeping With Ghosts',
#       'release_date': '2003-03-24',
#       'release_date_precision': 'day',
#       'total_tracks': 12,
#       'type': 'album',
#       'uri': 'spotify:album:4fUDor6o5gw0b18iYKEaRq'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#        'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#        'id': '6RZUqkomCmb8zCRqc9eznB',
#        'name': 'Placebo',
#        'type': 'artist',
#        'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#      'disc_number': 1,
#      'duration_ms': 315986,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBAAA0201210'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2h0HkReHGCQPOEDZXEMcTO'},
#      'href': 'https://api.spotify.com/v1/tracks/2h0HkReHGCQPOEDZXEMcTO',
#      'id': '2h0HkReHGCQPOEDZXEMcTO',
#      'is_local': False,
#      'is_playable': True,
#      'name': 'Special Needs',
#      'popularity': 60,
#      'preview_url': 'https://p.scdn.co/mp3-preview/f34d8e1a586e6873c7f1b62ddacbfed2a6bc319c?cid=d4726b15e5b34b0fa3c825aaea90d658',
#      'track_number': 8,
#      'type': 'track',
#      'uri': 'spotify:track:2h0HkReHGCQPOEDZXEMcTO'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Ew8VmfE06siL2THiMBwPP'},
#         'href': 'https://api.spotify.com/v1/artists/4Ew8VmfE06siL2THiMBwPP',
#         'id': '4Ew8VmfE06siL2THiMBwPP',
#         'name': 'GRIP',
#         'type': 'artist',
#         'uri': 'spotify:artist:4Ew8VmfE06siL2THiMBwPP'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/7c7CTwIQhbdfe9MdjhEiwJ'},
#       'href': 'https://api.spotify.com/v1/albums/7c7CTwIQhbdfe9MdjhEiwJ',
#       'id': '7c7CTwIQhbdfe9MdjhEiwJ',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273b2cba62cd843bccf80474b3a',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02b2cba62cd843bccf80474b3a',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851b2cba62cd843bccf80474b3a',
#         'width': 64}],
#       'name': 'I Died For This!?',
#       'release_date': '2021-08-27',
#       'release_date_precision': 'day',
#       'total_tracks': 17,
#       'type': 'album',
#       'uri': 'spotify:album:7c7CTwIQhbdfe9MdjhEiwJ'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Ew8VmfE06siL2THiMBwPP'},
#        'href': 'https://api.spotify.com/v1/artists/4Ew8VmfE06siL2THiMBwPP',
#        'id': '4Ew8VmfE06siL2THiMBwPP',
#        'name': 'GRIP',
#        'type': 'artist',
#        'uri': 'spotify:artist:4Ew8VmfE06siL2THiMBwPP'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6DVipHzYsPlIoA0DW8Gmns'},
#        'href': 'https://api.spotify.com/v1/artists/6DVipHzYsPlIoA0DW8Gmns',
#        'id': '6DVipHzYsPlIoA0DW8Gmns',
#        'name': 'Royce Da 5\'9"',
#        'type': 'artist',
#        'uri': 'spotify:artist:6DVipHzYsPlIoA0DW8Gmns'}],
#      'disc_number': 1,
#      'duration_ms': 245520,
#      'explicit': True,
#      'external_ids': {'isrc': 'USUG12103443'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/3ibmMcZkT8DJ4VTlll431B'},
#      'href': 'https://api.spotify.com/v1/tracks/3ibmMcZkT8DJ4VTlll431B',
#      'id': '3ibmMcZkT8DJ4VTlll431B',
#      'is_local': False,
#      'is_playable': True,
#      'name': "Placebo (feat. Royce Da 5'9'')",
#      'popularity': 46,
#      'preview_url': None,
#      'track_number': 6,
#      'type': 'track',
#      'uri': 'spotify:track:3ibmMcZkT8DJ4VTlll431B'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#         'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#         'id': '6RZUqkomCmb8zCRqc9eznB',
#         'name': 'Placebo',
#         'type': 'artist',
#         'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/7cfTTszDP3KgMjtxhE8Re7'},
#       'href': 'https://api.spotify.com/v1/albums/7cfTTszDP3KgMjtxhE8Re7',
#       'id': '7cfTTszDP3KgMjtxhE8Re7',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2735a95bd5fa1b59b390a22d1de',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e025a95bd5fa1b59b390a22d1de',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048515a95bd5fa1b59b390a22d1de',
#         'width': 64}],
#       'name': 'Meds',
#       'release_date': '2006-03-13',
#       'release_date_precision': 'day',
#       'total_tracks': 13,
#       'type': 'album',
#       'uri': 'spotify:album:7cfTTszDP3KgMjtxhE8Re7'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#        'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#        'id': '6RZUqkomCmb8zCRqc9eznB',
#        'name': 'Placebo',
#        'type': 'artist',
#        'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5rexG906fVLfq8H9m8J9P9'},
#        'href': 'https://api.spotify.com/v1/artists/5rexG906fVLfq8H9m8J9P9',
#        'id': '5rexG906fVLfq8H9m8J9P9',
#        'name': 'Alison Mosshart',
#        'type': 'artist',
#        'uri': 'spotify:artist:5rexG906fVLfq8H9m8J9P9'}],
#      'disc_number': 1,
#      'duration_ms': 175386,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBAAA0600119'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/5fVTi3rIiLvsEVYp0cRvaI'},
#      'href': 'https://api.spotify.com/v1/tracks/5fVTi3rIiLvsEVYp0cRvaI',
#      'id': '5fVTi3rIiLvsEVYp0cRvaI',
#      'is_local': False,
#      'is_playable': True,
#      'name': 'Meds',
#      'popularity': 54,
#      'preview_url': 'https://p.scdn.co/mp3-preview/1991268b8eb0233f5cc4b3fa5adb4fa4d78cb604?cid=d4726b15e5b34b0fa3c825aaea90d658',
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:5fVTi3rIiLvsEVYp0cRvaI'},
#     {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5qfkUSH3ip5dD2eEPhjkT3'},
#         'href': 'https://api.spotify.com/v1/artists/5qfkUSH3ip5dD2eEPhjkT3',
#         'id': '5qfkUSH3ip5dD2eEPhjkT3',
#         'name': 'Kyle Dion',
#         'type': 'artist',
#         'uri': 'spotify:artist:5qfkUSH3ip5dD2eEPhjkT3'},
#        {'external_urls': {'spotify': 'https://open.spotify.com/artist/1J2VVASYAamtQ3Bt8wGgA6'},
#         'href': 'https://api.spotify.com/v1/artists/1J2VVASYAamtQ3Bt8wGgA6',
#         'id': '1J2VVASYAamtQ3Bt8wGgA6',
#         'name': 'Ja Rule',
#         'type': 'artist',
#         'uri': 'spotify:artist:1J2VVASYAamtQ3Bt8wGgA6'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/7taJQqTyGJpEFfjExh7xE4'},
#       'href': 'https://api.spotify.com/v1/albums/7taJQqTyGJpEFfjExh7xE4',
#       'id': '7taJQqTyGJpEFfjExh7xE4',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273c10e42ef0543d6bae8d0f0e5',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02c10e42ef0543d6bae8d0f0e5',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851c10e42ef0543d6bae8d0f0e5',
#         'width': 64}],
#       'name': 'Placebo',
#       'release_date': '2021-07-09',
#       'release_date_precision': 'day',
#       'total_tracks': 1,
#       'type': 'album',
#       'uri': 'spotify:album:7taJQqTyGJpEFfjExh7xE4'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5qfkUSH3ip5dD2eEPhjkT3'},
#        'href': 'https://api.spotify.com/v1/artists/5qfkUSH3ip5dD2eEPhjkT3',
#        'id': '5qfkUSH3ip5dD2eEPhjkT3',
#        'name': 'Kyle Dion',
#        'type': 'artist',
#        'uri': 'spotify:artist:5qfkUSH3ip5dD2eEPhjkT3'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1J2VVASYAamtQ3Bt8wGgA6'},
#        'href': 'https://api.spotify.com/v1/artists/1J2VVASYAamtQ3Bt8wGgA6',
#        'id': '1J2VVASYAamtQ3Bt8wGgA6',
#        'name': 'Ja Rule',
#        'type': 'artist',
#        'uri': 'spotify:artist:1J2VVASYAamtQ3Bt8wGgA6'}],
#      'disc_number': 1,
#      'duration_ms': 184813,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBKPL2155719'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/6SjcDOTIblXDriAMnXnrY8'},
#      'href': 'https://api.spotify.com/v1/tracks/6SjcDOTIblXDriAMnXnrY8',
#      'id': '6SjcDOTIblXDriAMnXnrY8',
#      'is_local': False,
#      'is_playable': True,
#      'name': 'Placebo',
#      'popularity': 44,
#      'preview_url': 'https://p.scdn.co/mp3-preview/e14a29528d3ceebd0e809fd4716f2a452b743722?cid=d4726b15e5b34b0fa3c825aaea90d658',
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:6SjcDOTIblXDriAMnXnrY8'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#         'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#         'id': '6RZUqkomCmb8zCRqc9eznB',
#         'name': 'Placebo',
#         'type': 'artist',
#         'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/7gLNPbL9arQdIl4aj4hBcq'},
#       'href': 'https://api.spotify.com/v1/albums/7gLNPbL9arQdIl4aj4hBcq',
#       'id': '7gLNPbL9arQdIl4aj4hBcq',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2737f02102fd54b157fd1dd6fa4',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e027f02102fd54b157fd1dd6fa4',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048517f02102fd54b157fd1dd6fa4',
#         'width': 64}],
#       'name': 'Black Market Music',
#       'release_date': '2000-10-09',
#       'release_date_precision': 'day',
#       'total_tracks': 13,
#       'type': 'album',
#       'uri': 'spotify:album:7gLNPbL9arQdIl4aj4hBcq'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#        'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#        'id': '6RZUqkomCmb8zCRqc9eznB',
#        'name': 'Placebo',
#        'type': 'artist',
#        'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#      'disc_number': 1,
#      'duration_ms': 232306,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBAAA0000665'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/63peVCtLTPd0aM9x5j97sB'},
#      'href': 'https://api.spotify.com/v1/tracks/63peVCtLTPd0aM9x5j97sB',
#      'id': '63peVCtLTPd0aM9x5j97sB',
#      'is_local': False,
#      'is_playable': True,
#      'name': 'Special K',
#      'popularity': 54,
#      'preview_url': 'https://p.scdn.co/mp3-preview/f1d4a5719f52ce274382c9ce0a296db8e68bea71?cid=d4726b15e5b34b0fa3c825aaea90d658',
#      'track_number': 3,
#      'type': 'track',
#      'uri': 'spotify:track:63peVCtLTPd0aM9x5j97sB'},
#     {'album': {'album_type': 'single',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4lC8Q0azW5ij2e1skZo377'},
#         'href': 'https://api.spotify.com/v1/artists/4lC8Q0azW5ij2e1skZo377',
#         'id': '4lC8Q0azW5ij2e1skZo377',
#         'name': 'Stonebank',
#         'type': 'artist',
#         'uri': 'spotify:artist:4lC8Q0azW5ij2e1skZo377'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/4I3OW8uo4oONyqLpQeaIzv'},
#       'href': 'https://api.spotify.com/v1/albums/4I3OW8uo4oONyqLpQeaIzv',
#       'id': '4I3OW8uo4oONyqLpQeaIzv',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273965f7dd822f0e4face321739',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02965f7dd822f0e4face321739',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851965f7dd822f0e4face321739',
#         'width': 64}],
#       'name': 'Placebo',
#       'release_date': '2021-03-26',
#       'release_date_precision': 'day',
#       'total_tracks': 1,
#       'type': 'album',
#       'uri': 'spotify:album:4I3OW8uo4oONyqLpQeaIzv'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4lC8Q0azW5ij2e1skZo377'},
#        'href': 'https://api.spotify.com/v1/artists/4lC8Q0azW5ij2e1skZo377',
#        'id': '4lC8Q0azW5ij2e1skZo377',
#        'name': 'Stonebank',
#        'type': 'artist',
#        'uri': 'spotify:artist:4lC8Q0azW5ij2e1skZo377'}],
#      'disc_number': 1,
#      'duration_ms': 208551,
#      'explicit': False,
#      'external_ids': {'isrc': 'CA6D22100292'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/2gS10fIDyJqOPNWUS86bvv'},
#      'href': 'https://api.spotify.com/v1/tracks/2gS10fIDyJqOPNWUS86bvv',
#      'id': '2gS10fIDyJqOPNWUS86bvv',
#      'is_local': False,
#      'is_playable': True,
#      'name': 'Placebo',
#      'popularity': 40,
#      'preview_url': 'https://p.scdn.co/mp3-preview/095a89be04585a63196bf0403c6d6145c132526c?cid=d4726b15e5b34b0fa3c825aaea90d658',
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:2gS10fIDyJqOPNWUS86bvv'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#         'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#         'id': '6RZUqkomCmb8zCRqc9eznB',
#         'name': 'Placebo',
#         'type': 'artist',
#         'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/4fUDor6o5gw0b18iYKEaRq'},
#       'href': 'https://api.spotify.com/v1/albums/4fUDor6o5gw0b18iYKEaRq',
#       'id': '4fUDor6o5gw0b18iYKEaRq',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2736745a70abfc25f45612c4d32',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e026745a70abfc25f45612c4d32',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048516745a70abfc25f45612c4d32',
#         'width': 64}],
#       'name': 'Sleeping With Ghosts',
#       'release_date': '2003-03-24',
#       'release_date_precision': 'day',
#       'total_tracks': 12,
#       'type': 'album',
#       'uri': 'spotify:album:4fUDor6o5gw0b18iYKEaRq'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#        'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#        'id': '6RZUqkomCmb8zCRqc9eznB',
#        'name': 'Placebo',
#        'type': 'artist',
#        'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#      'disc_number': 1,
#      'duration_ms': 214906,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBAAA0201205'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/5he7AYCR3MGloRnuWEMroT'},
#      'href': 'https://api.spotify.com/v1/tracks/5he7AYCR3MGloRnuWEMroT',
#      'id': '5he7AYCR3MGloRnuWEMroT',
#      'is_local': False,
#      'is_playable': True,
#      'name': 'This Picture',
#      'popularity': 58,
#      'preview_url': 'https://p.scdn.co/mp3-preview/382b4be52cde49ea2bccccc6253ed665a1e4b604?cid=d4726b15e5b34b0fa3c825aaea90d658',
#      'track_number': 3,
#      'type': 'track',
#      'uri': 'spotify:track:5he7AYCR3MGloRnuWEMroT'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#         'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#         'id': '6RZUqkomCmb8zCRqc9eznB',
#         'name': 'Placebo',
#         'type': 'artist',
#         'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/42LvsxgKnHYVu7PQRXmURw'},
#       'href': 'https://api.spotify.com/v1/albums/42LvsxgKnHYVu7PQRXmURw',
#       'id': '42LvsxgKnHYVu7PQRXmURw',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2735574c157ee6da19c3d2fbd16',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e025574c157ee6da19c3d2fbd16',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048515574c157ee6da19c3d2fbd16',
#         'width': 64}],
#       'name': 'Covers',
#       'release_date': '2003-03-24',
#       'release_date_precision': 'day',
#       'total_tracks': 10,
#       'type': 'album',
#       'uri': 'spotify:album:42LvsxgKnHYVu7PQRXmURw'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#        'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#        'id': '6RZUqkomCmb8zCRqc9eznB',
#        'name': 'Placebo',
#        'type': 'artist',
#        'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#      'disc_number': 1,
#      'duration_ms': 224560,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBAAA0300300'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/3fR6HdcPn0VHjMBnbGvCQc'},
#      'href': 'https://api.spotify.com/v1/tracks/3fR6HdcPn0VHjMBnbGvCQc',
#      'id': '3fR6HdcPn0VHjMBnbGvCQc',
#      'is_local': False,
#      'is_playable': True,
#      'name': 'Where Is My Mind? - XFM Live Version',
#      'popularity': 53,
#      'preview_url': 'https://p.scdn.co/mp3-preview/e7b66b59aceb34188ae0d90cb3d33bbea174fff8?cid=d4726b15e5b34b0fa3c825aaea90d658',
#      'track_number': 2,
#      'type': 'track',
#      'uri': 'spotify:track:3fR6HdcPn0VHjMBnbGvCQc'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#         'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#         'id': '6RZUqkomCmb8zCRqc9eznB',
#         'name': 'Placebo',
#         'type': 'artist',
#         'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/7cfTTszDP3KgMjtxhE8Re7'},
#       'href': 'https://api.spotify.com/v1/albums/7cfTTszDP3KgMjtxhE8Re7',
#       'id': '7cfTTszDP3KgMjtxhE8Re7',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2735a95bd5fa1b59b390a22d1de',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e025a95bd5fa1b59b390a22d1de',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048515a95bd5fa1b59b390a22d1de',
#         'width': 64}],
#       'name': 'Meds',
#       'release_date': '2006-03-13',
#       'release_date_precision': 'day',
#       'total_tracks': 13,
#       'type': 'album',
#       'uri': 'spotify:album:7cfTTszDP3KgMjtxhE8Re7'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#        'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#        'id': '6RZUqkomCmb8zCRqc9eznB',
#        'name': 'Placebo',
#        'type': 'artist',
#        'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#      'disc_number': 1,
#      'duration_ms': 195653,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBAAA0600120'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1L9lxHOC34URTdhGghi8pZ'},
#      'href': 'https://api.spotify.com/v1/tracks/1L9lxHOC34URTdhGghi8pZ',
#      'id': '1L9lxHOC34URTdhGghi8pZ',
#      'is_local': False,
#      'is_playable': True,
#      'name': 'Infra-Red',
#      'popularity': 50,
#      'preview_url': 'https://p.scdn.co/mp3-preview/042035d9fee28f8ffb580c2bdcd09ed26ab86935?cid=d4726b15e5b34b0fa3c825aaea90d658',
#      'track_number': 2,
#      'type': 'track',
#      'uri': 'spotify:track:1L9lxHOC34URTdhGghi8pZ'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#         'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#         'id': '6RZUqkomCmb8zCRqc9eznB',
#         'name': 'Placebo',
#         'type': 'artist',
#         'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/57d7iI3YmpeAvbJGmvLBVu'},
#       'href': 'https://api.spotify.com/v1/albums/57d7iI3YmpeAvbJGmvLBVu',
#       'id': '57d7iI3YmpeAvbJGmvLBVu',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2736e2977bd512137598b5e00fc',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e026e2977bd512137598b5e00fc',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048516e2977bd512137598b5e00fc',
#         'width': 64}],
#       'name': 'Placebo',
#       'release_date': '1996-06-17',
#       'release_date_precision': 'day',
#       'total_tracks': 11,
#       'type': 'album',
#       'uri': 'spotify:album:57d7iI3YmpeAvbJGmvLBVu'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#        'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#        'id': '6RZUqkomCmb8zCRqc9eznB',
#        'name': 'Placebo',
#        'type': 'artist',
#        'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#      'disc_number': 1,
#      'duration_ms': 162466,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBAAA9600237'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1TJKT0lwL1UVCakuPvuEl1'},
#      'href': 'https://api.spotify.com/v1/tracks/1TJKT0lwL1UVCakuPvuEl1',
#      'id': '1TJKT0lwL1UVCakuPvuEl1',
#      'is_local': False,
#      'is_playable': True,
#      'name': 'Teenage Angst',
#      'popularity': 43,
#      'preview_url': 'https://p.scdn.co/mp3-preview/eefbd2db15b5a1d005736db5e5ee6321cd476c8c?cid=d4726b15e5b34b0fa3c825aaea90d658',
#      'track_number': 2,
#      'type': 'track',
#      'uri': 'spotify:track:1TJKT0lwL1UVCakuPvuEl1'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#         'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#         'id': '6RZUqkomCmb8zCRqc9eznB',
#         'name': 'Placebo',
#         'type': 'artist',
#         'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2cDDG5rnwEgjNL8Q0cO9Zd'},
#       'href': 'https://api.spotify.com/v1/albums/2cDDG5rnwEgjNL8Q0cO9Zd',
#       'id': '2cDDG5rnwEgjNL8Q0cO9Zd',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273ac68d5f575b62ee76a235396',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02ac68d5f575b62ee76a235396',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851ac68d5f575b62ee76a235396',
#         'width': 64}],
#       'name': "Without You I'm Nothing",
#       'release_date': '1998-10-12',
#       'release_date_precision': 'day',
#       'total_tracks': 13,
#       'type': 'album',
#       'uri': 'spotify:album:2cDDG5rnwEgjNL8Q0cO9Zd'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#        'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#        'id': '6RZUqkomCmb8zCRqc9eznB',
#        'name': 'Placebo',
#        'type': 'artist',
#        'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#      'disc_number': 1,
#      'duration_ms': 248893,
#      'explicit': False,
#      'external_ids': {'isrc': 'GBAAA9820457'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/0HCLFxsxnpBXSpU0XjvPa1'},
#      'href': 'https://api.spotify.com/v1/tracks/0HCLFxsxnpBXSpU0XjvPa1',
#      'id': '0HCLFxsxnpBXSpU0XjvPa1',
#      'is_local': False,
#      'is_playable': True,
#      'name': "Without You I'm Nothing",
#      'popularity': 48,
#      'preview_url': 'https://p.scdn.co/mp3-preview/6e89fe63350db333981280fe854015c518db9189?cid=d4726b15e5b34b0fa3c825aaea90d658',
#      'track_number': 5,
#      'type': 'track',
#      'uri': 'spotify:track:0HCLFxsxnpBXSpU0XjvPa1'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1QPdp5duV6lV4XINCzjwQ2'},
#         'href': 'https://api.spotify.com/v1/artists/1QPdp5duV6lV4XINCzjwQ2',
#         'id': '1QPdp5duV6lV4XINCzjwQ2',
#         'name': 'Dinos',
#         'type': 'artist',
#         'uri': 'spotify:artist:1QPdp5duV6lV4XINCzjwQ2'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2kxLG2zY19L7YWG5iWLewv'},
#       'href': 'https://api.spotify.com/v1/albums/2kxLG2zY19L7YWG5iWLewv',
#       'id': '2kxLG2zY19L7YWG5iWLewv',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273a16bc4ee16ec5ae6787dede5',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02a16bc4ee16ec5ae6787dede5',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851a16bc4ee16ec5ae6787dede5',
#         'width': 64}],
#       'name': 'Imany Deluxe',
#       'release_date': '2018-12-07',
#       'release_date_precision': 'day',
#       'total_tracks': 24,
#       'type': 'album',
#       'uri': 'spotify:album:2kxLG2zY19L7YWG5iWLewv'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1QPdp5duV6lV4XINCzjwQ2'},
#        'href': 'https://api.spotify.com/v1/artists/1QPdp5duV6lV4XINCzjwQ2',
#        'id': '1QPdp5duV6lV4XINCzjwQ2',
#        'name': 'Dinos',
#        'type': 'artist',
#        'uri': 'spotify:artist:1QPdp5duV6lV4XINCzjwQ2'}],
#      'disc_number': 1,
#      'duration_ms': 190253,
#      'explicit': False,
#      'external_ids': {'isrc': 'FR9EI1700180'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/17jlkHSNHFu1zUuu8QZyOW'},
#      'href': 'https://api.spotify.com/v1/tracks/17jlkHSNHFu1zUuu8QZyOW',
#      'id': '17jlkHSNHFu1zUuu8QZyOW',
#      'is_local': False,
#      'is_playable': True,
#      'name': 'Placebo',
#      'popularity': 58,
#      'preview_url': 'https://p.scdn.co/mp3-preview/c507b4faf93846293a86f1a1e1d5fba833b59de6?cid=d4726b15e5b34b0fa3c825aaea90d658',
#      'track_number': 18,
#      'type': 'track',
#      'uri': 'spotify:track:17jlkHSNHFu1zUuu8QZyOW'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#         'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#         'id': '6RZUqkomCmb8zCRqc9eznB',
#         'name': 'Placebo',
#         'type': 'artist',
#         'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/4tpfFZJnnK1E6Vb2Be65PH'},
#       'href': 'https://api.spotify.com/v1/albums/4tpfFZJnnK1E6Vb2Be65PH',
#       'id': '4tpfFZJnnK1E6Vb2Be65PH',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273e5d878593752fa6c6190314d',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02e5d878593752fa6c6190314d',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851e5d878593752fa6c6190314d',
#         'width': 64}],
#       'name': 'Loud Like Love',
#       'release_date': '2013-09-16',
#       'release_date_precision': 'day',
#       'total_tracks': 10,
#       'type': 'album',
#       'uri': 'spotify:album:4tpfFZJnnK1E6Vb2Be65PH'},
# ...
#       'release_date_precision': 'day',
#       'total_tracks': 17,
#       'type': 'album',
#       'uri': 'spotify:album:5F6Th386ar5HNmOkcA0QrK'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NgfOZCL9Ml67xzM0xzIvC'},
#        'href': 'https://api.spotify.com/v1/artists/4NgfOZCL9Ml67xzM0xzIvC',
#        'id': '4NgfOZCL9Ml67xzM0xzIvC',
#        'name': 'Janis Joplin',
#        'type': 'artist',
#        'uri': 'spotify:artist:4NgfOZCL9Ml67xzM0xzIvC'}],
#      'disc_number': 1,
#      'duration_ms': 224386,
#      'explicit': False,
#      'external_ids': {'isrc': 'USSM10027785'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/6grR9jNzUcXpE8aq80Nqtg'},
#      'href': 'https://api.spotify.com/v1/tracks/6grR9jNzUcXpE8aq80Nqtg',
#      'id': '6grR9jNzUcXpE8aq80Nqtg',
#      'is_local': False,
#      'is_playable': True,
#      'name': 'Raise Your Hand - Live at Jahrhunderthalle, Frankfurt, Germany',
#      'popularity': 35,
#      'preview_url': 'https://p.scdn.co/mp3-preview/8f578c9f010828af1ab147a3443b14c30d5e32a9?cid=d4726b15e5b34b0fa3c825aaea90d658',
#      'track_number': 9,
#      'type': 'track',
#      'uri': 'spotify:track:6grR9jNzUcXpE8aq80Nqtg'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4J69yWrKwWJgjv3DKTZcGo'},
#         'href': 'https://api.spotify.com/v1/artists/4J69yWrKwWJgjv3DKTZcGo',
#         'id': '4J69yWrKwWJgjv3DKTZcGo',
#         'name': 'Big Brother & The Holding Company',
#         'type': 'artist',
#         'uri': 'spotify:artist:4J69yWrKwWJgjv3DKTZcGo'},
#        {'external_urls': {'spotify': 'https://open.spotify.com/artist/4NgfOZCL9Ml67xzM0xzIvC'},
#         'href': 'https://api.spotify.com/v1/artists/4NgfOZCL9Ml67xzM0xzIvC',
#         'id': '4NgfOZCL9Ml67xzM0xzIvC',
#         'name': 'Janis Joplin',
#         'type': 'artist',
#         'uri': 'spotify:artist:4NgfOZCL9Ml67xzM0xzIvC'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2rogKfOpmCFuqNhtGKf2dX'},
#       'href': 'https://api.spotify.com/v1/albums/2rogKfOpmCFuqNhtGKf2dX',
#       'id': '2rogKfOpmCFuqNhtGKf2dX',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2731ba5ee8bc24979ce3eee4797',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e021ba5ee8bc24979ce3eee4797',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048511ba5ee8bc24979ce3eee4797',
#         'width': 64}],
#       'name': 'Cheap Thrills',
#       'release_date': '1968-08-12',
#       'release_date_precision': 'day',
#       'total_tracks': 11,
#       'type': 'album',
#       'uri': 'spotify:album:2rogKfOpmCFuqNhtGKf2dX'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4J69yWrKwWJgjv3DKTZcGo'},
#        'href': 'https://api.spotify.com/v1/artists/4J69yWrKwWJgjv3DKTZcGo',
#        'id': '4J69yWrKwWJgjv3DKTZcGo',
#        'name': 'Big Brother & The Holding Company',
#        'type': 'artist',
#        'uri': 'spotify:artist:4J69yWrKwWJgjv3DKTZcGo'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4NgfOZCL9Ml67xzM0xzIvC'},
#        'href': 'https://api.spotify.com/v1/artists/4NgfOZCL9Ml67xzM0xzIvC',
#        'id': '4NgfOZCL9Ml67xzM0xzIvC',
#        'name': 'Janis Joplin',
#        'type': 'artist',
#        'uri': 'spotify:artist:4NgfOZCL9Ml67xzM0xzIvC'}],
#      'disc_number': 1,
#      'duration_ms': 254400,
#      'explicit': False,
#      'external_ids': {'isrc': 'USSM16801242'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/6dK3YqaigUJPxdTZqwhnM7'},
#      'href': 'https://api.spotify.com/v1/tracks/6dK3YqaigUJPxdTZqwhnM7',
#      'id': '6dK3YqaigUJPxdTZqwhnM7',
#      'is_local': False,
#      'is_playable': True,
#      'name': 'Oh, Sweet Mary',
#      'popularity': 36,
#      'preview_url': 'https://p.scdn.co/mp3-preview/b22d7382ab5812f40decc98b2a4edfa28ba9f9db?cid=d4726b15e5b34b0fa3c825aaea90d658',
#      'track_number': 6,
#      'type': 'track',
#      'uri': 'spotify:track:6dK3YqaigUJPxdTZqwhnM7'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NgfOZCL9Ml67xzM0xzIvC'},
#         'href': 'https://api.spotify.com/v1/artists/4NgfOZCL9Ml67xzM0xzIvC',
#         'id': '4NgfOZCL9Ml67xzM0xzIvC',
#         'name': 'Janis Joplin',
#         'type': 'artist',
#         'uri': 'spotify:artist:4NgfOZCL9Ml67xzM0xzIvC'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/3j7nicLAWXM0Fb08q9XGyf'},
#       'href': 'https://api.spotify.com/v1/albums/3j7nicLAWXM0Fb08q9XGyf',
#       'id': '3j7nicLAWXM0Fb08q9XGyf',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2736f8c26346723dd0531696bed',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e026f8c26346723dd0531696bed',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048516f8c26346723dd0531696bed',
#         'width': 64}],
#       'name': 'Pearl (Legacy Edition)',
#       'release_date': '1971-01-11',
#       'release_date_precision': 'day',
#       'total_tracks': 29,
#       'type': 'album',
#       'uri': 'spotify:album:3j7nicLAWXM0Fb08q9XGyf'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NgfOZCL9Ml67xzM0xzIvC'},
#        'href': 'https://api.spotify.com/v1/artists/4NgfOZCL9Ml67xzM0xzIvC',
#        'id': '4NgfOZCL9Ml67xzM0xzIvC',
#        'name': 'Janis Joplin',
#        'type': 'artist',
#        'uri': 'spotify:artist:4NgfOZCL9Ml67xzM0xzIvC'}],
#      'disc_number': 1,
#      'duration_ms': 286733,
#      'explicit': False,
#      'external_ids': {'isrc': 'USSM17100178'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/24wUUPqDonEJryKo1NclJo'},
#      'href': 'https://api.spotify.com/v1/tracks/24wUUPqDonEJryKo1NclJo',
#      'id': '24wUUPqDonEJryKo1NclJo',
#      'is_local': False,
#      'is_playable': True,
#      'name': 'Me and Bobby McGee - Demo Version',
#      'popularity': 30,
#      'preview_url': 'https://p.scdn.co/mp3-preview/92b859d825486c2d9956b634be95587ad90d236e?cid=d4726b15e5b34b0fa3c825aaea90d658',
#      'track_number': 12,
#      'type': 'track',
#      'uri': 'spotify:track:24wUUPqDonEJryKo1NclJo'},
#     {'album': {'album_type': 'compilation',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NgfOZCL9Ml67xzM0xzIvC'},
#         'href': 'https://api.spotify.com/v1/artists/4NgfOZCL9Ml67xzM0xzIvC',
#         'id': '4NgfOZCL9Ml67xzM0xzIvC',
#         'name': 'Janis Joplin',
#         'type': 'artist',
#         'uri': 'spotify:artist:4NgfOZCL9Ml67xzM0xzIvC'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/4qHWXbp5TbUWqH35c6m8kN'},
#       'href': 'https://api.spotify.com/v1/albums/4qHWXbp5TbUWqH35c6m8kN',
#       'id': '4qHWXbp5TbUWqH35c6m8kN',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273bd1e98815e82e04ba980c65c',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02bd1e98815e82e04ba980c65c',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851bd1e98815e82e04ba980c65c',
#         'width': 64}],
#       'name': "Janis Joplin's Greatest Hits",
#       'release_date': '1973-06-22',
#       'release_date_precision': 'day',
#       'total_tracks': 12,
#       'type': 'album',
#       'uri': 'spotify:album:4qHWXbp5TbUWqH35c6m8kN'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NgfOZCL9Ml67xzM0xzIvC'},
#        'href': 'https://api.spotify.com/v1/artists/4NgfOZCL9Ml67xzM0xzIvC',
#        'id': '4NgfOZCL9Ml67xzM0xzIvC',
#        'name': 'Janis Joplin',
#        'type': 'artist',
#        'uri': 'spotify:artist:4NgfOZCL9Ml67xzM0xzIvC'}],
#      'disc_number': 1,
#      'duration_ms': 269493,
#      'explicit': False,
#      'external_ids': {'isrc': 'USSM17000790'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/28VuJueWxC1JlIAUvmMkMi'},
#      'href': 'https://api.spotify.com/v1/tracks/28VuJueWxC1JlIAUvmMkMi',
#      'id': '28VuJueWxC1JlIAUvmMkMi',
#      'is_local': False,
#      'is_playable': True,
#      'name': 'Me and Bobby McGee',
#      'popularity': 28,
#      'preview_url': 'https://p.scdn.co/mp3-preview/dea029d78a33995c3108578aae05ba6ff40a7576?cid=d4726b15e5b34b0fa3c825aaea90d658',
#      'track_number': 5,
#      'type': 'track',
#      'uri': 'spotify:track:28VuJueWxC1JlIAUvmMkMi'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NgfOZCL9Ml67xzM0xzIvC'},
#         'href': 'https://api.spotify.com/v1/artists/4NgfOZCL9Ml67xzM0xzIvC',
#         'id': '4NgfOZCL9Ml67xzM0xzIvC',
#         'name': 'Janis Joplin',
#         'type': 'artist',
#         'uri': 'spotify:artist:4NgfOZCL9Ml67xzM0xzIvC'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/5F6Th386ar5HNmOkcA0QrK'},
#       'href': 'https://api.spotify.com/v1/albums/5F6Th386ar5HNmOkcA0QrK',
#       'id': '5F6Th386ar5HNmOkcA0QrK',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b27310715fc320db4594c37dfb8f',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e0210715fc320db4594c37dfb8f',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d0000485110715fc320db4594c37dfb8f',
#         'width': 64}],
#       'name': 'Janis: Little Girl Blue (Original Motion Picture Soundtrack)',
#       'release_date': '2016-02-12',
#       'release_date_precision': 'day',
#       'total_tracks': 17,
#       'type': 'album',
#       'uri': 'spotify:album:5F6Th386ar5HNmOkcA0QrK'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NgfOZCL9Ml67xzM0xzIvC'},
#        'href': 'https://api.spotify.com/v1/artists/4NgfOZCL9Ml67xzM0xzIvC',
#        'id': '4NgfOZCL9Ml67xzM0xzIvC',
#        'name': 'Janis Joplin',
#        'type': 'artist',
#        'uri': 'spotify:artist:4NgfOZCL9Ml67xzM0xzIvC'}],
#      'disc_number': 1,
#      'duration_ms': 392520,
#      'explicit': False,
#      'external_ids': {'isrc': 'USSM17000888'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/5cSLT6bJti7KpIQGEzA1Si'},
#      'href': 'https://api.spotify.com/v1/tracks/5cSLT6bJti7KpIQGEzA1Si',
#      'id': '5cSLT6bJti7KpIQGEzA1Si',
#      'is_local': False,
#      'is_playable': True,
#      'name': 'Tell Mama - Live at McMahon Stadium, Calgary, Canada - July 1970',
#      'popularity': 34,
#      'preview_url': 'https://p.scdn.co/mp3-preview/a3563d481da74b718254f8ee66c5ae963741497e?cid=d4726b15e5b34b0fa3c825aaea90d658',
#      'track_number': 14,
#      'type': 'track',
#      'uri': 'spotify:track:5cSLT6bJti7KpIQGEzA1Si'},
#     {'album': {'album_type': 'compilation',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NgfOZCL9Ml67xzM0xzIvC'},
#         'href': 'https://api.spotify.com/v1/artists/4NgfOZCL9Ml67xzM0xzIvC',
#         'id': '4NgfOZCL9Ml67xzM0xzIvC',
#         'name': 'Janis Joplin',
#         'type': 'artist',
#         'uri': 'spotify:artist:4NgfOZCL9Ml67xzM0xzIvC'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/2uEM5GPliifxJ0llkQ59oR'},
#       'href': 'https://api.spotify.com/v1/albums/2uEM5GPliifxJ0llkQ59oR',
#       'id': '2uEM5GPliifxJ0llkQ59oR',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b2739c3c9a199b867758ffe57976',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e029c3c9a199b867758ffe57976',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d000048519c3c9a199b867758ffe57976',
#         'width': 64}],
#       'name': 'Box Of Pearls',
#       'release_date': '1999-08-23',
#       'release_date_precision': 'day',
#       'total_tracks': 55,
#       'type': 'album',
#       'uri': 'spotify:album:2uEM5GPliifxJ0llkQ59oR'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4NgfOZCL9Ml67xzM0xzIvC'},
#        'href': 'https://api.spotify.com/v1/artists/4NgfOZCL9Ml67xzM0xzIvC',
#        'id': '4NgfOZCL9Ml67xzM0xzIvC',
#        'name': 'Janis Joplin',
#        'type': 'artist',
#        'uri': 'spotify:artist:4NgfOZCL9Ml67xzM0xzIvC'}],
#      'disc_number': 3,
#      'duration_ms': 151133,
#      'explicit': False,
#      'external_ids': {'isrc': 'USSM16900168'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/1rH1PF17P6p7frsbkd0kIq'},
#      'href': 'https://api.spotify.com/v1/tracks/1rH1PF17P6p7frsbkd0kIq',
#      'id': '1rH1PF17P6p7frsbkd0kIq',
#      'is_local': False,
#      'is_playable': True,
#      'name': 'Dear Landlord',
#      'popularity': 32,
#      'preview_url': 'https://p.scdn.co/mp3-preview/2b4ae14b33bdbcfb55acbdf6a1b723a23cb98469?cid=d4726b15e5b34b0fa3c825aaea90d658',
#      'track_number': 9,
#      'type': 'track',
#      'uri': 'spotify:track:1rH1PF17P6p7frsbkd0kIq'},
#     {'album': {'album_type': 'album',
#       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4J69yWrKwWJgjv3DKTZcGo'},
#         'href': 'https://api.spotify.com/v1/artists/4J69yWrKwWJgjv3DKTZcGo',
#         'id': '4J69yWrKwWJgjv3DKTZcGo',
#         'name': 'Big Brother & The Holding Company',
#         'type': 'artist',
#         'uri': 'spotify:artist:4J69yWrKwWJgjv3DKTZcGo'},
#        {'external_urls': {'spotify': 'https://open.spotify.com/artist/4NgfOZCL9Ml67xzM0xzIvC'},
#         'href': 'https://api.spotify.com/v1/artists/4NgfOZCL9Ml67xzM0xzIvC',
#         'id': '4NgfOZCL9Ml67xzM0xzIvC',
#         'name': 'Janis Joplin',
#         'type': 'artist',
#         'uri': 'spotify:artist:4NgfOZCL9Ml67xzM0xzIvC'}],
#       'external_urls': {'spotify': 'https://open.spotify.com/album/4W821NJLoB9uHHkAFNXXKu'},
#       'href': 'https://api.spotify.com/v1/albums/4W821NJLoB9uHHkAFNXXKu',
#       'id': '4W821NJLoB9uHHkAFNXXKu',
#       'images': [{'height': 640,
#         'url': 'https://i.scdn.co/image/ab67616d0000b273555cadb7c5c8ad8bd20ac373',
#         'width': 640},
#        {'height': 300,
#         'url': 'https://i.scdn.co/image/ab67616d00001e02555cadb7c5c8ad8bd20ac373',
#         'width': 300},
#        {'height': 64,
#         'url': 'https://i.scdn.co/image/ab67616d00004851555cadb7c5c8ad8bd20ac373',
#         'width': 64}],
#       'name': 'Big Brother & The Holding Company',
#       'release_date': '1967',
#       'release_date_precision': 'year',
#       'total_tracks': 12,
#       'type': 'album',
#       'uri': 'spotify:album:4W821NJLoB9uHHkAFNXXKu'},
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4J69yWrKwWJgjv3DKTZcGo'},
#        'href': 'https://api.spotify.com/v1/artists/4J69yWrKwWJgjv3DKTZcGo',
#        'id': '4J69yWrKwWJgjv3DKTZcGo',
#        'name': 'Big Brother & The Holding Company',
#        'type': 'artist',
#        'uri': 'spotify:artist:4J69yWrKwWJgjv3DKTZcGo'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4NgfOZCL9Ml67xzM0xzIvC'},
#        'href': 'https://api.spotify.com/v1/artists/4NgfOZCL9Ml67xzM0xzIvC',
#        'id': '4NgfOZCL9Ml67xzM0xzIvC',
#        'name': 'Janis Joplin',
#        'type': 'artist',
#        'uri': 'spotify:artist:4NgfOZCL9Ml67xzM0xzIvC'}],
#      'disc_number': 1,
#      'duration_ms': 157200,
#      'explicit': False,
#      'external_ids': {'isrc': 'USSM16601321'},
#      'external_urls': {'spotify': 'https://open.spotify.com/track/7E6RJ05OosW2yd7mv3EwpN'},
#      'href': 'https://api.spotify.com/v1/tracks/7E6RJ05OosW2yd7mv3EwpN',
#      'id': '7E6RJ05OosW2yd7mv3EwpN',
#      'is_local': False,
#      'is_playable': True,
#      'name': 'Bye, Bye Baby',
#      'popularity': 37,
#      'preview_url': 'https://p.scdn.co/mp3-preview/abaa5b1615d34cf46443848d00f083658928e54a?cid=d4726b15e5b34b0fa3c825aaea90d658',
#      'track_number': 1,
#      'type': 'track',
#      'uri': 'spotify:track:7E6RJ05OosW2yd7mv3EwpN'}],
#    'limit': 50,
#    'next': 'https://api.spotify.com/v1/search?query=Janis+Joplin&type=track&market=GB&offset=50&limit=50',
#    'offset': 0,
#    'previous': None,
#    'total': 1111}}}

# %%
len(my_dict['Janis Joplin']['tracks']['items'])
# Out:
# 50

# %%
type(my_dict['Janis Joplin']['tracks']['items'][0])
# Out:
# dict

# %%
my_dict['Janis Joplin']['tracks']['items'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %% [markdown]
# # Understanding the json

# %% [markdown]
# Understanding the hierachy of a JSON can make you mad. Therefore you can cosider using some online pages where you can paste your JSON file and see the "tree" structure of the file.
#
# https://codebeautify.org/jsonviewer
#
# So, copy the json output from the previous query and paste it on the website's left panel. On the right panel you will be able to see the hierachy of the json file.

# %% [markdown]
# Let's get used to the json at hand.

# %%
print("The json file has the following keys: ",list(results.keys())) # We can see that we only have tracks
print("The 'tracks' key has the following child keys: ",list(results["tracks"].keys())) # Let's check the values
print("The query we made is: ",results["tracks"]["href"]) # Query we have searched 
print("The song's info is contained in: ",results["tracks"]["items"]) #items (actual tracks)
print("The limit of the query we've made is: ",results["tracks"]["limit"]) #Limit we have chosen
print("The next page if any: ",results["tracks"]["next"]) #link to the next page (next 50 tracks)
print("The starting webpage: ",results["tracks"]["offset"]) # Actual offset (starting point)
print("Starting webpage: ",results["tracks"]["previous"]) #Previous search
print("Total number of results: ",results["tracks"]["total"]) # Number of matches
# Out:
# The json file has the following keys:  ['tracks']
# The 'tracks' key has the following child keys:  ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# The query we made is:  https://api.spotify.com/v1/search?query=Billie+Eilish&type=track&offset=0&limit=5
# The song's info is contained in:  [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'}, 'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH', 'id': '6qqNVTkY8uBg9cP3Jd7DAH', 'name': 'Billie Eilish', 'type': 'artist', 'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RU', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'}, 'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp', 'id': '0JGOiO34nwfUdDrD612dOp', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e', 'width': 64}], 'name': 'Happier Than Ever', 'release_date': '2021-07-30', 'release_date_precision': 'day', 'total_tracks': 16, 'type': 'album', 'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'}, 'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH', 'id': '6qqNVTkY8uBg9cP3Jd7DAH', 'name': 'Billie Eilish', 'type': 'artist', 'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RU', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'disc_number': 1, 'duration_ms': 298899, 'explicit': True, 'external_ids': {'isrc': 'USUM72105936'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/4RVwu0g32PAqgUiJoXsdF8'}, 'href': 'https://api.spotify.com/v1/tracks/4RVwu0g32PAqgUiJoXsdF8', 'id': '4RVwu0g32PAqgUiJoXsdF8', 'is_local': False, 'name': 'Happier Than Ever', 'popularity': 94, 'preview_url': None, 'track_number': 15, 'type': 'track', 'uri': 'spotify:track:4RVwu0g32PAqgUiJoXsdF8'}, {'album ...
# The limit of the query we've made is:  5
# The next page if any:  https://api.spotify.com/v1/search?query=Billie+Eilish&type=track&offset=5&limit=5
# The starting webpage:  0
# Starting webpage:  None
# Total number of results:  1182

# %% [markdown]
# ## Exploring the tracks

# %%
print("Total number of tracks: ",len(results["tracks"]["items"])) # 50 Tracks (as limited, it is the maximum)
print("Info of the first song: ",results["tracks"]["items"][0]) # Explore the first song 
print("The keys of the dictionary are: ",list(results["tracks"]["items"][0].keys())) # We will focus on album, artists, id, name, popularity, type and uri
# Out:
# Total number of tracks:  5
# Info of the first song:  {'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'}, 'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH', 'id': '6qqNVTkY8uBg9cP3Jd7DAH', 'name': 'Billie Eilish', 'type': 'artist', 'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RU', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'}, 'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp', 'id': '0JGOiO34nwfUdDrD612dOp', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e', 'width': 64}], 'name': 'Happier Than Ever', 'release_date': '2021-07-30', 'release_date_precision': 'day', 'total_tracks': 16, 'type': 'album', 'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'}, 'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH', 'id': '6qqNVTkY8uBg9cP3Jd7DAH', 'name': 'Billie Eilish', 'type': 'artist', 'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RU', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'disc_number': 1, 'duration_ms': 298899, 'explicit': True, 'external_ids': {'isrc': 'USUM72105936'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/4RVwu0g32PAqgUiJoXsdF8'}, 'href': 'https://api.spotify.com/v1/tracks/4RVwu0g32PAqgUiJoXsdF8', 'id': '4RVwu0g32PAqgUiJoXsdF8', 'is_local': False, 'name': 'Happier Than Ever', 'popularity': 94, 'preview_url': None, 'track_number': 15, 'type': 'track', 'uri': 'spotify:track:4RVwu0g32PAqgUiJoXsdF8'}
# The keys of the dictionary are:  ['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri']

# %% [markdown]
# ## Checking albums

# %%
print(results["tracks"]["items"][0]["album"]) # we have more info about the album
print(list(results["tracks"]["items"][0]["album"].keys())) # Will check artists, id, name, release date, total tracks 
print(results["tracks"]["items"][0]["album"]["artists"]) # List with artists and information
print("The album ID is: ",results["tracks"]["items"][0]["album"]["id"]) # Album ID 
print(results["tracks"]["items"][0]["album"]["name"]) # Album name (if its a single u'll get the name of the song)
print(results["tracks"]["items"][0]["album"]["release_date"]) #date in YYYY-MM-DD format
print("Songs in the album: ",results["tracks"]["items"][0]["album"]["total_tracks"]) #songs in the album
# Out:
# {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'}, 'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH', 'id': '6qqNVTkY8uBg9cP3Jd7DAH', 'name': 'Billie Eilish', 'type': 'artist', 'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'FR', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MG', 'MH', 'MK', 'ML', 'MN', 'MO', 'MR', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NZ', 'OM', 'PA', 'PE', 'PG', 'PH', 'PK', 'PL', 'PS', 'PT', 'PW', 'PY', 'QA', 'RO', 'RS', 'RU', 'RW', 'SA', 'SB', 'SC', 'SE', 'SG', 'SI', 'SK', 'SL', 'SM', 'SN', 'SR', 'ST', 'SV', 'SZ', 'TD', 'TG', 'TH', 'TL', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'US', 'UY', 'UZ', 'VC', 'VN', 'VU', 'WS', 'XK', 'ZA', 'ZM', 'ZW'], 'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'}, 'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp', 'id': '0JGOiO34nwfUdDrD612dOp', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e', 'width': 64}], 'name': 'Happier Than Ever', 'release_date': '2021-07-30', 'release_date_precision': 'day', 'total_tracks': 16, 'type': 'album', 'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'}
# ['album_type', 'artists', 'available_markets', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri']
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'}, 'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH', 'id': '6qqNVTkY8uBg9cP3Jd7DAH', 'name': 'Billie Eilish', 'type': 'artist', 'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}]
# The album ID is:  0JGOiO34nwfUdDrD612dOp
# Happier Than Ever
# 2021-07-30
# Songs in the album:  16

# %% [markdown]
# ## Other info

# %%
results["tracks"]["items"][0]["artists"] # Track artists
results["tracks"]["items"][0]["id"] # Track ID
results["tracks"]["items"][0]["name"] # Track name
results["tracks"]["items"][0]["popularity"] # Popularity index
results["tracks"]["items"][0]["uri"] # Basically ID
# Out:
# 'spotify:track:4RVwu0g32PAqgUiJoXsdF8'

# %% [markdown]
# # Exploring songs

# %% [markdown]
# ## Searching a playlist

# %%
playlist = sp.user_playlist_tracks("spotify", "4rnleEAOdmFAbRcNCgZMpY")

# %%
type(playlist)
# Out:
# dict

# %%
print(list(playlist.keys())) # Let's look at items and total:
print("Total number of songs in the playlist: ",playlist["total"]) # 4Ksongs!! Let's check items:
len(playlist["items"]) # It is limited to 100 tracks, we will have to fix it:
# Out:
# ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# Total number of songs in the playlist:  5295
# 100

# %% [markdown]
# ## Extracting the songs of a playlist

# %% [markdown]
# Pagination using "next"
# When you collect songs from a playlist using sp.playlist_tracks, you're limited by the limit parameter, which has a maximum (and default) value of 100. When the playlist has more than 100 songs, you have to collect them by navigating through the "pages" of the results.
#
# The parameter offset allows you to retrieve resuls starting at a certain position: if you start at position 101, you'd get the next "page" of results. An offset of 201 would give you the third page, and so on.
#
# The function sp.next() does the same, but in a simpler way: it can be used on the results from any request to directly retrieve the results for the next page.
#
# We can check whether there's a next page or not by accessing the key next on the results from any request.

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

get_playlist_tracks("spotify", "37i9dQZF1DX6cg4h2PoN9y")
# Out:
# [{'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#     'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#     'id': '0JGOiO34nwfUdDrD612dOp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#       'width': 64}],
#     'name': 'Happier Than Ever',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 298899,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUM72105936'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4RVwu0g32PAqgUiJoXsdF8'},
#    'href': 'https://api.spotify.com/v1/tracks/4RVwu0g32PAqgUiJoXsdF8',
#    'id': '4RVwu0g32PAqgUiJoXsdF8',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Happier Than Ever',
#    'popularity': 94,
#    'preview_url': None,
#    'track': True,
#    'track_number': 15,
#    'type': 'track',
#    'uri': 'spotify:track:4RVwu0g32PAqgUiJoXsdF8'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5tzRuO6GP7WRvP3rEOPAO9'},
#     'href': 'https://api.spotify.com/v1/albums/5tzRuO6GP7WRvP3rEOPAO9',
#     'id': '5tzRuO6GP7WRvP3rEOPAO9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e1317227c6c759e01beae66e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e1317227c6c759e01beae66e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e1317227c6c759e01beae66e',
#       'width': 64}],
#     'name': 'Happier Than Ever',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:5tzRuO6GP7WRvP3rEOPAO9'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 244221,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72105922'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/42dosBqMOdtgxKw0KRFJF0'},
#    'href': 'https://api.spotify.com/v1/tracks/42dosBqMOdtgxKw0KRFJF0',
#    'id': '42dosBqMOdtgxKw0KRFJF0',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Getting Older',
#    'popularity': 65,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:42dosBqMOdtgxKw0KRFJF0'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#     'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#     'id': '0JGOiO34nwfUdDrD612dOp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#       'width': 64}],
#     'name': 'Happier Than Ever',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 158463,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUM72105926'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7bcy34fBT2ap1L4bfPsl9q'},
#    'href': 'https://api.spotify.com/v1/tracks/7bcy34fBT2ap1L4bfPsl9q',
#    'id': '7bcy34fBT2ap1L4bfPsl9q',
#    'is_local': False,
#    'is_playable': True,
#    'name': "I Didn't Change My Number",
#    'popularity': 80,
#    'preview_url': None,
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:7bcy34fBT2ap1L4bfPsl9q'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#     'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#     'id': '0JGOiO34nwfUdDrD612dOp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#       'width': 64}],
#     'name': 'Happier Than Ever',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 196730,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72105927'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2KnuaZYoGzDoHiBTNYOTXG'},
#    'href': 'https://api.spotify.com/v1/tracks/2KnuaZYoGzDoHiBTNYOTXG',
#    'id': '2KnuaZYoGzDoHiBTNYOTXG',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Billie Bossa Nova',
#    'popularity': 81,
#    'preview_url': None,
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:2KnuaZYoGzDoHiBTNYOTXG'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5tzRuO6GP7WRvP3rEOPAO9'},
#     'href': 'https://api.spotify.com/v1/albums/5tzRuO6GP7WRvP3rEOPAO9',
#     'id': '5tzRuO6GP7WRvP3rEOPAO9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e1317227c6c759e01beae66e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e1317227c6c759e01beae66e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e1317227c6c759e01beae66e',
#       'width': 64}],
#     'name': 'Happier Than Ever',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:5tzRuO6GP7WRvP3rEOPAO9'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 210232,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72104675'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0UJAH9v2PmS7sBcuBquprR'},
#    'href': 'https://api.spotify.com/v1/tracks/0UJAH9v2PmS7sBcuBquprR',
#    'id': '0UJAH9v2PmS7sBcuBquprR',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Oxytocin',
#    'popularity': 68,
#    'preview_url': None,
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:0UJAH9v2PmS7sBcuBquprR'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3oxhQpF3Twbkl18oQYfnh5'},
#     'href': 'https://api.spotify.com/v1/albums/3oxhQpF3Twbkl18oQYfnh5',
#     'id': '3oxhQpF3Twbkl18oQYfnh5',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273954fe13f7c5f4b2f18d066b8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02954fe13f7c5f4b2f18d066b8',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851954fe13f7c5f4b2f18d066b8',
#       'width': 64}],
#     'name': 'my future',
#     'release_date': '2020-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3oxhQpF3Twbkl18oQYfnh5'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 208155,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72013019'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2ygvZOXrIeVL4xZmAWJT2C'},
#    'href': 'https://api.spotify.com/v1/tracks/2ygvZOXrIeVL4xZmAWJT2C',
#    'id': '2ygvZOXrIeVL4xZmAWJT2C',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'my future',
#    'popularity': 74,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2ygvZOXrIeVL4xZmAWJT2C'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#     'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#     'id': '0JGOiO34nwfUdDrD612dOp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#       'width': 64}],
#     'name': 'Happier Than Ever',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 151536,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72105928'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0FfqyjhB6Kspvit1oOo7ax'},
#    'href': 'https://api.spotify.com/v1/tracks/0FfqyjhB6Kspvit1oOo7ax',
#    'id': '0FfqyjhB6Kspvit1oOo7ax',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'GOLDWING',
#    'popularity': 77,
#    'preview_url': None,
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:0FfqyjhB6Kspvit1oOo7ax'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5tzRuO6GP7WRvP3rEOPAO9'},
#     'href': 'https://api.spotify.com/v1/albums/5tzRuO6GP7WRvP3rEOPAO9',
#     'id': '5tzRuO6GP7WRvP3rEOPAO9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e1317227c6c759e01beae66e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e1317227c6c759e01beae66e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e1317227c6c759e01beae66e',
#       'width': 64}],
#     'name': 'Happier Than Ever',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:5tzRuO6GP7WRvP3rEOPAO9'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 212496,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72106984'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1LdXpFzKjF7Jz6jA82DYs0'},
#    'href': 'https://api.spotify.com/v1/tracks/1LdXpFzKjF7Jz6jA82DYs0',
#    'id': '1LdXpFzKjF7Jz6jA82DYs0',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/3fHNjvF6AU1LXVez0wnFvw'},
#     'href': 'https://api.spotify.com/v1/tracks/3fHNjvF6AU1LXVez0wnFvw',
#     'id': '3fHNjvF6AU1LXVez0wnFvw',
#     'type': 'track',
#     'uri': 'spotify:track:3fHNjvF6AU1LXVez0wnFvw'},
#    'name': 'Lost Cause',
#    'popularity': 64,
#    'preview_url': None,
#    'track': True,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:1LdXpFzKjF7Jz6jA82DYs0'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#     'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#     'id': '0JGOiO34nwfUdDrD612dOp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#       'width': 64}],
#     'name': 'Happier Than Ever',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 234761,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72105930'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5XsAal7ZcWg1I5T4NcRjkv'},
#    'href': 'https://api.spotify.com/v1/tracks/5XsAal7ZcWg1I5T4NcRjkv',
#    'id': '5XsAal7ZcWg1I5T4NcRjkv',
#    'is_local': False,
#    'is_playable': True,
#    'name': "Halley's Comet",
#    'popularity': 79,
#    'preview_url': None,
#    'track': True,
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:5XsAal7ZcWg1I5T4NcRjkv'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#     'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#     'id': '0JGOiO34nwfUdDrD612dOp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#       'width': 64}],
#     'name': 'Happier Than Ever',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 227679,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72105931'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4T2zre0jqstNJ5Gt0WG9lz'},
#    'href': 'https://api.spotify.com/v1/tracks/4T2zre0jqstNJ5Gt0WG9lz',
#    'id': '4T2zre0jqstNJ5Gt0WG9lz',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Not My Responsibility',
#    'popularity': 75,
#    'preview_url': None,
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:4T2zre0jqstNJ5Gt0WG9lz'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#     'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#     'id': '0JGOiO34nwfUdDrD612dOp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#       'width': 64}],
#     'name': 'Happier Than Ever',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 214058,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUM72105932'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5uSG6fUPRaehaV820zcpsK'},
#    'href': 'https://api.spotify.com/v1/tracks/5uSG6fUPRaehaV820zcpsK',
#    'id': '5uSG6fUPRaehaV820zcpsK',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'OverHeated',
#    'popularity': 76,
#    'preview_url': None,
#    'track': True,
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:5uSG6fUPRaehaV820zcpsK'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#     'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#     'id': '0JGOiO34nwfUdDrD612dOp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#       'width': 64}],
#     'name': 'Happier Than Ever',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 206622,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72105933'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5jhBwnqzNNrENXnYrAdoCe'},
#    'href': 'https://api.spotify.com/v1/tracks/5jhBwnqzNNrENXnYrAdoCe',
#    'id': '5jhBwnqzNNrENXnYrAdoCe',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Everybody Dies',
#    'popularity': 76,
#    'preview_url': None,
#    'track': True,
#    'track_number': 11,
#    'type': 'track',
#    'uri': 'spotify:track:5jhBwnqzNNrENXnYrAdoCe'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#     'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#     'id': '0JGOiO34nwfUdDrD612dOp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#       'width': 64}],
#     'name': 'Happier Than Ever',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 245896,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72105934'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/042Sl6Mn83JHyLEqdK7uI0'},
#    'href': 'https://api.spotify.com/v1/tracks/042Sl6Mn83JHyLEqdK7uI0',
#    'id': '042Sl6Mn83JHyLEqdK7uI0',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5qNh5WtzMbfpSj2jLlBkoD'},
#     'href': 'https://api.spotify.com/v1/tracks/5qNh5WtzMbfpSj2jLlBkoD',
#     'id': '5qNh5WtzMbfpSj2jLlBkoD',
#     'type': 'track',
#     'uri': 'spotify:track:5qNh5WtzMbfpSj2jLlBkoD'},
#    'name': 'Your Power',
#    'popularity': 81,
#    'preview_url': None,
#    'track': True,
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:042Sl6Mn83JHyLEqdK7uI0'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#     'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#     'id': '0JGOiO34nwfUdDrD612dOp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#       'width': 64}],
#     'name': 'Happier Than Ever',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 195776,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUM72105935'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/38GBNKZUhfBkk3oNlWzRYd'},
#    'href': 'https://api.spotify.com/v1/tracks/38GBNKZUhfBkk3oNlWzRYd',
#    'id': '38GBNKZUhfBkk3oNlWzRYd',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/6uqyE384HDSsuwpoF4mjrL'},
#     'href': 'https://api.spotify.com/v1/tracks/6uqyE384HDSsuwpoF4mjrL',
#     'id': '6uqyE384HDSsuwpoF4mjrL',
#     'type': 'track',
#     'uri': 'spotify:track:6uqyE384HDSsuwpoF4mjrL'},
#    'name': 'NDA',
#    'popularity': 83,
#    'preview_url': None,
#    'track': True,
#    'track_number': 13,
#    'type': 'track',
#    'uri': 'spotify:track:38GBNKZUhfBkk3oNlWzRYd'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5G58VVE9ub1KE01Mvbd8XM'},
#     'href': 'https://api.spotify.com/v1/albums/5G58VVE9ub1KE01Mvbd8XM',
#     'id': '5G58VVE9ub1KE01Mvbd8XM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737a152619a7b55bc621d07901',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027a152619a7b55bc621d07901',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517a152619a7b55bc621d07901',
#       'width': 64}],
#     'name': 'Therefore I Am',
#     'release_date': '2020-11-12',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5G58VVE9ub1KE01Mvbd8XM'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 174321,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72021500'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/54bFM56PmE4YLRnqpW6Tha'},
#    'href': 'https://api.spotify.com/v1/tracks/54bFM56PmE4YLRnqpW6Tha',
#    'id': '54bFM56PmE4YLRnqpW6Tha',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Therefore I Am',
#    'popularity': 80,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:54bFM56PmE4YLRnqpW6Tha'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5tzRuO6GP7WRvP3rEOPAO9'},
#     'href': 'https://api.spotify.com/v1/albums/5tzRuO6GP7WRvP3rEOPAO9',
#     'id': '5tzRuO6GP7WRvP3rEOPAO9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e1317227c6c759e01beae66e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e1317227c6c759e01beae66e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e1317227c6c759e01beae66e',
#       'width': 64}],
#     'name': 'Happier Than Ever',
#     'release_date': '2021-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:5tzRuO6GP7WRvP3rEOPAO9'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 194886,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72105937'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/13lUUFsU6GMvRDN432qKxX'},
#    'href': 'https://api.spotify.com/v1/tracks/13lUUFsU6GMvRDN432qKxX',
#    'id': '13lUUFsU6GMvRDN432qKxX',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Male Fantasy',
#    'popularity': 61,
#    'preview_url': None,
#    'track': True,
#    'track_number': 16,
#    'type': 'track',
#    'uri': 'spotify:track:13lUUFsU6GMvRDN432qKxX'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4i3rAwPw7Ln2YrKDusaWyT'},
#     'href': 'https://api.spotify.com/v1/albums/4i3rAwPw7Ln2YrKDusaWyT',
#     'id': '4i3rAwPw7Ln2YrKDusaWyT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f2248cf6dad1d6c062587249',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f2248cf6dad1d6c062587249',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f2248cf6dad1d6c062587249',
#       'width': 64}],
#     'name': 'everything i wanted',
#     'release_date': '2019-11-13',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:4i3rAwPw7Ln2YrKDusaWyT'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 245425,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71922577'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3ZCTVFBt2Brf31RLEnCkWJ'},
#    'href': 'https://api.spotify.com/v1/tracks/3ZCTVFBt2Brf31RLEnCkWJ',
#    'id': '3ZCTVFBt2Brf31RLEnCkWJ',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'everything i wanted',
#    'popularity': 81,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3ZCTVFBt2Brf31RLEnCkWJ'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5sXSHscDjBez8VF20cSyad'},
#     'href': 'https://api.spotify.com/v1/albums/5sXSHscDjBez8VF20cSyad',
#     'id': '5sXSHscDjBez8VF20cSyad',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f7b7174bef6f3fbfda3a0bb7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f7b7174bef6f3fbfda3a0bb7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f7b7174bef6f3fbfda3a0bb7',
#       'width': 64}],
#     'name': 'No Time To Die',
#     'release_date': '2020-02-13',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5sXSHscDjBez8VF20cSyad'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'disc_number': 1,
#    'duration_ms': 242265,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72002771'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/73SpzrcaHk0RQPFP73vqVR'},
#    'href': 'https://api.spotify.com/v1/tracks/73SpzrcaHk0RQPFP73vqVR',
#    'id': '73SpzrcaHk0RQPFP73vqVR',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'No Time To Die',
#    'popularity': 73,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:73SpzrcaHk0RQPFP73vqVR'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7ltDVBr6mKbRvohxheJ9h1'},
#       'href': 'https://api.spotify.com/v1/artists/7ltDVBr6mKbRvohxheJ9h1',
#       'id': '7ltDVBr6mKbRvohxheJ9h1',
#       'name': 'ROSALÍA',
#       'type': 'artist',
#       'uri': 'spotify:artist:7ltDVBr6mKbRvohxheJ9h1'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4E8puNI8tw7cXz6YJkwMew'},
#     'href': 'https://api.spotify.com/v1/albums/4E8puNI8tw7cXz6YJkwMew',
#     'id': '4E8puNI8tw7cXz6YJkwMew',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c64ed7bab63186d7fca3012f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c64ed7bab63186d7fca3012f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c64ed7bab63186d7fca3012f',
#       'width': 64}],
#     'name': 'Lo Vas A Olvidar (with ROSALÍA)',
#     'release_date': '2021-01-21',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:4E8puNI8tw7cXz6YJkwMew'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7ltDVBr6mKbRvohxheJ9h1'},
#      'href': 'https://api.spotify.com/v1/artists/7ltDVBr6mKbRvohxheJ9h1',
#      'id': '7ltDVBr6mKbRvohxheJ9h1',
#      'name': 'ROSALÍA',
#      'type': 'artist',
#      'uri': 'spotify:artist:7ltDVBr6mKbRvohxheJ9h1'}],
#    'disc_number': 1,
#    'duration_ms': 203464,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72100008'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0psS4i5YooJrXfDnGvWRLi'},
#    'href': 'https://api.spotify.com/v1/tracks/0psS4i5YooJrXfDnGvWRLi',
#    'id': '0psS4i5YooJrXfDnGvWRLi',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0jagsVVkxwxhmTIicnOaon'},
#     'href': 'https://api.spotify.com/v1/tracks/0jagsVVkxwxhmTIicnOaon',
#     'id': '0jagsVVkxwxhmTIicnOaon',
#     'type': 'track',
#     'uri': 'spotify:track:0jagsVVkxwxhmTIicnOaon'},
#    'name': 'Lo Vas A Olvidar (with ROSALÍA)',
#    'popularity': 66,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0psS4i5YooJrXfDnGvWRLi'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2AyexmwyUy1nZfBadyewL7'},
#     'href': 'https://api.spotify.com/v1/albums/2AyexmwyUy1nZfBadyewL7',
#     'id': '2AyexmwyUy1nZfBadyewL7',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27398a3d331aad09aede2a9dcad',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0298a3d331aad09aede2a9dcad',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485198a3d331aad09aede2a9dcad',
#       'width': 64}],
#     'name': 'ilomilo (Live From The Film - Billie Eilish: The World’s A Little Blurry)',
#     'release_date': '2021-02-22',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2AyexmwyUy1nZfBadyewL7'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
# ...
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/44OSkEmvHwdTFhPBCewIks'},
#     'href': 'https://api.spotify.com/v1/albums/44OSkEmvHwdTFhPBCewIks',
#     'id': '44OSkEmvHwdTFhPBCewIks',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732dc817144c8081281f77508d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022dc817144c8081281f77508d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512dc817144c8081281f77508d',
#       'width': 64}],
#     'name': 'Ocean Eyes (The Remixes)',
#     'release_date': '2017-01-13',
#     'release_date_precision': 'day',
#     'total_tracks': 4,
#     'type': 'album',
#     'uri': 'spotify:album:44OSkEmvHwdTFhPBCewIks'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3EpmmPtV7DduqNmeqaADIm'},
#      'href': 'https://api.spotify.com/v1/artists/3EpmmPtV7DduqNmeqaADIm',
#      'id': '3EpmmPtV7DduqNmeqaADIm',
#      'name': 'Astronomyy',
#      'type': 'artist',
#      'uri': 'spotify:artist:3EpmmPtV7DduqNmeqaADIm'}],
#    'disc_number': 1,
#    'duration_ms': 296266,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'TCACL1611532'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6NOq79ynBpBi6BSJMdgReN'},
#    'href': 'https://api.spotify.com/v1/tracks/6NOq79ynBpBi6BSJMdgReN',
#    'id': '6NOq79ynBpBi6BSJMdgReN',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Ocean Eyes - Astronomyy Remix',
#    'popularity': 62,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6NOq79ynBpBi6BSJMdgReN'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2I9wpUTuzMT8aS6iVpM2EQ'},
#     'href': 'https://api.spotify.com/v1/albums/2I9wpUTuzMT8aS6iVpM2EQ',
#     'id': '2I9wpUTuzMT8aS6iVpM2EQ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b16b427371c5fdd76f1b0ee1',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b16b427371c5fdd76f1b0ee1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b16b427371c5fdd76f1b0ee1',
#       'width': 64}],
#     'name': 'Bellyache (Marian Hill Remix)',
#     'release_date': '2017-05-05',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2I9wpUTuzMT8aS6iVpM2EQ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1xHQO9GJIW9OXHxGBISYc5'},
#      'href': 'https://api.spotify.com/v1/artists/1xHQO9GJIW9OXHxGBISYc5',
#      'id': '1xHQO9GJIW9OXHxGBISYc5',
#      'name': 'Marian Hill',
#      'type': 'artist',
#      'uri': 'spotify:artist:1xHQO9GJIW9OXHxGBISYc5'}],
#    'disc_number': 1,
#    'duration_ms': 220800,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71703692'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/61X077SWMs5aAGQHhf4pd0'},
#    'href': 'https://api.spotify.com/v1/tracks/61X077SWMs5aAGQHhf4pd0',
#    'id': '61X077SWMs5aAGQHhf4pd0',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Bellyache - Marian Hill Remix',
#    'popularity': 61,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:61X077SWMs5aAGQHhf4pd0'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/44OSkEmvHwdTFhPBCewIks'},
#     'href': 'https://api.spotify.com/v1/albums/44OSkEmvHwdTFhPBCewIks',
#     'id': '44OSkEmvHwdTFhPBCewIks',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732dc817144c8081281f77508d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022dc817144c8081281f77508d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512dc817144c8081281f77508d',
#       'width': 64}],
#     'name': 'Ocean Eyes (The Remixes)',
#     'release_date': '2017-01-13',
#     'release_date_precision': 'day',
#     'total_tracks': 4,
#     'type': 'album',
#     'uri': 'spotify:album:44OSkEmvHwdTFhPBCewIks'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2cFrymmkijnjDg9SS92EPM'},
#      'href': 'https://api.spotify.com/v1/artists/2cFrymmkijnjDg9SS92EPM',
#      'id': '2cFrymmkijnjDg9SS92EPM',
#      'name': 'blackbear',
#      'type': 'artist',
#      'uri': 'spotify:artist:2cFrymmkijnjDg9SS92EPM'}],
#    'disc_number': 1,
#    'duration_ms': 195306,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'TCACL1611534'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4JuZQeSRYJfLCqBgBIxxrR'},
#    'href': 'https://api.spotify.com/v1/tracks/4JuZQeSRYJfLCqBgBIxxrR',
#    'id': '4JuZQeSRYJfLCqBgBIxxrR',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Ocean Eyes - Blackbear Remix',
#    'popularity': 64,
#    'preview_url': None,
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:4JuZQeSRYJfLCqBgBIxxrR'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/586uxXMyD5ObPuzjtrzO1Q'},
#       'href': 'https://api.spotify.com/v1/artists/586uxXMyD5ObPuzjtrzO1Q',
#       'id': '586uxXMyD5ObPuzjtrzO1Q',
#       'name': 'Sofi Tukker',
#       'type': 'artist',
#       'uri': 'spotify:artist:586uxXMyD5ObPuzjtrzO1Q'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5XRJoC2QtsNbAubsCrBBbG'},
#     'href': 'https://api.spotify.com/v1/albums/5XRJoC2QtsNbAubsCrBBbG',
#     'id': '5XRJoC2QtsNbAubsCrBBbG',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738fbc40da547bc157e8956cea',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028fbc40da547bc157e8956cea',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518fbc40da547bc157e8956cea',
#       'width': 64}],
#     'name': 'COPYCAT (Sofi Tukker Remix)',
#     'release_date': '2018-01-12',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5XRJoC2QtsNbAubsCrBBbG'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/586uxXMyD5ObPuzjtrzO1Q'},
#      'href': 'https://api.spotify.com/v1/artists/586uxXMyD5ObPuzjtrzO1Q',
#      'id': '586uxXMyD5ObPuzjtrzO1Q',
#      'name': 'Sofi Tukker',
#      'type': 'artist',
#      'uri': 'spotify:artist:586uxXMyD5ObPuzjtrzO1Q'}],
#    'disc_number': 1,
#    'duration_ms': 198684,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71713025'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2njUxZ4151DWIrfIK3loFj'},
#    'href': 'https://api.spotify.com/v1/tracks/2njUxZ4151DWIrfIK3loFj',
#    'id': '2njUxZ4151DWIrfIK3loFj',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'COPYCAT - Sofi Tukker Remix',
#    'popularity': 60,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2njUxZ4151DWIrfIK3loFj'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7Chuv69qWaXuK5eCmZ8gCi'},
#     'href': 'https://api.spotify.com/v1/albums/7Chuv69qWaXuK5eCmZ8gCi',
#     'id': '7Chuv69qWaXuK5eCmZ8gCi',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737b9881aa297e336c0d4d5cef',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027b9881aa297e336c0d4d5cef',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517b9881aa297e336c0d4d5cef',
#       'width': 64}],
#     'name': 'Six Feet Under (The Remixes)',
#     'release_date': '2017-02-03',
#     'release_date_precision': 'day',
#     'total_tracks': 4,
#     'type': 'album',
#     'uri': 'spotify:album:7Chuv69qWaXuK5eCmZ8gCi'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/356FCJoyYWyzONni54Dgrv'},
#      'href': 'https://api.spotify.com/v1/artists/356FCJoyYWyzONni54Dgrv',
#      'id': '356FCJoyYWyzONni54Dgrv',
#      'name': 'Jerry Folk',
#      'type': 'artist',
#      'uri': 'spotify:artist:356FCJoyYWyzONni54Dgrv'}],
#    'disc_number': 1,
#    'duration_ms': 200898,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71700468'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/58nxGpcCfNDiqmFXklOslz'},
#    'href': 'https://api.spotify.com/v1/tracks/58nxGpcCfNDiqmFXklOslz',
#    'id': '58nxGpcCfNDiqmFXklOslz',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Six Feet Under - Jerry Folk Remix',
#    'popularity': 57,
#    'preview_url': None,
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:58nxGpcCfNDiqmFXklOslz'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-07-29T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/44OSkEmvHwdTFhPBCewIks'},
#     'href': 'https://api.spotify.com/v1/albums/44OSkEmvHwdTFhPBCewIks',
#     'id': '44OSkEmvHwdTFhPBCewIks',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732dc817144c8081281f77508d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022dc817144c8081281f77508d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512dc817144c8081281f77508d',
#       'width': 64}],
#     'name': 'Ocean Eyes (The Remixes)',
#     'release_date': '2017-01-13',
#     'release_date_precision': 'day',
#     'total_tracks': 4,
#     'type': 'album',
#     'uri': 'spotify:album:44OSkEmvHwdTFhPBCewIks'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/670UISOh9XV1zlq5z5IfoY'},
#      'href': 'https://api.spotify.com/v1/artists/670UISOh9XV1zlq5z5IfoY',
#      'id': '670UISOh9XV1zlq5z5IfoY',
#      'name': 'GOLDHOUSE',
#      'type': 'artist',
#      'uri': 'spotify:artist:670UISOh9XV1zlq5z5IfoY'}],
#    'disc_number': 1,
#    'duration_ms': 213600,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'TCACL1637941'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1JbuC7uZm0P1PyX7N7gDEM'},
#    'href': 'https://api.spotify.com/v1/tracks/1JbuC7uZm0P1PyX7N7gDEM',
#    'id': '1JbuC7uZm0P1PyX7N7gDEM',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Ocean Eyes - GOLDHOUSE Remix',
#    'popularity': 56,
#    'preview_url': None,
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:1JbuC7uZm0P1PyX7N7gDEM'},
#   'video_thumbnail': {'url': None}}]

# %% [markdown]
# ## Getting the artists of the playlist

# %%
def get_artists_from_track(track):
    return [artist["name"] for artist in track["artists"]]

# %%
def get_artists_from_playlist(playlist_id):
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    return list(set(artist for subset in [get_artists_from_track(track["track"]) for track in tracks_from_playlist] for artist in subset))

# %%
get_artists_from_playlist("4rnleEAOdmFAbRcNCgZMpY")

# %% [markdown]
# ## Artists ID

# %%
def get_artists_from_track(track):
    return[artist["name"] for artist in track["artists"]]

#--------------------------------------------------------------------

def get_artists_ids_from_track(track):
    return [artist["id"] for artist in track["artists"]]

# %%
def get_artists_ids_from_playlist(playlist_id):
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    return list(set(artist for subset in [get_artists_ids_from_track(track["track"]) for track in tracks_from_playlist] for artist in subset))

# %%
artists = get_artists_from_playlist("4rnleEAOdmFAbRcNCgZMpY") # Apply the function
artists_ids = get_artists_ids_from_playlist("4rnleEAOdmFAbRcNCgZMpY")
len(artists)
len(artists_ids) # We might have more ids due to artists having the same name
# Out:
# 2420

# %% [markdown]
# # Getting the info

# %% [markdown]
# In this section we will work with albums to extract information. We will start by extracting all the albums of an artist.

# %%
def get_albums_from_artist(artist_id):
    results = sp.artist_albums(artist_id, limit = 50,country="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# Same for albums ids
def get_album_ids_from_artist(artist_id):
    results = sp.artist_albums(artist_id, limit = 50)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return [track["id"] for track in tracks]

# %%
get_albums_from_artist("6qqNVTkY8uBg9cP3Jd7DAH")
# Out:
# [{'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0JGOiO34nwfUdDrD612dOp'},
#   'href': 'https://api.spotify.com/v1/albums/0JGOiO34nwfUdDrD612dOp',
#   'id': '0JGOiO34nwfUdDrD612dOp',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2732a038d3bf875d23e4aeaa84e',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e022a038d3bf875d23e4aeaa84e',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048512a038d3bf875d23e4aeaa84e',
#     'width': 64}],
#   'name': 'Happier Than Ever',
#   'release_date': '2021-07-30',
#   'release_date_precision': 'day',
#   'total_tracks': 16,
#   'type': 'album',
#   'uri': 'spotify:album:0JGOiO34nwfUdDrD612dOp'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5tzRuO6GP7WRvP3rEOPAO9'},
#   'href': 'https://api.spotify.com/v1/albums/5tzRuO6GP7WRvP3rEOPAO9',
#   'id': '5tzRuO6GP7WRvP3rEOPAO9',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273e1317227c6c759e01beae66e',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02e1317227c6c759e01beae66e',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851e1317227c6c759e01beae66e',
#     'width': 64}],
#   'name': 'Happier Than Ever',
#   'release_date': '2021-07-30',
#   'release_date_precision': 'day',
#   'total_tracks': 16,
#   'type': 'album',
#   'uri': 'spotify:album:5tzRuO6GP7WRvP3rEOPAO9'},
#  {'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0S0KGZnfBGSIssfF54WSJh'},
#   'href': 'https://api.spotify.com/v1/albums/0S0KGZnfBGSIssfF54WSJh',
#   'id': '0S0KGZnfBGSIssfF54WSJh',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27350a3147b4edd7701a876c6ce',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0250a3147b4edd7701a876c6ce',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485150a3147b4edd7701a876c6ce',
#     'width': 64}],
#   'name': 'WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?',
#   'release_date': '2019-03-29',
#   'release_date_precision': 'day',
#   'total_tracks': 14,
#   'type': 'album',
#   'uri': 'spotify:album:0S0KGZnfBGSIssfF54WSJh'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2kzPJWrTjVKEYWWhowXLnz'},
#   'href': 'https://api.spotify.com/v1/albums/2kzPJWrTjVKEYWWhowXLnz',
#   'id': '2kzPJWrTjVKEYWWhowXLnz',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27331aa3ebe23f59778bff800c9',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0231aa3ebe23f59778bff800c9',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485131aa3ebe23f59778bff800c9',
#     'width': 64}],
#   'name': 'Happier Than Ever (Edit)',
#   'release_date': '2021-07-28',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:2kzPJWrTjVKEYWWhowXLnz'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5lDUpb6zBr4xBh9AGUXYtQ'},
#   'href': 'https://api.spotify.com/v1/albums/5lDUpb6zBr4xBh9AGUXYtQ',
#   'id': '5lDUpb6zBr4xBh9AGUXYtQ',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2735f831fc87adfeab20ce97c7b',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e025f831fc87adfeab20ce97c7b',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048515f831fc87adfeab20ce97c7b',
#     'width': 64}],
#   'name': 'Happier Than Ever (Edit)',
#   'release_date': '2021-07-28',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:5lDUpb6zBr4xBh9AGUXYtQ'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2AyexmwyUy1nZfBadyewL7'},
#   'href': 'https://api.spotify.com/v1/albums/2AyexmwyUy1nZfBadyewL7',
#   'id': '2AyexmwyUy1nZfBadyewL7',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27398a3d331aad09aede2a9dcad',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0298a3d331aad09aede2a9dcad',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485198a3d331aad09aede2a9dcad',
#     'width': 64}],
#   'name': 'ilomilo (Live From The Film - Billie Eilish: The World’s A Little Blurry)',
#   'release_date': '2021-02-22',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:2AyexmwyUy1nZfBadyewL7'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7ltDVBr6mKbRvohxheJ9h1'},
#     'href': 'https://api.spotify.com/v1/artists/7ltDVBr6mKbRvohxheJ9h1',
#     'id': '7ltDVBr6mKbRvohxheJ9h1',
#     'name': 'ROSALÍA',
#     'type': 'artist',
#     'uri': 'spotify:artist:7ltDVBr6mKbRvohxheJ9h1'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4E8puNI8tw7cXz6YJkwMew'},
#   'href': 'https://api.spotify.com/v1/albums/4E8puNI8tw7cXz6YJkwMew',
#   'id': '4E8puNI8tw7cXz6YJkwMew',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273c64ed7bab63186d7fca3012f',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02c64ed7bab63186d7fca3012f',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851c64ed7bab63186d7fca3012f',
#     'width': 64}],
#   'name': 'Lo Vas A Olvidar (with ROSALÍA)',
#   'release_date': '2021-01-21',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:4E8puNI8tw7cXz6YJkwMew'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7ltDVBr6mKbRvohxheJ9h1'},
#     'href': 'https://api.spotify.com/v1/artists/7ltDVBr6mKbRvohxheJ9h1',
#     'id': '7ltDVBr6mKbRvohxheJ9h1',
#     'name': 'ROSALÍA',
#     'type': 'artist',
#     'uri': 'spotify:artist:7ltDVBr6mKbRvohxheJ9h1'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3ZuV4xSFJnWDncgMICfFmX'},
#   'href': 'https://api.spotify.com/v1/albums/3ZuV4xSFJnWDncgMICfFmX',
#   'id': '3ZuV4xSFJnWDncgMICfFmX',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273a5fe409478aefa2527076489',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02a5fe409478aefa2527076489',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851a5fe409478aefa2527076489',
#     'width': 64}],
#   'name': 'Lo Vas A Olvidar (with ROSALÍA)',
#   'release_date': '2021-01-21',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:3ZuV4xSFJnWDncgMICfFmX'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5G58VVE9ub1KE01Mvbd8XM'},
#   'href': 'https://api.spotify.com/v1/albums/5G58VVE9ub1KE01Mvbd8XM',
#   'id': '5G58VVE9ub1KE01Mvbd8XM',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2737a152619a7b55bc621d07901',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e027a152619a7b55bc621d07901',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048517a152619a7b55bc621d07901',
#     'width': 64}],
#   'name': 'Therefore I Am',
#   'release_date': '2020-11-12',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:5G58VVE9ub1KE01Mvbd8XM'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/3oxhQpF3Twbkl18oQYfnh5'},
#   'href': 'https://api.spotify.com/v1/albums/3oxhQpF3Twbkl18oQYfnh5',
#   'id': '3oxhQpF3Twbkl18oQYfnh5',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273954fe13f7c5f4b2f18d066b8',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02954fe13f7c5f4b2f18d066b8',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851954fe13f7c5f4b2f18d066b8',
#     'width': 64}],
#   'name': 'my future',
#   'release_date': '2020-07-30',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:3oxhQpF3Twbkl18oQYfnh5'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5sXSHscDjBez8VF20cSyad'},
#   'href': 'https://api.spotify.com/v1/albums/5sXSHscDjBez8VF20cSyad',
#   'id': '5sXSHscDjBez8VF20cSyad',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273f7b7174bef6f3fbfda3a0bb7',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02f7b7174bef6f3fbfda3a0bb7',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851f7b7174bef6f3fbfda3a0bb7',
#     'width': 64}],
#   'name': 'No Time To Die',
#   'release_date': '2020-02-13',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:5sXSHscDjBez8VF20cSyad'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4i3rAwPw7Ln2YrKDusaWyT'},
#   'href': 'https://api.spotify.com/v1/albums/4i3rAwPw7Ln2YrKDusaWyT',
#   'id': '4i3rAwPw7Ln2YrKDusaWyT',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273f2248cf6dad1d6c062587249',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02f2248cf6dad1d6c062587249',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851f2248cf6dad1d6c062587249',
#     'width': 64}],
#   'name': 'everything i wanted',
#   'release_date': '2019-11-13',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:4i3rAwPw7Ln2YrKDusaWyT'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#     'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#     'id': '1uNFoZAHBGtllmzznpCI3s',
#     'name': 'Justin Bieber',
#     'type': 'artist',
#     'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6lMlX68jJrx67hiCqdiDvW'},
#   'href': 'https://api.spotify.com/v1/albums/6lMlX68jJrx67hiCqdiDvW',
#   'id': '6lMlX68jJrx67hiCqdiDvW',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273a69b8b111a5fb8cb1c97e8eb',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02a69b8b111a5fb8cb1c97e8eb',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851a69b8b111a5fb8cb1c97e8eb',
#     'width': 64}],
#   'name': 'bad guy (with Justin Bieber)',
#   'release_date': '2019-07-11',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:6lMlX68jJrx67hiCqdiDvW'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0LgnntyagLdfW5Dz2OSYHU'},
#   'href': 'https://api.spotify.com/v1/albums/0LgnntyagLdfW5Dz2OSYHU',
#   'id': '0LgnntyagLdfW5Dz2OSYHU',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27373f85e8b4338d2aa07f59f3a',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0273f85e8b4338d2aa07f59f3a',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485173f85e8b4338d2aa07f59f3a',
#     'width': 64}],
#   'name': 'WHEN I WAS OLDER (Music Inspired By The Film ROMA)',
#   'release_date': '2019-01-09',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:0LgnntyagLdfW5Dz2OSYHU'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0ifM8RTX9HjtCJtY9452bW'},
#   'href': 'https://api.spotify.com/v1/albums/0ifM8RTX9HjtCJtY9452bW',
#   'id': '0ifM8RTX9HjtCJtY9452bW',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27348a98a5a97b2cc7963016888',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0248a98a5a97b2cc7963016888',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485148a98a5a97b2cc7963016888',
#     'width': 64}],
#   'name': 'come out and play',
#   'release_date': '2018-11-20',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:0ifM8RTX9HjtCJtY9452bW'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6LuN9FCkKOj5PcnpouEgny'},
#     'href': 'https://api.spotify.com/v1/artists/6LuN9FCkKOj5PcnpouEgny',
#     'id': '6LuN9FCkKOj5PcnpouEgny',
#     'name': 'Khalid',
#     'type': 'artist',
#     'uri': 'spotify:artist:6LuN9FCkKOj5PcnpouEgny'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2sBB17RXTamvj7Ncps15AK'},
#   'href': 'https://api.spotify.com/v1/albums/2sBB17RXTamvj7Ncps15AK',
#   'id': '2sBB17RXTamvj7Ncps15AK',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2738a3f0a3ca7929dea23cd274c',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e028a3f0a3ca7929dea23cd274c',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048518a3f0a3ca7929dea23cd274c',
#     'width': 64}],
#   'name': 'lovely (with Khalid)',
#   'release_date': '2018-04-19',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:2sBB17RXTamvj7Ncps15AK'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1Z0XtKcevvITZ5ydimkYcx'},
#   'href': 'https://api.spotify.com/v1/albums/1Z0XtKcevvITZ5ydimkYcx',
#   'id': '1Z0XtKcevvITZ5ydimkYcx',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273408b5dbd24ad9f44bb1af72f',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02408b5dbd24ad9f44bb1af72f',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851408b5dbd24ad9f44bb1af72f',
#     'width': 64}],
#   'name': 'bitches broken hearts',
#   'release_date': '2018-03-30',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:1Z0XtKcevvITZ5ydimkYcx'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5m9lO9SriYMPpXTrVIU8P5'},
#   'href': 'https://api.spotify.com/v1/albums/5m9lO9SriYMPpXTrVIU8P5',
#   'id': '5m9lO9SriYMPpXTrVIU8P5',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273b01e0794e65a909958897fa2',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02b01e0794e65a909958897fa2',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851b01e0794e65a909958897fa2',
#     'width': 64}],
#   'name': 'MyBoi (TroyBoi Remix)',
#   'release_date': '2018-03-09',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:5m9lO9SriYMPpXTrVIU8P5'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/586uxXMyD5ObPuzjtrzO1Q'},
#     'href': 'https://api.spotify.com/v1/artists/586uxXMyD5ObPuzjtrzO1Q',
#     'id': '586uxXMyD5ObPuzjtrzO1Q',
#     'name': 'Sofi Tukker',
#     'type': 'artist',
#     'uri': 'spotify:artist:586uxXMyD5ObPuzjtrzO1Q'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5XRJoC2QtsNbAubsCrBBbG'},
#   'href': 'https://api.spotify.com/v1/albums/5XRJoC2QtsNbAubsCrBBbG',
#   'id': '5XRJoC2QtsNbAubsCrBBbG',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2738fbc40da547bc157e8956cea',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e028fbc40da547bc157e8956cea',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048518fbc40da547bc157e8956cea',
#     'width': 64}],
#   'name': 'COPYCAT (Sofi Tukker Remix)',
#   'release_date': '2018-01-12',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:5XRJoC2QtsNbAubsCrBBbG'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/7fRrTyKvE4Skh93v97gtcU'},
#   'href': 'https://api.spotify.com/v1/albums/7fRrTyKvE4Skh93v97gtcU',
#   'id': '7fRrTyKvE4Skh93v97gtcU',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273a9f6c04ba168640b48aa5795',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02a9f6c04ba168640b48aa5795',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851a9f6c04ba168640b48aa5795',
#     'width': 64}],
#   'name': 'dont smile at me',
#   'release_date': '2017-12-22',
#   'release_date_precision': 'day',
#   'total_tracks': 9,
#   'type': 'album',
#   'uri': 'spotify:album:7fRrTyKvE4Skh93v97gtcU'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/68kEuyFKyqrdQQLLsmiatm'},
#     'href': 'https://api.spotify.com/v1/artists/68kEuyFKyqrdQQLLsmiatm',
#     'id': '68kEuyFKyqrdQQLLsmiatm',
#     'name': 'Vince Staples',
#     'type': 'artist',
#     'uri': 'spotify:artist:68kEuyFKyqrdQQLLsmiatm'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6eQpKhYCtvD0TwXQVHsgC2'},
#   'href': 'https://api.spotify.com/v1/albums/6eQpKhYCtvD0TwXQVHsgC2',
#   'id': '6eQpKhYCtvD0TwXQVHsgC2',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273f3425d012117543bf914c451',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02f3425d012117543bf914c451',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851f3425d012117543bf914c451',
#     'width': 64}],
#   'name': '&burn (with Vince Staples)',
#   'release_date': '2017-12-15',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:6eQpKhYCtvD0TwXQVHsgC2'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5YCdlD3eREt72lTZxNL7id'},
#   'href': 'https://api.spotify.com/v1/albums/5YCdlD3eREt72lTZxNL7id',
#   'id': '5YCdlD3eREt72lTZxNL7id',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2739c05fec02bd9b81ee1246b2f',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e029c05fec02bd9b81ee1246b2f',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048519c05fec02bd9b81ee1246b2f',
#     'width': 64}],
#   'name': 'dont smile at me (Expanded Edition)',
#   'release_date': '2017-08-11',
#   'release_date_precision': 'day',
#   'total_tracks': 11,
#   'type': 'album',
#   'uri': 'spotify:album:5YCdlD3eREt72lTZxNL7id'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2I9wpUTuzMT8aS6iVpM2EQ'},
#   'href': 'https://api.spotify.com/v1/albums/2I9wpUTuzMT8aS6iVpM2EQ',
#   'id': '2I9wpUTuzMT8aS6iVpM2EQ',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273b16b427371c5fdd76f1b0ee1',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02b16b427371c5fdd76f1b0ee1',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851b16b427371c5fdd76f1b0ee1',
#     'width': 64}],
#   'name': 'Bellyache (Marian Hill Remix)',
#   'release_date': '2017-05-05',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:2I9wpUTuzMT8aS6iVpM2EQ'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4iyJ8i3eKbez8JXDbsHIdZ'},
#   'href': 'https://api.spotify.com/v1/albums/4iyJ8i3eKbez8JXDbsHIdZ',
#   'id': '4iyJ8i3eKbez8JXDbsHIdZ',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273e0f2af91be409aad81bba98c',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02e0f2af91be409aad81bba98c',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851e0f2af91be409aad81bba98c',
#     'width': 64}],
#   'name': 'Bored',
#   'release_date': '2017-03-30',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:4iyJ8i3eKbez8JXDbsHIdZ'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/25FGyvj0UnD6YYWLq0s9nl'},
#   'href': 'https://api.spotify.com/v1/albums/25FGyvj0UnD6YYWLq0s9nl',
#   'id': '25FGyvj0UnD6YYWLq0s9nl',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2734adbeb26299adca766cec2c5',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e024adbeb26299adca766cec2c5',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048514adbeb26299adca766cec2c5',
#     'width': 64}],
#   'name': 'Bellyache',
#   'release_date': '2017-02-24',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:25FGyvj0UnD6YYWLq0s9nl'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/7Chuv69qWaXuK5eCmZ8gCi'},
#   'href': 'https://api.spotify.com/v1/albums/7Chuv69qWaXuK5eCmZ8gCi',
#   'id': '7Chuv69qWaXuK5eCmZ8gCi',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2737b9881aa297e336c0d4d5cef',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e027b9881aa297e336c0d4d5cef',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048517b9881aa297e336c0d4d5cef',
#     'width': 64}],
#   'name': 'Six Feet Under (The Remixes)',
#   'release_date': '2017-02-03',
#   'release_date_precision': 'day',
#   'total_tracks': 4,
#   'type': 'album',
#   'uri': 'spotify:album:7Chuv69qWaXuK5eCmZ8gCi'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/44OSkEmvHwdTFhPBCewIks'},
#   'href': 'https://api.spotify.com/v1/albums/44OSkEmvHwdTFhPBCewIks',
#   'id': '44OSkEmvHwdTFhPBCewIks',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2732dc817144c8081281f77508d',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e022dc817144c8081281f77508d',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048512dc817144c8081281f77508d',
#     'width': 64}],
#   'name': 'Ocean Eyes (The Remixes)',
#   'release_date': '2017-01-13',
#   'release_date_precision': 'day',
#   'total_tracks': 4,
#   'type': 'album',
#   'uri': 'spotify:album:44OSkEmvHwdTFhPBCewIks'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2msN7XBgV3JCjQ7Tq3t7i9'},
#   'href': 'https://api.spotify.com/v1/albums/2msN7XBgV3JCjQ7Tq3t7i9',
#   'id': '2msN7XBgV3JCjQ7Tq3t7i9',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2732cafcdd985630d72594ecc49',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e022cafcdd985630d72594ecc49',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048512cafcdd985630d72594ecc49',
#     'width': 64}],
#   'name': 'Ocean Eyes',
#   'release_date': '2016-11-18',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:2msN7XBgV3JCjQ7Tq3t7i9'},
#  {'album_group': 'single',
#   'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/74TRp3O8BRdGxc0XO0UzoY'},
#   'href': 'https://api.spotify.com/v1/albums/74TRp3O8BRdGxc0XO0UzoY',
#   'id': '74TRp3O8BRdGxc0XO0UzoY',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273fae80fc6c7f60e75cfc519c7',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02fae80fc6c7f60e75cfc519c7',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851fae80fc6c7f60e75cfc519c7',
#     'width': 64}],
#   'name': 'Six Feet Under',
#   'release_date': '2016-11-17',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:74TRp3O8BRdGxc0XO0UzoY'},
#  {'album_group': 'appears_on',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2O439lGHwhRYc2rSNxenhB'},
#   'href': 'https://api.spotify.com/v1/albums/2O439lGHwhRYc2rSNxenhB',
#   'id': '2O439lGHwhRYc2rSNxenhB',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273f0a0a3cccb37ad19ae3bf7de',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02f0a0a3cccb37ad19ae3bf7de',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851f0a0a3cccb37ad19ae3bf7de',
#     'width': 64}],
#   'name': 'Música Para Niños: Éxitos',
#   'release_date': '2021-09-14',
#   'release_date_precision': 'day',
#   'total_tracks': 29,
#   'type': 'album',
#   'uri': 'spotify:album:2O439lGHwhRYc2rSNxenhB'},
#  {'album_group': 'appears_on',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1DxyBdVtWkNuQntkrcd2YY'},
#   'href': 'https://api.spotify.com/v1/albums/1DxyBdVtWkNuQntkrcd2YY',
#   'id': '1DxyBdVtWkNuQntkrcd2YY',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2735417d296d2098ead3af58165',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e025417d296d2098ead3af58165',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048515417d296d2098ead3af58165',
#     'width': 64}],
#   'name': 'Monster Pop Hits',
#   'release_date': '2021-09-10',
#   'release_date_precision': 'day',
#   'total_tracks': 28,
#   'type': 'album',
#   'uri': 'spotify:album:1DxyBdVtWkNuQntkrcd2YY'},
#  {'album_group': 'appears_on',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2UvTWAKSMlF3pYuK71IdfW'},
#   'href': 'https://api.spotify.com/v1/albums/2UvTWAKSMlF3pYuK71IdfW',
#   'id': '2UvTWAKSMlF3pYuK71IdfW',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273bf427b9bd081b8ddcd6a8a55',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02bf427b9bd081b8ddcd6a8a55',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851bf427b9bd081b8ddcd6a8a55',
#     'width': 64}],
#   'name': 'Fall Love Songs',
#   'release_date': '2021-09-10',
#   'release_date_precision': 'day',
#   'total_tracks': 15,
#   'type': 'album',
#   'uri': 'spotify:album:2UvTWAKSMlF3pYuK71IdfW'},
#  {'album_group': 'appears_on',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/7j2POSE9jvbSprLX7ffCmI'},
#   'href': 'https://api.spotify.com/v1/albums/7j2POSE9jvbSprLX7ffCmI',
#   'id': '7j2POSE9jvbSprLX7ffCmI',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2731f18c09af69e9ccbdc85d0ef',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e021f18c09af69e9ccbdc85d0ef',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048511f18c09af69e9ccbdc85d0ef',
#     'width': 64}],
#   'name': 'Like I Can',
#   'release_date': '2021-09-10',
#   'release_date_precision': 'day',
#   'total_tracks': 15,
#   'type': 'album',
#   'uri': 'spotify:album:7j2POSE9jvbSprLX7ffCmI'},
#  {'album_group': 'appears_on',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5iaQWHTIQDOgwMXVqgDGTD'},
#   'href': 'https://api.spotify.com/v1/albums/5iaQWHTIQDOgwMXVqgDGTD',
#   'id': '5iaQWHTIQDOgwMXVqgDGTD',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273c966edd9069a21c1f11ccc10',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02c966edd9069a21c1f11ccc10',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851c966edd9069a21c1f11ccc10',
#     'width': 64}],
#   'name': 'Breakup Songs To Scream',
#   'release_date': '2021-09-10',
#   'release_date_precision': 'day',
#   'total_tracks': 30,
#   'type': 'album',
#   'uri': 'spotify:album:5iaQWHTIQDOgwMXVqgDGTD'},
#  {'album_group': 'appears_on',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5wmIhQEeclhlGvv9uce2Yc'},
#   'href': 'https://api.spotify.com/v1/albums/5wmIhQEeclhlGvv9uce2Yc',
#   'id': '5wmIhQEeclhlGvv9uce2Yc',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2732d1dbb4c119d77e755010f80',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e022d1dbb4c119d77e755010f80',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048512d1dbb4c119d77e755010f80',
#     'width': 64}],
#   'name': 'Virgo Energy',
#   'release_date': '2021-09-10',
#   'release_date_precision': 'day',
#   'total_tracks': 15,
#   'type': 'album',
#   'uri': 'spotify:album:5wmIhQEeclhlGvv9uce2Yc'},
#  {'album_group': 'appears_on',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6PoVpBDB1QVVqZFX2s2FyO'},
#   'href': 'https://api.spotify.com/v1/albums/6PoVpBDB1QVVqZFX2s2FyO',
#   'id': '6PoVpBDB1QVVqZFX2s2FyO',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2737ff5dd7743259b243cb879fa',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e027ff5dd7743259b243cb879fa',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048517ff5dd7743259b243cb879fa',
#     'width': 64}],
#   'name': 'Dinner Chill Music',
#   'release_date': '2021-09-10',
#   'release_date_precision': 'day',
#   'total_tracks': 30,
#   'type': 'album',
#   'uri': 'spotify:album:6PoVpBDB1QVVqZFX2s2FyO'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2Ykq3HY9ehZU5q6ST5aAQP'},
#   'href': 'https://api.spotify.com/v1/albums/2Ykq3HY9ehZU5q6ST5aAQP',
#   'id': '2Ykq3HY9ehZU5q6ST5aAQP',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2739c566d4d9dfe34724bb16cfc',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e029c566d4d9dfe34724bb16cfc',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048519c566d4d9dfe34724bb16cfc',
#     'width': 64}],
#   'name': "it's giving fall",
#   'release_date': '2021-09-10',
#   'release_date_precision': 'day',
#   'total_tracks': 20,
#   'type': 'album',
#   'uri': 'spotify:album:2Ykq3HY9ehZU5q6ST5aAQP'},
#  {'album_group': 'appears_on',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0A0Ql1Dm4SRQ9RSZRm2e0J'},
#   'href': 'https://api.spotify.com/v1/albums/0A0Ql1Dm4SRQ9RSZRm2e0J',
#   'id': '0A0Ql1Dm4SRQ9RSZRm2e0J',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27393724ebeb06b5c1ea2b20e59',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0293724ebeb06b5c1ea2b20e59',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485193724ebeb06b5c1ea2b20e59',
#     'width': 64}],
#   'name': 'Chilled R&B',
#   'release_date': '2021-09-10',
#   'release_date_precision': 'day',
#   'total_tracks': 24,
#   'type': 'album',
#   'uri': 'spotify:album:0A0Ql1Dm4SRQ9RSZRm2e0J'},
#  {'album_group': 'appears_on',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6KkwSHBXcqVOEQZAqdmtty'},
#   'href': 'https://api.spotify.com/v1/albums/6KkwSHBXcqVOEQZAqdmtty',
#   'id': '6KkwSHBXcqVOEQZAqdmtty',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27380cac8526fd25574ac9056ac',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0280cac8526fd25574ac9056ac',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485180cac8526fd25574ac9056ac',
#     'width': 64}],
#   'name': 'Hits Rentree 2021',
#   'release_date': '2021-09-10',
#   'release_date_precision': 'day',
#   'total_tracks': 60,
#   'type': 'album',
#   'uri': 'spotify:album:6KkwSHBXcqVOEQZAqdmtty'},
#  {'album_group': 'appears_on',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5OmrHkEJBQeZYTCdPjQ8sc'},
#   'href': 'https://api.spotify.com/v1/albums/5OmrHkEJBQeZYTCdPjQ8sc',
#   'id': '5OmrHkEJBQeZYTCdPjQ8sc',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2738030ef716ad50c771b3eb509',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e028030ef716ad50c771b3eb509',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048518030ef716ad50c771b3eb509',
#     'width': 64}],
#   'name': "But they'll never love you like",
#   'release_date': '2021-09-09',
#   'release_date_precision': 'day',
#   'total_tracks': 25,
#   'type': 'album',
#   'uri': 'spotify:album:5OmrHkEJBQeZYTCdPjQ8sc'},
#  {'album_group': 'appears_on',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1x9fBNjYnmau3x5msthFyT'},
#   'href': 'https://api.spotify.com/v1/albums/1x9fBNjYnmau3x5msthFyT',
#   'id': '1x9fBNjYnmau3x5msthFyT',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27379eb2983560f0df72bc1e620',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0279eb2983560f0df72bc1e620',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485179eb2983560f0df72bc1e620',
#     'width': 64}],
#   'name': 'theyll never love you like',
#   'release_date': '2021-09-09',
#   'release_date_precision': 'day',
#   'total_tracks': 26,
#   'type': 'album',
#   'uri': 'spotify:album:1x9fBNjYnmau3x5msthFyT'},
#  {'album_group': 'appears_on',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
# ...
#   'total_tracks': 20,
#   'type': 'album',
#   'uri': 'spotify:album:4RpgjxgSxcRwGNuWnImneN'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4Vf5l1TvPROSWTSzIj9v6i'},
#   'href': 'https://api.spotify.com/v1/albums/4Vf5l1TvPROSWTSzIj9v6i',
#   'id': '4Vf5l1TvPROSWTSzIj9v6i',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273ac2372b9d344a5d3fc9167cc',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02ac2372b9d344a5d3fc9167cc',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851ac2372b9d344a5d3fc9167cc',
#     'width': 64}],
#   'name': 'Top 30 US',
#   'release_date': '2018-04-27',
#   'release_date_precision': 'day',
#   'total_tracks': 30,
#   'type': 'album',
#   'uri': 'spotify:album:4Vf5l1TvPROSWTSzIj9v6i'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/41vkdnhery9pTR4iBwpeKn'},
#   'href': 'https://api.spotify.com/v1/albums/41vkdnhery9pTR4iBwpeKn',
#   'id': '41vkdnhery9pTR4iBwpeKn',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2733f0479a898ea907cf54d8064',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e023f0479a898ea907cf54d8064',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048513f0479a898ea907cf54d8064',
#     'width': 64}],
#   'name': 'Chill Wind Down',
#   'release_date': '2018-04-20',
#   'release_date_precision': 'day',
#   'total_tracks': 28,
#   'type': 'album',
#   'uri': 'spotify:album:41vkdnhery9pTR4iBwpeKn'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0UURABllcIvOWRXAyzMQsy'},
#   'href': 'https://api.spotify.com/v1/albums/0UURABllcIvOWRXAyzMQsy',
#   'id': '0UURABllcIvOWRXAyzMQsy',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27331c25321f3ac749834c99c46',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0231c25321f3ac749834c99c46',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485131c25321f3ac749834c99c46',
#     'width': 64}],
#   'name': 'Fresh For 2018',
#   'release_date': '2018-01-19',
#   'release_date_precision': 'day',
#   'total_tracks': 43,
#   'type': 'album',
#   'uri': 'spotify:album:0UURABllcIvOWRXAyzMQsy'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5bL1zO5hy4pwIActiffZSo'},
#   'href': 'https://api.spotify.com/v1/albums/5bL1zO5hy4pwIActiffZSo',
#   'id': '5bL1zO5hy4pwIActiffZSo',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2730cde228fbe420a543938a929',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e020cde228fbe420a543938a929',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048510cde228fbe420a543938a929',
#     'width': 64}],
#   'name': 'Helix (Volume 1)',
#   'release_date': '2017-11-17',
#   'release_date_precision': 'day',
#   'total_tracks': 20,
#   'type': 'album',
#   'uri': 'spotify:album:5bL1zO5hy4pwIActiffZSo'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/68FGnF6LTrgtYHQDVgPkZL'},
#   'href': 'https://api.spotify.com/v1/albums/68FGnF6LTrgtYHQDVgPkZL',
#   'id': '68FGnF6LTrgtYHQDVgPkZL',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2730e46960707a051199917b50e',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e020e46960707a051199917b50e',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048510e46960707a051199917b50e',
#     'width': 64}],
#   'name': "NOW That's What I Call Music, Vol. 64",
#   'release_date': '2017-11-03',
#   'release_date_precision': 'day',
#   'total_tracks': 22,
#   'type': 'album',
#   'uri': 'spotify:album:68FGnF6LTrgtYHQDVgPkZL'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0qMJpB1ZbVLU0p0RkrNyQN'},
#   'href': 'https://api.spotify.com/v1/albums/0qMJpB1ZbVLU0p0RkrNyQN',
#   'id': '0qMJpB1ZbVLU0p0RkrNyQN',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273191d9212a062cb992a535735',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02191d9212a062cb992a535735',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851191d9212a062cb992a535735',
#     'width': 64}],
#   'name': 'Pastel Goth',
#   'release_date': '2017-09-22',
#   'release_date_precision': 'day',
#   'total_tracks': 22,
#   'type': 'album',
#   'uri': 'spotify:album:0qMJpB1ZbVLU0p0RkrNyQN'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5L5J1xNm6oQb6AZtQYsctQ'},
#   'href': 'https://api.spotify.com/v1/albums/5L5J1xNm6oQb6AZtQYsctQ',
#   'id': '5L5J1xNm6oQb6AZtQYsctQ',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273118fab08371fc6510323d739',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02118fab08371fc6510323d739',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851118fab08371fc6510323d739',
#     'width': 64}],
#   'name': 'Deep Songwriters',
#   'release_date': '2017-09-01',
#   'release_date_precision': 'day',
#   'total_tracks': 20,
#   'type': 'album',
#   'uri': 'spotify:album:5L5J1xNm6oQb6AZtQYsctQ'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/35zjbqKjGdbXOIrpmo9ZGS'},
#   'href': 'https://api.spotify.com/v1/albums/35zjbqKjGdbXOIrpmo9ZGS',
#   'id': '35zjbqKjGdbXOIrpmo9ZGS',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27338a23f2044ab928d803021f8',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0238a23f2044ab928d803021f8',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485138a23f2044ab928d803021f8',
#     'width': 64}],
#   'name': 'Electronic Chill',
#   'release_date': '2017-08-18',
#   'release_date_precision': 'day',
#   'total_tracks': 23,
#   'type': 'album',
#   'uri': 'spotify:album:35zjbqKjGdbXOIrpmo9ZGS'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/03zG7RXfRVtembbdsQaop1'},
#   'href': 'https://api.spotify.com/v1/albums/03zG7RXfRVtembbdsQaop1',
#   'id': '03zG7RXfRVtembbdsQaop1',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27392eb52c21aa666d0b1e1370d',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0292eb52c21aa666d0b1e1370d',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485192eb52c21aa666d0b1e1370d',
#     'width': 64}],
#   'name': 'Background Music',
#   'release_date': '2017-08-04',
#   'release_date_precision': 'day',
#   'total_tracks': 20,
#   'type': 'album',
#   'uri': 'spotify:album:03zG7RXfRVtembbdsQaop1'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/031MdHpLnKjZgw84xs8P35'},
#   'href': 'https://api.spotify.com/v1/albums/031MdHpLnKjZgw84xs8P35',
#   'id': '031MdHpLnKjZgw84xs8P35',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2730cae1ce655c99ee0c1534d58',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e020cae1ce655c99ee0c1534d58',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048510cae1ce655c99ee0c1534d58',
#     'width': 64}],
#   'name': 'Nastaw się na chill out, Vol. 17',
#   'release_date': '2017-05-26',
#   'release_date_precision': 'day',
#   'total_tracks': 26,
#   'type': 'album',
#   'uri': 'spotify:album:031MdHpLnKjZgw84xs8P35'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/0vCnfRymNflFa4Zx9mZCwZ'},
#   'href': 'https://api.spotify.com/v1/albums/0vCnfRymNflFa4Zx9mZCwZ',
#   'id': '0vCnfRymNflFa4Zx9mZCwZ',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273b65ed1440e4f16f4d62669d0',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02b65ed1440e4f16f4d62669d0',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851b65ed1440e4f16f4d62669d0',
#     'width': 64}],
#   'name': 'Everything, Everything (Original Motion Picture Soundtrack)',
#   'release_date': '2017-05-17',
#   'release_date_precision': 'day',
#   'total_tracks': 11,
#   'type': 'album',
#   'uri': 'spotify:album:0vCnfRymNflFa4Zx9mZCwZ'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2xerQRqzikn4agzay3EHnd'},
#   'href': 'https://api.spotify.com/v1/albums/2xerQRqzikn4agzay3EHnd',
#   'id': '2xerQRqzikn4agzay3EHnd',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2734626edb6b415d69356a84223',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e024626edb6b415d69356a84223',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048514626edb6b415d69356a84223',
#     'width': 64}],
#   'name': 'Everything, Everything (Original Motion Picture Soundtrack)',
#   'release_date': '2017-05-17',
#   'release_date_precision': 'day',
#   'total_tracks': 11,
#   'type': 'album',
#   'uri': 'spotify:album:2xerQRqzikn4agzay3EHnd'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2OicPkzxga0ybQIdl3kvaa'},
#   'href': 'https://api.spotify.com/v1/albums/2OicPkzxga0ybQIdl3kvaa',
#   'id': '2OicPkzxga0ybQIdl3kvaa',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b2738e0cf26ddc14f90080a62aac',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e028e0cf26ddc14f90080a62aac',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d000048518e0cf26ddc14f90080a62aac',
#     'width': 64}],
#   'name': '13 Reasons Why (A Netflix Original Series Soundtrack)',
#   'release_date': '2017-03-30',
#   'release_date_precision': 'day',
#   'total_tracks': 13,
#   'type': 'album',
#   'uri': 'spotify:album:2OicPkzxga0ybQIdl3kvaa'},
#  {'album_group': 'appears_on',
#   'album_type': 'compilation',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#     'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#     'id': '0LyfQWJT6nXafLPZqxe9Of',
#     'name': 'Various Artists',
#     'type': 'artist',
#     'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/7z3lbsoJ6fqaYdPWaOYnB2'},
#   'href': 'https://api.spotify.com/v1/albums/7z3lbsoJ6fqaYdPWaOYnB2',
#   'id': '7z3lbsoJ6fqaYdPWaOYnB2',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273f39cf592977ea48323d58638',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02f39cf592977ea48323d58638',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851f39cf592977ea48323d58638',
#     'width': 64}],
#   'name': 'Common Culture, Vol. V by Connor Franta',
#   'release_date': '2016-04-29',
#   'release_date_precision': 'day',
#   'total_tracks': 12,
#   'type': 'album',
#   'uri': 'spotify:album:7z3lbsoJ6fqaYdPWaOYnB2'}]

# %% [markdown]
# Example: Coldplay

# %%
coldplay_id = "4gzpq5DPGxSnKTe4SA8HAU"
coldplay_albums = get_albums_from_artist(coldplay_id)
coldplay_album_ids = get_album_ids_from_artist(coldplay_id)

# Check artists that played with coldplay
set([artist["name"] for track in coldplay_albums for artist in track["artists"]])
# Out:
# {'Alexandre Desplat',
#  'Alyx Ander',
#  'Banda Sinfónica da Polícia de Seguranca Pública',
#  'Coldplay',
#  'Greta Bradman',
#  'José Manuel Ferreira Brito',
#  'Rhythms Del Mundo',
#  'Rihanna',
#  'Robin Schulz',
#  'Seeb',
#  'Swedish House Mafia',
#  'The Chainsmokers',
#  'The String Family',
#  'Tiësto',
#  'Various Artists',
#  'ZHU'}

# %% [markdown]
# ## Getting the songs of a given album

# %%
def get_track_ids_from_albums(album_ids):
    return list(set([i["id"] for j in album_ids for i in sp.album(j)["tracks"]["items"]]))

# %%
coldplay_songs = get_track_ids_from_albums(coldplay_album_ids)

len(coldplay_songs)
# Out:
# 15256
